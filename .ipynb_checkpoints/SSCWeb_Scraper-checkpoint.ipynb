# %% [markdown]
# ## Jupyter Notebook to Scrap SSCWeb using sscws

# %% [markdown]
# This notebook uses [sscws](https://pypi.org/project/sscws/) to generate a DB of data availability for the followign missions:
# - DMSP
# - FAST

# %% [markdown]
# ### Prerequisites
# 1. pip install sscws

# %% [markdown]
# ### Setup

# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import datetime

import csv



# Imports for SSCWS
from sscws.sscws import SscWs
from sscws.bfieldmodels import BFieldModel, Tsyganenko89cBFieldModel
from sscws.coordinates import CoordinateComponent, CoordinateSystem,\
    SurfaceGeographicCoordinates
from sscws.filteroptions import LocationFilterOptions,\
    MappedRegionFilterOptions, RegionFilterOptions,\
    SpaceRegionsFilterOptions
from sscws.outputoptions import CoordinateOptions, BFieldTraceOptions,\
    DistanceFromOptions, LocationFilter, OutputOptions, RegionOptions,\
    ValueOptions
from sscws.regions import Hemisphere, HemisphereRegions
from sscws.request import DataRequest, SatelliteSpecification
from sscws.timeinterval import TimeInterval
ssc = SscWs()

# %%
# Identify save directory
save_directory = '/Users/ryanmcgranaghan/Documents/Helio_ECIP/data/summary_data/'

# %%
ssc.get_observatories()#.index('dmsp')
# Out:
# {'Observatory': [{'Id': 'ace',
#    'Name': 'ACE',
#    'Resolution': 720,
#    'StartTime': datetime.datetime(1997, 8, 25, 17, 48, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 6, 13, 23, 48, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/ACE'},
#   {'Id': 'active',
#    'Name': 'Active',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1989, 9, 29, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1991, 10, 4, 8, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'aec',
#    'Name': 'AE-C',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1973, 12, 17, 8, 1, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1978, 12, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'aerocube6a',
#    'Name': 'AEROCUBE-6A',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 6, 29, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'aerocube6b',
#    'Name': 'AEROCUBE-6B',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 6, 29, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'aim',
#    'Name': 'AIM',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2007, 4, 25, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/AIM'},
#   {'Id': 'akebono',
#    'Name': 'Akebono',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1989, 2, 23, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2019, 5, 14, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/Akebono'},
#   {'Id': 'alouette1',
#    'Name': 'Alouette-1',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1965, 1, 1, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1972, 9, 25, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/Alouette1'},
#   {'Id': 'alouette2',
#    'Name': 'Alouette-2',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1966, 1, 27, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1975, 7, 31, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/Alouette2'},
#   {'Id': 'apex',
#    'Name': 'APEX-MAIN',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1991, 12, 17, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2004, 5, 1, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'aqua',
#    'Name': 'Aqua',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2002, 5, 4, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'arase',
#    'Name': 'Arase (ERG)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2016, 12, 20, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'arasepred',
#    'Name': 'Arase (ERG, 1-year Predict)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2018, 1, 16, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2022, 1, 1, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'ariel4',
#    'Name': 'ARIEL-4',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1972, 1, 16, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1978, 11, 26, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'artemisp1',
#    'Name': 'ARTEMIS_P1',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2007, 2, 18, 0, 13, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 4, 22, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'artemisp1pred',
#    'Name': 'ARTEMIS_P1 (6-year Predict)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2008, 7, 18, 0, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2023, 6, 8, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'artemisp2',
#    'Name': 'ARTEMIS_P2',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2007, 2, 18, 0, 13, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 4, 22, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'artemisp2pred',
#    'Name': 'ARTEMIS_P2 (6-year Predict)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2008, 7, 18, 0, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2023, 6, 8, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'astrid2',
#    'Name': 'ASTRID II',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1998, 12, 12, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2002, 4, 3, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'aura',
#    'Name': 'Aura',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2004, 7, 15, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1a',
#    'Name': 'BARREL-1A',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 28, 13, 25, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 2, 14, 1, 42, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1b',
#    'Name': 'BARREL-1B',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 2, 10, 26, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 1, 9, 20, 16, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1c',
#    'Name': 'BARREL-1C',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 16, 19, 11, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 1, 26, 1, 52, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1d',
#    'Name': 'BARREL-1D',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 4, 17, 7, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 1, 21, 10, 19, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1g',
#    'Name': 'BARREL-1G',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 14, 13, 44, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 1, 27, 8, 16, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1h',
#    'Name': 'BARREL-1H',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 19, 17, 44, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 2, 11, 16, 15, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1i',
#    'Name': 'BARREL-1I',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 9, 19, 16, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 2, 2, 22, 11, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1j',
#    'Name': 'BARREL-1J',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 1, 18, 24, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 1, 14, 20, 52, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1k',
#    'Name': 'BARREL-1K',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 5, 17, 49, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 1, 21, 1, 23, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1m',
#    'Name': 'BARREL-1M',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 6, 19, 10, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 1, 12, 5, 32, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1o',
#    'Name': 'BARREL-1O',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 9, 14, 29, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 1, 17, 9, 39, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1q',
#    'Name': 'BARREL-1Q',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 20, 21, 40, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 2, 6, 16, 23, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1r',
#    'Name': 'BARREL-1R',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 21, 21, 46, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 1, 23, 11, 23, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1s',
#    'Name': 'BARREL-1S',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 22, 16, 31, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 1, 27, 4, 20, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1t',
#    'Name': 'BARREL-1T',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 24, 16, 43, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 2, 15, 20, 10, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1u',
#    'Name': 'BARREL-1U',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 26, 17, 38, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 2, 9, 3, 58, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel1v',
#    'Name': 'BARREL-1V',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 1, 30, 18, 26, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 2, 6, 1, 20, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2a',
#    'Name': 'BARREL-2A',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 16, 16, 9, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 2, 4, 17, 46, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2b',
#    'Name': 'BARREL-2B',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 17, 19, 40, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 2, 8, 5, 57, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2c',
#    'Name': 'BARREL-2C',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 20, 18, 32, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 1, 25, 7, 45, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2d',
#    'Name': 'BARREL-2D',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 27, 16, 9, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 1, 29, 3, 48, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2e',
#    'Name': 'BARREL-2E',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 30, 16, 16, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 2, 11, 7, 7, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2f',
#    'Name': 'BARREL-2F',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 2, 1, 16, 27, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 2, 3, 14, 29, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2i',
#    'Name': 'BARREL-2I',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 12, 31, 12, 2, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 1, 14, 21, 46, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2k',
#    'Name': 'BARREL-2K',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 4, 12, 48, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 1, 13, 9, 46, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2l',
#    'Name': 'BARREL-2L',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 6, 17, 15, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 2, 3, 8, 34, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2m',
#    'Name': 'BARREL-2M',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 11, 11, 31, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 1, 13, 6, 9, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2n',
#    'Name': 'BARREL-2N',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 18, 13, 8, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 1, 19, 2, 41, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2o',
#    'Name': 'BARREL-2O',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 26, 17, 59, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 2, 9, 9, 31, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2p',
#    'Name': 'BARREL-2P',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 30, 11, 43, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 2, 11, 17, 11, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2q',
#    'Name': 'BARREL-2Q',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 2, 2, 14, 52, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 2, 4, 6, 25, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2t',
#    'Name': 'BARREL-2T',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 12, 31, 11, 29, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 1, 17, 7, 45, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2w',
#    'Name': 'BARREL-2W',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 12, 31, 17, 51, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 1, 11, 17, 46, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2x',
#    'Name': 'BARREL-2X',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 4, 19, 23, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 1, 22, 8, 18, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'barrel2y',
#    'Name': 'BARREL-2Y',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 11, 19, 46, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 1, 19, 18, 16, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'bepicolombo',
#    'Name': 'BepiColombo',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2018, 10, 20, 2, 13, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2025, 11, 2, 0, 48, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'calipso',
#    'Name': 'CALIPSO',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2006, 4, 28, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'cassiope',
#    'Name': 'CASSIOPE',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 10, 7, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'cce',
#    'Name': 'CCE (AMPTE/CCE)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1984, 8, 16, 15, 55, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1989, 8, 1, 0, 4, 59, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/AMPTE-CCE'},
#   {'Id': 'champ',
#    'Name': 'CHAMP',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2000, 11, 9, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2010, 9, 19, 6, 45, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/CHAMP'},
#   {'Id': 'chandra',
#    'Name': 'Chandra',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1999, 10, 31, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2013, 7, 2, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'chibism',
#    'Name': 'Chibis-M',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2012, 1, 26, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 11, 4, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'cloudsat',
#    'Name': 'Cloudsat',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2006, 5, 5, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'cluster1',
#    'Name': 'Cluster-1 (FM5/Rumba)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2000, 8, 22, 0, 2, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2025, 11, 5, 23, 59, 30, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/Cluster-Rumba'},
#   {'Id': 'cluster2',
#    'Name': 'Cluster-2 (FM6/Salsa)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2000, 8, 22, 0, 2, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2024, 8, 30, 23, 59, 30, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/Cluster-Salsa'},
#   {'Id': 'cluster3',
#    'Name': 'Cluster-3 (FM7/Samba)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2000, 8, 22, 0, 2, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2026, 6, 29, 23, 59, 30, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/Cluster-Samba'},
#   {'Id': 'cluster4',
#    'Name': 'Cluster-4 (FM8/Tango)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2000, 8, 22, 0, 2, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2026, 6, 29, 23, 59, 30, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/Cluster-Tango'},
#   {'Id': 'cnofs',
#    'Name': 'C/NOFS',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2008, 4, 18, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2015, 11, 26, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/CNOFS'},
#   {'Id': 'crres',
#    'Name': 'CRRES',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1990, 7, 25, 23, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1991, 12, 4, 8, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/CRRES'},
#   {'Id': 'csswe',
#    'Name': 'CSSWE',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2012, 10, 6, 14, 58, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2015, 4, 8, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'dawn',
#    'Name': 'Dawn',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 6, 19, 1, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2018, 4, 9, 15, 51, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'de1',
#    'Name': 'DE-1',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1981, 8, 3, 10, 37, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1991, 3, 2, 8, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/DynamicsExplorer1'},
#   {'Id': 'de2',
#    'Name': 'DE-2',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1981, 8, 4, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1983, 2, 19, 12, 19, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/DynamicsExplorer2'},
#   {'Id': 'demeter',
#    'Name': 'DEMETER',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2004, 7, 8, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2010, 12, 11, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'dmea',
#    'Name': 'DME-A',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1966, 4, 10, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1969, 7, 1, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'dmspf06',
#    'Name': 'DMSP-06',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1982, 12, 22, 13, 28, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1987, 12, 27, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'dmspf07',
#    'Name': 'DMSP-07',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1983, 11, 18, 14, 24, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1988, 12, 28, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'dmspf08',
#    'Name': 'DMSP-08',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1987, 6, 20, 4, 22, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1994, 9, 13, 8, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/DMSP_5D-2/F08'},
#   {'Id': 'dmspf09',
#    'Name': 'DMSP-09',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1988, 2, 5, 14, 46, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1992, 12, 29, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/DMSP_5D-2/F09'},
#   {'Id': 'dmspf10',
#    'Name': 'DMSP-10',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1990, 12, 2, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1999, 9, 12, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/DMSP_5D-2/F10'},
#   {'Id': 'dmspf11',
#    'Name': 'DMSP-11',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1991, 11, 29, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2003, 9, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/DMSP_5D-2/F11'},
#   {'Id': 'dmspf12',
#    'Name': 'DMSP-12',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1994, 9, 16, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2003, 9, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/DMSP_5D-2/F12'},
#   {'Id': 'dmspf13',
#    'Name': 'DMSP-13',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1995, 4, 13, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2010, 5, 8, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/DMSP_5D-2/F13'},
#   {'Id': 'dmspf14',
#    'Name': 'DMSP-14',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1997, 4, 20, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2010, 11, 13, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/DMSP_5D-2/F14'},
#   {'Id': 'dmspf15',
#    'Name': 'DMSP-15',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1999, 12, 13, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 3, 8, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/DMSP_5D-3/F15'},
#   {'Id': 'dmspf16',
#    'Name': 'DMSP-16',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2003, 10, 18, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 3, 8, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/DMSP_5D-3/F16'},
#   {'Id': 'dmspf17',
#    'Name': 'DMSP-17',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2006, 11, 5, 16, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 3, 8, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/DMSP_5D-3/F17'},
#   {'Id': 'dmspf18',
#    'Name': 'DMSP-18',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2009, 10, 22, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 3, 8, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/DMSP_5D-3/F18'},
#   {'Id': 'dmspf19',
#    'Name': 'DMSP-19',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 4, 3, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2016, 11, 13, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'doublestar1',
#    'Name': 'Double Star-1',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2004, 1, 3, 7, 5, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2007, 10, 10, 12, 37, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/DoubleStar1'},
#   {'Id': 'doublestar2',
#    'Name': 'Double Star-2',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2004, 9, 16, 23, 53, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2009, 12, 31, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/DoubleStar2'},
#   {'Id': 'dscovr',
#    'Name': 'DSCOVR',
#    'Resolution': 720,
#    'StartTime': datetime.datetime(2015, 2, 11, 23, 48, 6, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 19, 12, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'elfina',
#    'Name': 'ELFIN-A',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2018, 9, 15, 18, 43, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 18, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'elfinapred',
#    'Name': 'ELFIN-A (2-year Predict)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2018, 9, 17, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2023, 1, 3, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'elfinb',
#    'Name': 'ELFIN-B',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2018, 9, 15, 18, 43, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 18, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'elfinbpred',
#    'Name': 'ELFIN-B (2-year Predict)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2018, 9, 17, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2023, 1, 3, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'equators',
#    'Name': 'Equator-S',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1997, 12, 12, 16, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1998, 9, 24, 8, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/Equator-S'},
#   {'Id': 'explorer45',
#    'Name': 'Explorer-45',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1971, 11, 22, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1974, 1, 31, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'fast',
#    'Name': 'FAST',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1996, 8, 22, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/FAST'},
#   {'Id': 'firebird3',
#    'Name': 'FIREBIRD 3',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2015, 1, 31, 20, 10, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 18, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'firebird4',
#    'Name': 'FIREBIRD 4',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2015, 1, 31, 20, 10, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 19, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'freja',
#    'Name': 'Freja',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1992, 10, 7, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2000, 5, 11, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'gcomw1',
#    'Name': 'GCOM-W1',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2012, 5, 17, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'genesis',
#    'Name': 'Genesis',
#    'Resolution': 3600,
#    'StartTime': datetime.datetime(2001, 8, 12, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2004, 9, 7, 23, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/Genesis'},
#   {'Id': 'geotail',
#    'Name': 'Geotail',
#    'Resolution': 720,
#    'StartTime': datetime.datetime(1992, 7, 26, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 23, 23, 48, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/Geotail'},
#   {'Id': 'geotailpred',
#    'Name': 'Geotail (2-year Predict)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2016, 7, 27, 0, 1, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2019, 3, 31, 23, 58, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'gms3',
#    'Name': 'GMS-3',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1986, 3, 25, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1986, 7, 1, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'goes10',
#    'Name': 'GOES-10',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1997, 4, 25, 0, 6, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2009, 11, 28, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/GOES/10'},
#   {'Id': 'goes11',
#    'Name': 'GOES-11',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(2000, 5, 17, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2016, 12, 17, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/GOES/11'},
#   {'Id': 'goes12',
#    'Name': 'GOES-12',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2001, 8, 18, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2016, 12, 20, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/GOES/12'},
#   {'Id': 'goes13',
#    'Name': 'GOES-13',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(2006, 6, 10, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/GOES/13'},
#   {'Id': 'goes14',
#    'Name': 'GOES-14',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(2009, 7, 9, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/GOES/14'},
#   {'Id': 'goes15',
#    'Name': 'GOES-15',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(2010, 3, 21, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/GOES/15'},
#   {'Id': 'goes16',
#    'Name': 'GOES-16',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2016, 12, 3, 10, 55, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/GOES/16'},
#   {'Id': 'goes17',
#    'Name': 'GOES-17',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2018, 3, 21, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/GOES/17'},
#   {'Id': 'goes6',
#    'Name': 'GOES-6',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(1993, 12, 1, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1995, 5, 1, 8, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/GOES/6'},
#   {'Id': 'goes7',
#    'Name': 'GOES-7',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(1987, 4, 15, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1998, 12, 2, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/GOES/7'},
#   {'Id': 'goes8',
#    'Name': 'GOES-8',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1994, 5, 3, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2016, 11, 23, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/GOES/8'},
#   {'Id': 'goes9',
#    'Name': 'GOES-9',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1995, 6, 5, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2010, 3, 18, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/GOES/9'},
#   {'Id': 'gold',
#    'Name': 'GOLD',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2018, 1, 27, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'goldc',
#    'Name': 'GOLD (Conceptual)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2018, 9, 1, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2019, 8, 31, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'gosat',
#    'Name': 'GOSAT',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2009, 1, 30, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'grace1',
#    'Name': 'GRACE-1',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2002, 3, 31, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2018, 3, 25, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'grace2',
#    'Name': 'GRACE-2',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2002, 3, 31, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2018, 1, 12, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'gracefo1',
#    'Name': 'GRACE-FO1',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2018, 5, 30, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'gracefo2',
#    'Name': 'GRACE-FO2',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2018, 5, 30, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'hawkeye',
#    'Name': 'Hawkeye',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(1974, 6, 9, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1978, 1, 1, 8, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/Hawkeye'},
#   {'Id': 'hinode',
#    'Name': 'Hinode',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2006, 9, 23, 0, 10, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'icon',
#    'Name': 'ICON',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2019, 10, 17, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'image',
#    'Name': 'IMAGE',
#    'Resolution': 120,
#    'StartTime': datetime.datetime(2000, 3, 27, 0, 0, 55, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 8, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/IMAGE'},
#   {'Id': 'imp7',
#    'Name': 'IMP-7',
#    'Resolution': 720,
#    'StartTime': datetime.datetime(1972, 9, 26, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1978, 10, 1, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/IMP7'},
#   {'Id': 'imp8',
#    'Name': 'IMP-8',
#    'Resolution': 300,
#    'StartTime': datetime.datetime(1973, 10, 30, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2010, 1, 1, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/IMP8'},
#   {'Id': 'interballaurora',
#    'Name': 'Interball-2 (Auroral Probe)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1996, 9, 2, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1999, 7, 15, 8, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/Interball-2'},
#   {'Id': 'interballtail',
#    'Name': 'Interball-1 (Tail)',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(1995, 8, 4, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2000, 10, 10, 8, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/Interball-1'},
#   {'Id': 'irm',
#    'Name': 'IRM (AMPTE/IRM)',
#    'Resolution': 720,
#    'StartTime': datetime.datetime(1984, 9, 12, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1986, 8, 30, 8, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/AMPTE-IRM'},
#   {'Id': 'isee1',
#    'Name': 'ISEE-1',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1977, 10, 22, 14, 49, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1987, 9, 26, 5, 58, 59, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/ISEE1'},
#   {'Id': 'isee2',
#    'Name': 'ISEE-2',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1977, 10, 22, 14, 49, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1987, 9, 26, 5, 58, 59, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/ISEE2'},
#   {'Id': 'isee3',
#    'Name': 'ISEE-3',
#    'Resolution': 720,
#    'StartTime': datetime.datetime(1978, 8, 16, 3, 43, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2014, 8, 11, 23, 36, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/ISEE3'},
#   {'Id': 'isis1',
#    'Name': 'ISIS-1',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1969, 1, 30, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1990, 1, 30, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/ISIS1'},
#   {'Id': 'isis2',
#    'Name': 'ISIS-2',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1971, 4, 10, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1990, 1, 30, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/ISIS2'},
#   {'Id': 'iss',
#    'Name': 'ISS',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1998, 11, 21, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'issb',
#    'Name': 'ISS-b',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1978, 2, 19, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1983, 11, 16, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'jason2',
#    'Name': 'JASON2',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2008, 7, 8, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2019, 11, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'juno',
#    'Name': 'Juno',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 8, 1, 1, 1, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2020, 2, 20, 17, 51, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'kepler',
#    'Name': 'Kepler',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 6, 0, 1, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2016, 9, 29, 23, 56, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'lanl01',
#    'Name': 'LANL-01',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(2001, 5, 2, 2, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2008, 1, 3, 17, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/LANL/2001'},
#   {'Id': 'lanl02',
#    'Name': 'LANL-02',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(2003, 10, 1, 2, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2008, 1, 3, 17, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/LANL/2002'},
#   {'Id': 'lanl89',
#    'Name': 'LANL-89',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(1993, 3, 15, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2008, 1, 3, 17, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/LANL/1989'},
#   {'Id': 'lanl90',
#    'Name': 'LANL-90',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(1994, 5, 20, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2005, 11, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/LANL/1990'},
#   {'Id': 'lanl91',
#    'Name': 'LANL-91',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(1993, 10, 27, 2, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2004, 11, 19, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/LANL/1991'},
#   {'Id': 'lanl94',
#    'Name': 'LANL-94',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(1996, 1, 1, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2008, 1, 3, 17, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/LANL/1994'},
#   {'Id': 'lanl97',
#    'Name': 'LANL-97',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(1997, 7, 4, 23, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2008, 1, 3, 17, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/LANL/1997'},
#   {'Id': 'lro',
#    'Name': 'LRO',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 12, 1, 1, 1, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2016, 8, 23, 23, 58, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'mars',
#    'Name': 'Mars',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2006, 1, 1, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2019, 12, 31, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'maven',
#    'Name': 'MAVEN',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 11, 21, 20, 1, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2019, 12, 25, 14, 58, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'mercury',
#    'Name': 'Mercury',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2008, 1, 1, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2015, 12, 31, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'messenger',
#    'Name': 'MESSENGER',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2004, 8, 3, 8, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2015, 3, 28, 10, 40, 39, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'metop1b',
#    'Name': 'MetOp-B (MetOp-1)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2012, 9, 17, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'metop2a',
#    'Name': 'MetOp-A (MetOp-2)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2006, 10, 19, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'microlab1',
#    'Name': 'Microlab1',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2000, 1, 1, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2005, 4, 30, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'mir',
#    'Name': 'MIR',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1995, 7, 26, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2000, 11, 29, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'mms1',
#    'Name': 'MMS 1',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2015, 3, 13, 10, 0, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 11, 27, 8, 29, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'mms1ltpred',
#    'Name': 'MMS 1 (5-year Predict)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2019, 8, 20, 15, 49, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2025, 12, 31, 22, 21, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'mms2',
#    'Name': 'MMS 2',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2015, 3, 13, 10, 0, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 11, 27, 8, 29, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'mms3',
#    'Name': 'MMS 3',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2015, 3, 13, 10, 0, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 11, 27, 8, 29, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'mms4',
#    'Name': 'MMS 4',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2015, 3, 13, 10, 0, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 11, 27, 8, 29, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'moon',
#    'Name': 'Moon',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1959, 1, 1, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2022, 8, 21, 23, 58, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'mro',
#    'Name': 'MRO',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2014, 1, 4, 21, 1, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2019, 4, 17, 12, 32, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'msx',
#    'Name': 'MSX',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1996, 4, 25, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1999, 3, 4, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'newhorizons',
#    'Name': 'New Horizons',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2006, 1, 19, 19, 51, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2019, 2, 28, 23, 58, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'noaa10',
#    'Name': 'NOAA-10',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1986, 9, 27, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1991, 9, 27, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/NOAA/10'},
#   {'Id': 'noaa12',
#    'Name': 'NOAA-12',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1991, 5, 16, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1998, 5, 2, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/NOAA/12'},
#   {'Id': 'noaa14',
#    'Name': 'NOAA-14',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1995, 1, 14, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2004, 5, 1, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/NOAA/14'},
#   {'Id': 'noaa15',
#    'Name': 'NOAA-15',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1998, 5, 26, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/NOAA/15'},
#   {'Id': 'noaa16',
#    'Name': 'NOAA-16',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2000, 9, 27, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2015, 12, 20, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/NOAA/16'},
#   {'Id': 'noaa17',
#    'Name': 'NOAA-17',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2002, 6, 25, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2015, 12, 20, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/NOAA/17'},
#   {'Id': 'noaa18',
#    'Name': 'NOAA-18',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2005, 7, 3, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/NOAA/18'},
#   {'Id': 'noaa19',
#    'Name': 'NOAA-19',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2009, 2, 6, 21, 37, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/NOAA/19'},
#   {'Id': 'noaa20',
#    'Name': 'NOAA-20',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2017, 12, 16, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'noaa5',
#    'Name': 'NOAA-5',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1976, 7, 31, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1980, 6, 28, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/NOAA/5'},
#   {'Id': 'noaa6',
#    'Name': 'NOAA-6',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1979, 10, 5, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1986, 8, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/NOAA/6'},
#   {'Id': 'noaa7',
#    'Name': 'NOAA-7',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1981, 10, 1, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1986, 6, 29, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/NOAA/7'},
#   {'Id': 'noaa8',
#    'Name': 'NOAA-8',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1983, 3, 28, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1985, 10, 27, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/NOAA/8'},
#   {'Id': 'oersted',
#    'Name': 'Oersted',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1999, 5, 15, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'ogo5',
#    'Name': 'OGO-5',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1969, 4, 9, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1971, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'ogo6',
#    'Name': 'OGO-6',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1969, 6, 5, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1970, 1, 1, 8, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/OGO6'},
#   {'Id': 'ohzora',
#    'Name': 'Ohzora',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1984, 2, 20, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1986, 4, 12, 8, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'parasol',
#    'Name': 'PARASOL',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2004, 12, 19, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'parkersp',
#    'Name': 'Parker Solar Probe',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2018, 8, 12, 8, 16, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 3, 25, 15, 59, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'parkersppred',
#    'Name': 'Parker Solar Probe (Predict)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2018, 8, 12, 8, 16, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2025, 8, 31, 9, 17, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'polar',
#    'Name': 'Polar',
#    'Resolution': 180,
#    'StartTime': datetime.datetime(1996, 3, 1, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2009, 6, 27, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/POLAR'},
#   {'Id': 'rbspa',
#    'Name': 'RBSP-A',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2012, 8, 30, 9, 25, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2019, 12, 7, 1, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/RBSP/A'},
#   {'Id': 'rbspapred',
#    'Name': 'RBSP-A (1-year Predict)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 11, 26, 0, 1, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2020, 9, 22, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'rbspb',
#    'Name': 'RBSP-B',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2012, 8, 30, 9, 25, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2019, 9, 16, 22, 11, 59, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/RBSP/B'},
#   {'Id': 'rbspbpred',
#    'Name': 'RBSP-B (1-year Predict)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 11, 26, 0, 1, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2020, 7, 14, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'reimei',
#    'Name': 'Reimei',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2005, 8, 25, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'rhessi',
#    'Name': 'RHESSI',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2002, 2, 5, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/RHESSI'},
#   {'Id': 'rocsat1',
#    'Name': 'ROCSAT1',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1999, 3, 31, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2004, 6, 13, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/ROCSAT-1'},
#   {'Id': 'rosetta',
#    'Name': 'Rosetta',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2004, 3, 2, 10, 27, 20, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2016, 7, 31, 1, 38, 30, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'sampex',
#    'Name': 'SAMPEX',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1992, 7, 4, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2012, 11, 12, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/SAMPEX'},
#   {'Id': 'scatha',
#    'Name': 'SCATHA',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1979, 2, 5, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1991, 1, 1, 8, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/SCATHA'},
#   {'Id': 'sdo',
#    'Name': 'SDO',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2010, 5, 22, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'smileconcept',
#    'Name': 'SMILE (Concept)',
#    'Resolution': 600,
#    'StartTime': datetime.datetime(2024, 12, 31, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2029, 12, 31, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'snoe',
#    'Name': 'SNOE',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1998, 2, 27, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2004, 5, 1, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/SNOE'},
#   {'Id': 'soho',
#    'Name': 'SOHO',
#    'Resolution': 720,
#    'StartTime': datetime.datetime(1995, 12, 2, 0, 12, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 31, 23, 48, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/SOHO'},
#   {'Id': 'solarorbiter',
#    'Name': 'Solar Orbiter',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2020, 2, 10, 4, 56, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2030, 11, 20, 3, 48, 29, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'sorce',
#    'Name': 'SORCE',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2003, 1, 30, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2020, 4, 12, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'spitzer',
#    'Name': 'Spitzer',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2003, 8, 25, 6, 26, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2022, 1, 1, 0, 3, 24, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'sputnik1',
#    'Name': 'Sputnik 1',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1957, 10, 4, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1957, 10, 31, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'st5a',
#    'Name': 'ST5-A',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2006, 3, 23, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2006, 8, 28, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/ST5-155'},
#   {'Id': 'st5b',
#    'Name': 'ST5-B',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2006, 3, 23, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2006, 8, 29, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/ST5-094'},
#   {'Id': 'st5c',
#    'Name': 'ST5-C',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2006, 3, 23, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2006, 8, 29, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/ST5-224'},
#   {'Id': 'stereoa',
#    'Name': 'STEREO-Ahead',
#    'Resolution': 720,
#    'StartTime': datetime.datetime(2006, 10, 27, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 7, 13, 23, 48, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/STEREO-A'},
#   {'Id': 'stereob',
#    'Name': 'STEREO-Behind',
#    'Resolution': 720,
#    'StartTime': datetime.datetime(2006, 10, 27, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 7, 6, 23, 48, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/STEREO-B'},
#   {'Id': 'sun',
#    'Name': 'Sun',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1959, 1, 1, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2022, 8, 21, 23, 58, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'suomi',
#    'Name': 'Suomi NPP',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2011, 11, 4, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'swarma',
#    'Name': 'Swarm A',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 11, 26, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'swarmb',
#    'Name': 'Swarm B',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 11, 26, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'swarmc',
#    'Name': 'Swarm C',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2013, 11, 26, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 10, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'tatiana1',
#    'Name': 'Tatiana1',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2005, 1, 25, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2007, 3, 30, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'tatiana2',
#    'Name': 'Tatiana2',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2009, 9, 17, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2010, 7, 13, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'themisa',
#    'Name': 'THEMIS-A (P5)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2007, 2, 18, 0, 13, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 4, 22, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/THEMIS/A'},
#   {'Id': 'themisapred',
#    'Name': 'THEMIS-A (8-year Predict)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2008, 7, 18, 0, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2027, 7, 8, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'themisb',
#    'Name': 'THEMIS-B (P1)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2007, 2, 18, 0, 13, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 4, 22, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/THEMIS/B'},
#   {'Id': 'themisbpred',
#    'Name': 'THEMIS-B (6-year Predict)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2008, 7, 18, 0, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2023, 6, 8, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'themisc',
#    'Name': 'THEMIS-C (P2)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2007, 2, 18, 0, 13, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 4, 22, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/THEMIS/C'},
#   {'Id': 'themiscpred',
#    'Name': 'THEMIS-C (6-year Predict)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2008, 7, 18, 0, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2023, 6, 8, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'themisd',
#    'Name': 'THEMIS-D (P3)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2007, 2, 18, 0, 13, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 4, 22, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/THEMIS/D'},
#   {'Id': 'themisdpred',
#    'Name': 'THEMIS-D (8-year Predict)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2008, 7, 18, 0, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2027, 7, 8, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'themise',
#    'Name': 'THEMIS-E (P4)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2007, 2, 18, 0, 13, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 4, 22, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/THEMIS/E'},
#   {'Id': 'themisepred',
#    'Name': 'THEMIS-E (8-year Predict)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2008, 7, 18, 0, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2027, 7, 8, 23, 58, 59, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'timed',
#    'Name': 'TIMED',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2002, 2, 7, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 9, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/TIMED'},
#   {'Id': 'trace',
#    'Name': 'TRACE',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1998, 4, 2, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2010, 10, 19, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/TRACE'},
#   {'Id': 'tse2017c',
#    'Name': 'Total_Solar_Eclipse_2017',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(2017, 8, 21, 16, 49, 59, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2017, 8, 21, 20, 1, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'twins1',
#    'Name': 'Twins1',
#    'Resolution': 120,
#    'StartTime': datetime.datetime(2007, 4, 1, 0, 2, 30, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2018, 12, 12, 23, 54, 29, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/TWINS1'},
#   {'Id': 'twins2',
#    'Name': 'Twins2',
#    'Resolution': 120,
#    'StartTime': datetime.datetime(2008, 4, 11, 0, 0, 29, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2016, 10, 26, 23, 58, 30, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/TWINS2'},
#   {'Id': 'uars',
#    'Name': 'UARS',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1991, 9, 20, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2006, 5, 11, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/UARS'},
#   {'Id': 'viking',
#    'Name': 'Viking',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1986, 3, 5, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1987, 1, 1, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'wind',
#    'Name': 'Wind',
#    'Resolution': 720,
#    'StartTime': datetime.datetime(1994, 11, 16, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 6, 29, 23, 48, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'xmm',
#    'Name': 'XMM-Newton',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1999, 12, 21, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(2021, 5, 11, 0, 0, tzinfo=tzutc()),
#    'ResourceId': None},
#   {'Id': 'yohkoh',
#    'Name': 'Yohkoh (Solar-A)',
#    'Resolution': 60,
#    'StartTime': datetime.datetime(1991, 9, 5, 0, 0, tzinfo=tzutc()),
#    'EndTime': datetime.datetime(1998, 1, 2, 0, 0, tzinfo=tzutc()),
#    'ResourceId': 'spase://SMWG/Observatory/Yohkoh'}],
#  'HttpStatus': 200}

# %% [markdown]
# ### Set datetime range

# %%
# dt_start = datetime.date(2000,1,1).isoformat()+'T00:00:00Z'
# print(dt_start)
# dt_end = datetime.date(2000,1,2).isoformat()+'T00:00:00Z'
# print(dt_end)


dt_start = datetime.datetime(2000,1,1)
dt_end = datetime.datetime(2000,12,31)

# %%
# Out:
# 2021-04-23 16:07:27.842505
# do some things
#
#
#  do some more things
# 0:00:00.000448

# %% [markdown]
# ### Get Locations

# %% [markdown]
# The following code gets location information for requested spacecraft IDs

# %%
sc_ids = ['dmspf' +  str(d).zfill(2) for d in range(6,19)]
sc_ids = sc_ids + ['fast']
sc_ids
# Out:
# ['dmspf06',
#  'dmspf07',
#  'dmspf08',
#  'dmspf09',
#  'dmspf10',
#  'dmspf11',
#  'dmspf12',
#  'dmspf13',
#  'dmspf14',
#  'dmspf15',
#  'dmspf16',
#  'dmspf17',
#  'dmspf18',
#  'fast']

# %% [markdown]
# ##### Prepare the output options

# %%
sats = []
for s in sc_ids:
    sats += [SatelliteSpecification(s, 1)] 
# sats

b_field_model = BFieldModel(external=Tsyganenko89cBFieldModel())

coord_options = [
    CoordinateOptions(CoordinateSystem.GEO, CoordinateComponent.LAT),
    CoordinateOptions(CoordinateSystem.GEO, CoordinateComponent.LON),
    CoordinateOptions(CoordinateSystem.GEO, CoordinateComponent.LOCAL_TIME),
    CoordinateOptions(CoordinateSystem.GM, CoordinateComponent.LAT),
    CoordinateOptions(CoordinateSystem.GM, CoordinateComponent.LON),
    CoordinateOptions(CoordinateSystem.GM, CoordinateComponent.LOCAL_TIME)
]

# B-field trace options 
#   (coordinate_system: bool = None, 
#    hemisphere: Hemisphere = None, 
#    footpoint_latitude: bool = None, 
#    footpoint_longitude: bool = None, 
#    field_line_length: bool = None)
b_field_trace_options = [
    BFieldTraceOptions(CoordinateSystem.GEO, Hemisphere.NORTH,
                       True, True, False),
    BFieldTraceOptions(CoordinateSystem.GEO, Hemisphere.SOUTH,
                       True, True, False),
    BFieldTraceOptions(CoordinateSystem.GM, Hemisphere.NORTH,
                       True, True, False),
    BFieldTraceOptions(CoordinateSystem.GM, Hemisphere.SOUTH,
                       True, True, False)
]

# region options details: (spacecraft: bool = None, radial_traced_footpoint: bool = None, north_b_traced_footpoint: bool = None, south_b_traced_footpoint: bool = None)

output_options = OutputOptions(
    coord_options,
    None, None,
    RegionOptions(True, True, True, True),
    None,
    None,
    b_field_trace_options
    )

# %% [markdown]
# ##### Create README

# %%
f = open(os.path.join(save_directory,'README.txt'), "w")
         
f.write("Data were generated on: "+str(datetime.datetime.now()))
f.write("\n\nOutput coordinates are geographic and geomagnetic (from SSCweb: https://sscweb.gsfc.nasa.gov/users_guide/Appendix_C.html)")
f.write("\n    geo: Geographic coordinate system. This system is defined so that its X-axis is in the Earths equatorial plane but is fixed with the rotation of the Earth so that it passes through the Greenwich meridian (0 longitude). Its Z-axis is parallel to the rotation axis of the Earth, and its Y-axis completes a right handed orthogonal set (Y = Z * X). ")
f.write("\n    gm: Geomagnetic coordinate system. Z-axis points to the Geomagnetic north pole (in Greenland). The positive X-axis points towards the great circle encompassing the North and South Geomagetic poles and lies in the geomagnetic equatorial plane in the segment that is in the western hemisphere. (The South GM pole is the antipode of the North GM pole.) Earth-centered Dipole is invoked. Y completes the triad.")
         
f.close()

# %% [markdown]
# ##### Run through dates

# %%
begin_time = datetime.datetime.now()

date = dt_start
while date <= dt_end:
    print('\n\n\n\n\n working on date = {}'.format(date))

    
    date_input_start = datetime.date(date.year,date.month,date.day).isoformat()+'T00:00:00Z'
    date_input_end = datetime.date(date.year,date.month,date.day).isoformat()+'T23:59:59Z'
    date_input = [date_input_start,
                  date_input_end]

    status, result = ssc.get_locations(sc_ids,
                                       date_input,)
    
    for d in range(len(result['Data'])):
#         print(' -----> working on s/c ID = {}\n\n\n'.format(result['Data'][d]['Id']))
        
        loop_directory = save_directory + str(date.year) + '/' + str(date.year)+str(date.month).zfill(2)+str(date.day).zfill(2)+'/'+str(result['Data'][d]['Id'])
        if not os.path.isdir(loop_directory):
            os.makedirs(loop_directory)

            
        if 'dmsp' in result['Data'][d]['Id']:
            loop_file = os.path.join(loop_directory,str(result['Data'][d]['Id'][0:3]) + '_' + str(result['Data'][d]['Id'][4:5]) + '_ephemeris_' + str(date.year)+str(date.month).zfill(2)+str(date.day).zfill(2) + '.csv')
        else:
            loop_file = os.path.join(loop_directory,str(result['Data'][d]['Id']) + '_ephemeris_' + str(date.year)+str(date.month).zfill(2)+str(date.day).zfill(2) + '.csv')

#         header_text = '# Ephemeris from Helio-KNOW Database\n# Generated using output from SSC\n# File generated on ' + str(datetime.datetime.now().year) + ' ' + str(datetime.datetime.now().month) + ' ' + str(datetime.datetime.now().day) + '\n# HEADER: year doy hh_mm_ss geographic_lat geographic_lon north_b_trace_lat north_b_trace_lon south_b_trace_lat south_b_trace_lon'
#         header_text = '# Ephemeris from Helio-KNOW Database\n# Generated using output from SSC\n# File generated on ' + str(datetime.datetime.now().year) + ' ' + str(datetime.datetime.now().month) + ' ' + str(datetime.datetime.now().day) + '\n# HEADER: year doy hh_mm_ss geographic_lat geographic_lon north_b_trace_lat north_b_trace_lon south_b_trace_lat south_b_trace_lon'
        data = result['Data'][d]
        coords = data['Coordinates']
        times = data['Time']
                
        df = pd.DataFrame()
        df['year'] = [t.year for t in times]
        df['month'] = [t.month for t in times]
        df['day'] = [t.day for t in times]
        df['hour'] = [t.hour for t in times]
        df['minute'] = [t.minute for t in times]
        df['latitude'] = coords['Latitude']
        df['longitude'] = coords['Longitude']
        df['local_time'] = coords['LocalTime']

#         df
        df.to_csv(loop_file, index=False)
        
#         with open(loop_file, mode='w') as csv_file:
#             loop_writer = csv.writer(loop_file, delimiter='\t', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#             loop_writer.writeheader(header_text)
#             for i in range(len(coords['Latitude'])):
#                 loop_writer.writerow([data['Id'],times[i].year,times[i].month.zfill(2),times[i].day.zfill(2),coords['Latitude'][i],coords['Longitude'][i]])
    
#         for i in range(len(coords['Latitude'])):
#             print(' ----->  -----> {}: {}     {} {}'.format(data['Id'],times[i],coords['Latitude'][i],coords['Longitude'][i]))
    
        # Write output to a file
        
        # Save the file
        
        
    date += datetime.timedelta(days=1)
    
    
    
time_elapsed = datetime.datetime.now() - begin_time
print(time_elapsed)
# Out:
#  working on date = 2000-01-01 00:00:00
#  -----> working on s/c ID = dmspf11
#
#
#
#  -----> working on s/c ID = dmspf12
#
#
#
#  -----> working on s/c ID = dmspf13
#
#
#
#  -----> working on s/c ID = dmspf14
#
#
#
#  -----> working on s/c ID = dmspf15
#
#
#
#  -----> working on s/c ID = fast
#
#
#
#
#
#
#
#
#  working on date = 2000-01-02 00:00:00
#  -----> working on s/c ID = dmspf11
#
#
#
#  -----> working on s/c ID = dmspf12
#
#
#
#  -----> working on s/c ID = dmspf13
#
#
#
#  -----> working on s/c ID = dmspf14
#
#
#
#  -----> working on s/c ID = dmspf15
#
#
#
#  -----> working on s/c ID = fast

# %%
date = dt_start
while date <= dt_end:
    print('\n\n\n\n\n working on date = {}'.format(date))

    
    date_input_start = datetime.date(date.year,date.month,date.day).isoformat()+'T00:00:00Z'
    date_input_end = datetime.date(date.year,date.month,date.day).isoformat()+'T23:59:59Z'
    date_input = [date_input_start,
                  date_input_end]

    result = ssc.get_locations(loc_request)
    if ~result['HttpStatus'] == 200:

        print('ssc.get_locations failed with status = ', result['HttpStatus'])
        if 'ErrorMessage' in result:
            print('ErrorMessage = ', result['ErrorMessage'])
            print('ErrorDescription = ', result['ErrorDescription'])
        else:
            print('HttpText = ', result['ErrorText'])

    
    for d in range(len(result['Data'])):
        print(' -----> working on s/c ID = {}\n\n\n'.format(result['Data'][d]['Id']))
        
        loop_directory = save_directory + str(date.year) + '/' + str(date.year)+str(date.month).zfill(2)+str(date.day).zfill(2)+'/'+str(result['Data'][d]['Id'])
        if not os.path.isdir(loop_directory):
            os.makedirs(loop_directory)

            
        if 'dmsp' in result['Data'][d]['Id']:
            loop_file = os.path.join(loop_directory,str(result['Data'][d]['Id'][0:4]) + '_' + str(result['Data'][d]['Id'][4:7]) + '_ephemeris_' + str(date.year)+str(date.month).zfill(2)+str(date.day).zfill(2) + '.csv')
        else:
            loop_file = os.path.join(loop_directory,str(result['Data'][d]['Id']) + '_ephemeris_' + str(date.year)+str(date.month).zfill(2)+str(date.day).zfill(2) + '.csv')
        
        data = result['Data'][0]
        coords = data['Coordinates']
        bfield_data = data['BTraceData']
        times = data['Time']

        df = pd.DataFrame()
        df['year'] = [t.year for t in times]
        df['month'] = [t.month for t in times]
        df['day'] = [t.day for t in times]
        df['hour'] = [t.hour for t in times]
        df['minute'] = [t.minute for t in times]
        df['geographic_lat'] = coords[0]['Latitude']
        df['geographic_lon'] = coords[0]['Longitude']
        df['geographic_lt'] = coords[0]['LocalTime']
        df['geomagnetic_lat'] = coords[1]['Latitude']
        df['geomagnetic_lon'] = coords[1]['Longitude']
        df['geomagnetic_lt'] = coords[1]['LocalTime']

        #  Key to B-Field Trace Data 
            # bfield_data[0] == GEO North
            # bfield_data[1] == GM North
            # bfield_data[2] == GM South
            # bfield_data[3] == GEO South
        df['geographic_north_b_trace_lat'] = bfield_data[0]['Latitude']
        df['geographic_north_b_trace_lon'] = bfield_data[0]['Longitude']
        df['geographic_south_b_trace_lat'] = bfield_data[3]['Latitude']
        df['geographic_south_b_trace_lon'] = bfield_data[3]['Longitude']
        df['geomagnetic_north_b_trace_lat'] = bfield_data[1]['Latitude']
        df['geomagnetic_north_b_trace_lon'] = bfield_data[1]['Longitude']
        df['geomagnetic_south_b_trace_lat'] = bfield_data[2]['Latitude']
        df['geomagnetic_south_b_trace_lon'] = bfield_data[2]['Longitude']

        df


        # Write output to a file
        df.to_csv(loop_file, index=False)
        
        
        
    date += datetime.timedelta(days=1)
# Out:
#  working on date = 2000-01-01 00:00:00
#  -----> working on s/c ID = dmspf11
#
#
#
#  -----> working on s/c ID = dmspf12
#
#
#
#  -----> working on s/c ID = dmspf13
#
#
#
#  -----> working on s/c ID = dmspf14
#
#
#
#  -----> working on s/c ID = dmspf15
#
#
#
#  -----> working on s/c ID = fast
#
#
#
#
#
#
#
#
#  working on date = 2000-01-02 00:00:00
#  -----> working on s/c ID = dmspf11
#
#
#
#  -----> working on s/c ID = dmspf12
#
#
#
#  -----> working on s/c ID = dmspf13
#
#
#
#  -----> working on s/c ID = dmspf14
#
#
#
#  -----> working on s/c ID = dmspf15
#
#
#
#  -----> working on s/c ID = fast

# %%
result['Data'][d-1]['Id'][4:7]
# Out:
# 'f15'

# %% [markdown]
# TO DO
# - Generate all data to populate the directory
# - Create interactive data visual with selection for date and visualization of all data for that day (maybe use CHESS dashboard as an example)

# %%
sats = []
for s in sc_ids:
    sats += [SatelliteSpecification(s, 1)]
    
sats
# Out:
# [<sscws.request.SatelliteSpecification at 0x19a880550>,
#  <sscws.request.SatelliteSpecification at 0x19a880220>,
#  <sscws.request.SatelliteSpecification at 0x19a880a90>,
#  <sscws.request.SatelliteSpecification at 0x19a880b50>,
#  <sscws.request.SatelliteSpecification at 0x19a880a00>,
#  <sscws.request.SatelliteSpecification at 0x19a880310>,
#  <sscws.request.SatelliteSpecification at 0x19a8808b0>,
#  <sscws.request.SatelliteSpecification at 0x19a8803a0>,
#  <sscws.request.SatelliteSpecification at 0x19a8801f0>,
#  <sscws.request.SatelliteSpecification at 0x19a880160>,
#  <sscws.request.SatelliteSpecification at 0x19a880100>,
#  <sscws.request.SatelliteSpecification at 0x19a8800d0>,
#  <sscws.request.SatelliteSpecification at 0x19a880040>,
#  <sscws.request.SatelliteSpecification at 0x19a880700>]

# %%
sats = [SatelliteSpecification('dmspf12', 1),
        SatelliteSpecification('dmspf13', 1)]

sats = []
for s in sc_ids:
    sats += [SatelliteSpecification(s, 1)]
    
sats

#------------------------------------------------------------------------------------------
# Prepare the output options
b_field_model = BFieldModel(external=Tsyganenko89cBFieldModel())

coord_options = [
    CoordinateOptions(CoordinateSystem.GEO, CoordinateComponent.LAT),
    CoordinateOptions(CoordinateSystem.GEO, CoordinateComponent.LON),
    CoordinateOptions(CoordinateSystem.GEO, CoordinateComponent.LOCAL_TIME),
    CoordinateOptions(CoordinateSystem.GM, CoordinateComponent.LAT),
    CoordinateOptions(CoordinateSystem.GM, CoordinateComponent.LON),
    CoordinateOptions(CoordinateSystem.GM, CoordinateComponent.LOCAL_TIME)
]

# B-field trace options 
#   (coordinate_system: bool = None, 
#    hemisphere: Hemisphere = None, 
#    footpoint_latitude: bool = None, 
#    footpoint_longitude: bool = None, 
#    field_line_length: bool = None)
b_field_trace_options = [
    BFieldTraceOptions(CoordinateSystem.GEO, Hemisphere.NORTH,
                       True, True, False),
    BFieldTraceOptions(CoordinateSystem.GEO, Hemisphere.SOUTH,
                       True, True, False),
    BFieldTraceOptions(CoordinateSystem.GM, Hemisphere.NORTH,
                       True, True, False),
    BFieldTraceOptions(CoordinateSystem.GM, Hemisphere.SOUTH,
                       True, True, False)
]

# region options details: (spacecraft: bool = None, radial_traced_footpoint: bool = None, north_b_traced_footpoint: bool = None, south_b_traced_footpoint: bool = None)

output_options = OutputOptions(
    coord_options,
    None, None,
    RegionOptions(True, True, True, True),
    None,
    None,
    b_field_trace_options
    )
#------------------------------------------------------------------------------------------


format_options = None

loc_request = DataRequest('dmspf12 request',
                          TimeInterval('2000-01-01T00:00:00Z',
                                       '2000-01-02T00:10:00Z'),
                          sats, b_field_model,
                          output_options, None,
                          None, format_options)

# %%
result = ssc.get_locations(loc_request)
if result['HttpStatus'] == 200:
    SscWs.print_locations_result(result)
else:
    print('ssc.get_locations failed with status = ', result['HttpStatus'])
    if 'ErrorMessage' in result:
        print('ErrorMessage = ', result['ErrorMessage'])
        print('ErrorDescription = ', result['ErrorDescription'])
    else:
        print('HttpText = ', result['ErrorText'])
# Out:
# dmspf11 Geo
# Time                      X                      Y                      Z
# Geo North Magnetic Field-Line Trace Footpoints
# Time                           Latitude         Longitude    Arc Length
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-8a8053fdb3d3> in <module>
#       1 result = ssc.get_locations(loc_request)
#       2 if result['HttpStatus'] == 200:
# ----> 3     SscWs.print_locations_result(result)
#       4 else:
#       5     print('ssc.get_locations failed with status = ', result['HttpStatus'])
#
# ~/opt/anaconda3/envs/pythontf/lib/python3.9/site-packages/sscws/sscws.py in print_locations_result(result)
#     693                                       b_trace['Latitude'][index],
#     694                                       b_trace['Longitude'][index],
# --> 695                                       b_trace['ArcLength'][index]))
#     696
#     697                 quantities = ['RadialLength', 'MagneticStrength',
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
date = dt_start
while date <= dt_end:
    print('\n\n\n\n\n working on date = {}'.format(date))

    
    date_input_start = datetime.date(date.year,date.month,date.day).isoformat()+'T00:00:00Z'
    date_input_end = datetime.date(date.year,date.month,date.day).isoformat()+'T23:59:59Z'
    date_input = [date_input_start,
                  date_input_end]

    for sc in sc_ids:
        result = ssc.get_locations(loc_request)

        status, result = ssc.get_locations(sc_ids,
                                           date_input,)
    
    for d in range(len(result['Data'])):
        print(' -----> working on s/c ID = {}\n\n\n'.format(result['Data'][d]['Id']))
        
        loop_directory = save_directory + str(date.year) + '/' + str(date.year)+str(date.month).zfill(2)+str(date.day).zfill(2)+'/'+str(result['Data'][d]['Id'])
        if not os.path.isdir(loop_directory):
            os.makedirs(loop_directory)

            
        if 'dmsp' in result['Data'][d]['Id']:
            loop_file = os.path.join(loop_directory,str(result['Data'][d]['Id'][0:3]) + '_' + str(result['Data'][d]['Id'][4:5]) + '_ephemeris_' + str(date.year)+str(date.month).zfill(2)+str(date.day).zfill(2) + '.csv')
        else:
            loop_file = os.path.join(loop_directory,str(result['Data'][d]['Id']) + '_ephemeris_' + str(date.year)+str(date.month).zfill(2)+str(date.day).zfill(2) + '.csv')
        
        data = result['Data'][0]
        coords = data['Coordinates']
        bfield_data = data['BTraceData']
        times = data['Time']

        df = pd.DataFrame()
        df['year'] = [t.year for t in times]
        df['month'] = [t.month for t in times]
        df['day'] = [t.day for t in times]
        df['hour'] = [t.hour for t in times]
        df['minute'] = [t.minute for t in times]
        df['geographic_lat'] = coords[0]['Latitude']
        df['geographic_lon'] = coords[0]['Longitude']
        df['geographic_lt'] = coords[0]['LocalTime']
        df['geomagnetic_lat'] = coords[1]['Latitude']
        df['geomagnetic_lon'] = coords[1]['Longitude']
        df['geomagnetic_lt'] = coords[1]['LocalTime']

        #  Key to B-Field Trace Data 
            # bfield_data[0] == GEO North
            # bfield_data[1] == GM North
            # bfield_data[2] == GM South
            # bfield_data[3] == GEO South
        df['geographic_north_b_trace_lat'] = bfield_data[0]['Latitude']
        df['geographic_north_b_trace_lon'] = bfield_data[0]['Longitude']
        df['geographic_south_b_trace_lat'] = bfield_data[3]['Latitude']
        df['geographic_south_b_trace_lon'] = bfield_data[3]['Longitude']
        df['geomagnetic_north_b_trace_lat'] = bfield_data[1]['Latitude']
        df['geomagnetic_north_b_trace_lon'] = bfield_data[1]['Longitude']
        df['geomagnetic_south_b_trace_lat'] = bfield_data[2]['Latitude']
        df['geomagnetic_south_b_trace_lon'] = bfield_data[2]['Longitude']

        df


        # Write output to a file
        df.to_csv(loop_file, index=False)
        
        
        
    date += datetime.timedelta(days=1)
