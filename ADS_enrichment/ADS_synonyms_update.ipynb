# %% [markdown]
# The purpose of this script is to update the NASA ADS synonyms files with AGU index terms related to Heliophysics and Space Weather
#
# Relevant resources:
# - ADS synonyms files:
#     - simple (single term) synonyms: data/ads_simple_synonyms.txt
#     - multi-term synonyms: data/ads_multi_synonyms.txt
# - AGU Index Terms: data/agu-index-terms.xlsx
# - Heliohpysics Acronyms (generated from 2013 Decadal Survey): data/solar_physics_acronyms.csv
#
# Dependencies:
# - [NLTK](https://www.nltk.org); and you must download the NLTK corpora
#
# Oustanding items:
# - We are not yet determining whether similar terms to the AGU index terms already exist in the ADS synonyms files. We need to explore that and if they do simply add the AGU index term as a synonym for that existing term
# - relying on common language model to generate word variations (wordnet) and we would benefit greatly from a science-based language model -> NEED: to somehow efficiently remove superfluous/non-scientific terms from the words returned from the synonym_antonym_extractor function
# - does ADS/Apache Solr handle antonyms?

# %%
import os, json
import numpy as np
import pandas as pd

import re

import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

import nltk

# %%
def synonym_antonym_extractor(phrase):
    '''
    Obtained from: https://www.holisticseo.digital/python-seo/nltk/wordnet
    NOTE: returns null sets for commons stop words (e.g., 'the', 'and')
    example: synonym_antonym_extractor('x-ray')
    '''
    from nltk.corpus import wordnet
    synonyms = []
    antonyms = []

    for syn in wordnet.synsets(phrase):
        for l in syn.lemmas():
            synonyms.append(l.name())
            if l.antonyms():
                antonyms.append(l.antonyms()[0].name())

    return(set(synonyms),set(antonyms))
#     print(set(synonyms))
#     print(set(antonyms))


def get_all_variations(list_of_lists):
    '''
    get all unique combinations of N lists
    requires passing a list of lists: list_of_lists = [[list1],[list2],...]
    obtained from: https://www.geeksforgeeks.org/python-all-possible-permutations-of-n-lists/
    example: get_all_variations( [[1,2,3],[4,5,6],[7,8,9]] )
    '''
    import itertools
    # using itertools.product()  
    # to compute all possible permutations
    all_combinations = list(itertools.product(*list_of_lists))
    return all_combinations

# %% [markdown]
# ### Read in AGU index terms

# %%
# Read in AGU Index Terms
pd_agu = pd.read_excel('data/agu-index-terms.xlsx')
pd_agu


for r in range(len(pd_agu)): 
    if ~( (pd_agu['Code'][r] >= 1900) & (pd_agu['Code'][r] < 1999) |
         (pd_agu['Code'][r] >= 2100) & (pd_agu['Code'][r] < 2199) |
         (pd_agu['Code'][r] >= 2400) & (pd_agu['Code'][r] < 2499) |
         (pd_agu['Code'][r] >= 2700) & (pd_agu['Code'][r] < 2799) |
         (pd_agu['Code'][r] >= 3200) & (pd_agu['Code'][r] < 3299) |
         (pd_agu['Code'][r] >= 4300) & (pd_agu['Code'][r] < 4399) |
         (pd_agu['Code'][r] >= 6900) & (pd_agu['Code'][r] < 6999) |
         (pd_agu['Code'][r] >= 7500) & (pd_agu['Code'][r] < 7599) |
         (pd_agu['Code'][r] >= 7800) & (pd_agu['Code'][r] < 7899) ):
#         print('Code = {} --> Term = {}'.format(pd_agu['Code'][r],pd_agu['Description'][r]))
        pd_agu = pd_agu.drop([r])

for r in pd_agu.index:
    if '(' in pd_agu['Description'][r]:
#         print('prior = {}'.format(pd_agu['Description'][r]))
        pd_agu['Description'][r] = pd_agu['Description'][r][0:pd_agu['Description'][r].find('(')-1]
#         print('post = {}'.format(pd_agu['Description'][r]))

# Transforming into a new dataframe that can be combined with other glossaries
pd_agu_terms = pd.DataFrame(columns=['term','definition'])
pd_agu_terms['term'] = pd_agu['Description']
pd_agu_terms

pd_agu_terms['term'] = pd_agu_terms['term'].str.lower()

pd_agu_terms['source'] = np.tile('agu',(len(pd_agu_terms),1))
pd_agu_terms
# Out:
# <ipython-input-3-fc53958012bc>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd_agu['Description'][r] = pd_agu['Description'][r][0:pd_agu['Description'][r].find('(')-1]
#                                   term definition source
# 432                        informatics        NaN    agu
# 433      community modeling frameworks        NaN    agu
# 434                community standards        NaN    agu
# 435   computational models, algorithms        NaN    agu
# 436                cyberinfrastructure        NaN    agu
# ...                                ...        ...    ...
# 1154               transport processes        NaN    agu
# 1155                        turbulence        NaN    agu
# 1156        wave/particle interactions        NaN    agu
# 1157            wave/wave interactions        NaN    agu
# 1158        instruments and techniques        NaN    agu
#
# [272 rows x 3 columns]

# %%
for r in pd_agu_terms['term'].values[0:10]:
    print(r)
# Out:
# informatics
# community modeling frameworks
# community standards
# computational models, algorithms
# cyberinfrastructure
# data assimilation, integration and fusion
# data management, preservation, rescue
# data mining
# data and information discovery
# decision analysis

# %% [markdown]
# ### Read in acronyms pulled from [2013 Solar and Space Physic Decadal Survey](https://nap.nationalacademies.org/read/13060/chapter/1)

# %%
file_acronyms = 'data/solar_physics_acronyms.csv'
pd_acronyms = pd.read_csv(file_acronyms)

pd_acronyms
# Out:
#       acronyms                                    terms
# 0          AAS            American Astronomical Society
# 1          ACE            Advanced Composition Explorer
# 2          ACR                     anomalous cosmic ray
# 3        AFOSR  Air Force Office of Scientific Research
# 4         AFRL            Air Force Research Laboratory
# ..         ...                                      ...
# 295        WHI               Whole Heliosphere Interval
# 296        WLC                  White Light Coronagraph
# 297        WPI                wave-particle interaction
# 298  WSA-Enlil                   Wang-Sheely-Arge-Enlil
# 299        WSO                 Wilcox Solar Observatory
#
# [300 rows x 2 columns]

# %%
# Make some corrections to the acronyms
for val in range(len(pd_acronyms)):
    
    # Catch abbreviations with periods in them
    pd_acronyms['terms'][val] = pd_acronyms['terms'][val].replace('.','')

    # Catch abbreviations with commas in them
    pd_acronyms['terms'][val] = pd_acronyms['terms'][val].replace(',','')
    
    # Catch some specific fixes
    pd_acronyms['terms'][val] = pd_acronyms['terms'][val].replace('-',' ')
pd_acronyms
# Out:
#       acronyms                                    terms
# 0          AAS            American Astronomical Society
# 1          ACE            Advanced Composition Explorer
# 2          ACR                     anomalous cosmic ray
# 3        AFOSR  Air Force Office of Scientific Research
# 4         AFRL            Air Force Research Laboratory
# ..         ...                                      ...
# 295        WHI               Whole Heliosphere Interval
# 296        WLC                  White Light Coronagraph
# 297        WPI                wave particle interaction
# 298  WSA-Enlil                   Wang Sheely Arge Enlil
# 299        WSO                 Wilcox Solar Observatory
#
# [300 rows x 2 columns]

# %% [markdown]
# ### Read in ADS synonyms

# %%
simple_syns_file = '/Users/ryanmcgranaghan/Documents/Helio_ECIP/dev/Helio-KNOW/ADS_enrichment/data/ads_simple_synonyms.txt'
f = open(simple_syns_file,"r")
txt_data_simple_syns = f.read().split('\n')#.remove('')
f.close()

simple_syns_data = [x.split('=>') for x in txt_data_simple_syns]
pd_simple_syns = pd.DataFrame(simple_syns_data,columns=['words','ADS term'])
pd_simple_syns

multi_syns_file = '/Users/ryanmcgranaghan/Documents/Helio_ECIP/dev/Helio-KNOW/ADS_enrichment/data/ads_multi_synonyms.txt'
f = open(multi_syns_file,"r")
txt_data_multi_syns = f.read().split('\n')#.remove('')
f.close()

txt_data_multi_syns = txt_data_multi_syns[:-1]

# %%
# Extract acronyms from multi-term synonyms file for later determining if Heliophysics acronyms already exist
extracted_acronyms = []
for val in txt_data_multi_syns:
    
    if (not val):
        continue
    elif (val[0] == '#'):
        continue
    else:
        
        extracted_acronyms.append(val.split(',')[0])

# %% [markdown]
# ### Method of Identifying Synonyms: OpenAlex
#
# This uses the [OpenAlex](https://explore.openalex.org) resource to identify related concepts and then prunes those results. OpenAlex is an open and comprehensive catalog of scholarly papers, authors, institutions, and more.
#
#
# TODO: look through UAT synonyms and remove duplicate/fuse similar terms

# %%
# Code from Donny Winston

from urllib.parse import urlencode

import requests

OPENALEX_HEADERS = {"User-Agent": "mailto:ryan.mcgranaghan@gmail.com"}
OPENALEX_API_BASE_URL = "https://api.openalex.org"

def openalex_get(path, params=None, page=1):
    url = f"{OPENALEX_API_BASE_URL}{path}"
    if params:
        url += f"?{urlencode(params)}&page={page}&per-page=200"
    return requests.get(url, headers=OPENALEX_HEADERS)


from toolz import get_in

from toolz import keyfilter

def pick(whitelist, d):
    return keyfilter(lambda k: k in whitelist, d)

def count_and_results(rv):
    d = rv.json()
    count = get_in(['meta', 'count'], d)
    results = [pick(['id', 'display_name', 'description'], r) for r in d['results']]
    return count, results

# %%
# read in synonyms files
with open('data/ads_simple_synonyms.txt') as f:
    ADS_simple_syns = [line for line in f.readlines()]
    
with open('data/ads_multi_synonyms.txt') as f:
    ADS_multi_syns = [line for line in f.readlines()]

# %%
any('astronomical journal' in x for x in ADS_multi_syns)
# Out:
# True

# %%
rv = openalex_get("/concepts", {"search": 'informatics'})
d=rv.json()
for r in d['results']:
    print('{} - {} - {}'.format(r['id'], r['display_name'], r['description']))
# Out:
# https://openalex.org/C145642194 - Health informatics - discipline at the intersection of information science, computer science, and health care
# https://openalex.org/C191630685 - Informatics - academic field
# https://openalex.org/C73851307 - Translational research informatics - discipline of applied computer science research concerned with the application of informatics theory and methods to translational research
# https://openalex.org/C158518442 - Engineering informatics - discipline combining information technology (IT) – or informatics – with engineering concepts
# https://openalex.org/C141363852 - Health Administration Informatics - None
# https://openalex.org/C106476913 - Public health informatics - None
# https://openalex.org/C62085286 - Materials informatics - None
# https://openalex.org/C167785021 - Health informatics tools - None
# https://openalex.org/C27518888 - Business informatics - science that deals with development and application of information and communication systems in business enterprises
# https://openalex.org/C86908248 - Museum informatics - None
# https://openalex.org/C92209122 - Informatics engineering - type of engineering
# https://openalex.org/C69505689 - Unified Medical Language System - medical informatics tool
# https://openalex.org/C89074322 - Telematics - integrated use of telecommunications and informatics for application in vehicles
# https://openalex.org/C2777019752 - Hospital information system - element of health informatics that focuses mainly on the administrational needs of hospitals
# https://openalex.org/C556297831 - Information and Computer Science - field that emphasizes both computing and informatics

# %%
unaddressed_terms = []
count_unaddressed_terms = 0
list_syns_update = []

unreplaced_terms = []
count_unreplaced_terms = 0

for t in pd_agu_terms['term']:
    print('\n\nworking on term: {}'.format(t))
    
    # remove punctuation
    t_mod = t
    t_mod = t_mod.replace(',','')
    t_mod = t_mod.replace('.','')
    t_mod = t_mod.replace(':','')
    t_mod = t_mod.replace('/',' ')
    
    # First catch if this term already exists in the synonyms files and skip if it does
    if (any(t_mod in x for x in ADS_simple_syns)) | (any(t_mod in x for x in ADS_multi_syns)):
        print('...already exists in synonyms list')
        unreplaced_terms.append(t)
        count_unreplaced_terms += 1
        continue
    
    
    rv = openalex_get("/concepts", {"search": t_mod})
#     d=rv.json()
#     for r in d['results']:
#         print('{} - {} - {}'.format(r['id'], r['display_name'], r['description']))
    try:
        count, results = count_and_results(rv)
    except:
        print('problem with return for {}, continuing'.format(t_mod))
        

    if count:
#         print(count)
#         print(results)
        tmp = [r['display_name'] for r in results]
#         tmp.append(t)
        print(tmp)
#         list_syns_update.append('{} => {}'.format(', '.join(variations_synonyms),t))
        # Choosing the multi-term synonyms format for all entries
        list_syns_update.append('{}, {}'.format(', '.join(tmp),t))

    else:
        print('no matching concepts')
#         rv = openalex_get("/works", {"search": q})
#         count, results = count_and_results(rv)
#         print(count, 'matching works')
#         print(results)
        # append to a list of unaddressed terms
        unaddressed_terms.append(t)
        count_unaddressed_terms += 1
    print()
print('number of terms that do not exist in OpenAlex = {}'.format(count_unaddressed_terms))
# Out:
# working on term: informatics
# ...already exists in synonyms list
#
#
# working on term: community modeling frameworks
# no matching concepts
#
#
#
# working on term: community standards
# ['Community standards']
#
#
#
# working on term: computational models, algorithms
# ['PSQM']
#
#
#
# working on term: cyberinfrastructure
# ['Cyberinfrastructure']
#
#
#
# working on term: data assimilation, integration and fusion
# no matching concepts
#
#
#
# working on term: data management, preservation, rescue
# no matching concepts
#
#
#
# working on term: data mining
# ['Data mining', 'Lift (data mining)', 'Data stream mining', 'Educational data mining', 'Process mining', 'Biclustering', 'Semantic computing', 'Predictive analytics', 'Statistical arbitrage']
#
#
#
# working on term: data and information discovery
# no matching concepts
#
#
#
# working on term: decision analysis
# ['Decision analysis', 'Multiple-criteria decision analysis', 'Risk assessment', 'Dominance-based rough set approach', 'ELECTRE', 'Risk stratification', 'Weighted sum model', 'Cost–utility analysis']
#
#
#
# working on term: emerging informatics technologies
# no matching concepts
#
#
#
# working on term: forecasting
# ...already exists in synonyms list
#
#
# working on term: formal logics and grammars
# no matching concepts
#
#
#
# working on term: geospatial
# ['Geospatial analysis', 'Geospatial metadata', 'Geospatial PDF', 'Geovisualization', 'Mobile mapping', 'Data archive']
#
#
#
# working on term: gis science
# no matching concepts
#
#
#
# working on term: data and information governance
# no matching concepts
#
#
#
# working on term: high-performance computing
# ['Fabric computing']
#
#
#
# working on term: international collaboration
# no matching concepts
#
#
#
# working on term: interoperability
# ...already exists in synonyms list
#
#
# working on term: knowledge representation and knowledge bases
# no matching concepts
#
#
#
# working on term: machine-to-machine communication
# no matching concepts
#
#
#
# working on term: machine learning
# ['Machine learning', 'Margin (machine learning)', 'Boosting (machine learning)', 'Active learning (machine learning)', 'Online machine learning', 'Data mining', 'Artificial neural network', 'Adversarial machine learning', 'Deep learning', 'Semantic analysis (machine learning)', 'Extreme learning machine', 'Quantum machine learning', 'Feature selection', 'Reinforcement learning', 'Linear discriminant analysis', 'Deep neural networks', 'Training set', 'Unsupervised learning', 'Feature vector', 'Test set', 'Predictive modelling', 'Discriminant function analysis', 'Semi-supervised learning', 'Learning to rank', 'Gradient boosting', 'Random subspace method', 'Statistical learning theory', 'Domain adaptation', 'Decision tree learning', 'Feature learning', 'Ensemble learning', 'Supervised learning', 'Linear classifier', 'Conditional random field', 'Probably approximately correct learning', 'Multi-task learning', 'Generalization error', 'Conceptual clustering', 'Q-learning', 'Computational learning theory', 'Meta learning (computer science)', 'Tree kernel', 'Feature engineering', 'Large margin nearest neighbor', 'Bootstrap aggregating', 'Co-training', 'Learning with errors', 'Structured prediction', 'Inductive bias', 'Data discovery', 'Decision engineering', 'Multiple kernel learning', 'Intelligent control', 'Inductive transfer', 'Error-driven learning', 'Pattern analysis', 'Predictive analytics', 'Early stopping', 'Multimodal learning', 'Pattern detection', 'Similarity learning']
#
#
#
# working on term: markup languages
# ['XML', 'XPDL', 'SGML', 'RDF/XML', 'XML validation', 'XHTML', 'Document type definition', 'XACML', 'HTML', 'HTML5', 'HTML element']
#
#
#
# working on term: metadata
# ['Metadata', 'Metadata repository', 'Metadata modeling', 'Geospatial metadata', 'Metadata management', 'Annotation', 'Payload (computing)', 'Java annotation', 'Automatic image annotation', 'ID3', 'Semantic annotation', 'Calais', 'Data dictionary']
#
#
#
# working on term: metadata: provenance
# no matching concepts
#
#
#
# working on term: metadata: quality
# no matching concepts
#
#
#
# working on term: modeling
# ...already exists in synonyms list
#
#
# working on term: natural language processing
# ['Natural language processing', 'Sentiment analysis', 'Latent semantic analysis', 'Parsing', 'Word embedding', 'Natural language understanding', 'Tree kernel', 'Lemmatisation', 'Semantic computing', 'Word-sense disambiguation', 'Language understanding', 'Stop words', 'Computational semantics']
#
#
#
# working on term: numerical algorithms
# ['Monte Carlo method', 'Numerical analysis', 'Evolutionary programming', 'Numerical approximation']
#
#
#
# working on term: ontologies
# ...already exists in synonyms list
#
#
# working on term: portals and user interfaces
# no matching concepts
#
#
#
# working on term: query languages for science, markup languages, ontologies
# no matching concepts
#
#
#
# working on term: real-time and responsive information delivery
# no matching concepts
#
#
#
# working on term: rules and logic
# ['Resolution (logic)', 'Transposition (logic)', 'Semantic Web Rule Language']
#
#
#
# working on term: scientific reasoning/inference
# no matching concepts
#
#
#
# working on term: semantic web and semantic integration
# no matching concepts
#
#
#
# working on term: sensor web
# ['Sensor web']
#
#
#
# working on term: social networks
# ['Social support', 'Virtual community', 'Social network analysis', 'Viral marketing', 'Interactive Learning', 'Mobile social network', 'Network society', 'Computer monitoring']
#
#
#
# working on term: software tools and services
# no matching concepts
#
#
#
# working on term: software re-use
# no matching concepts
#
#
#
# working on term: spatial analysis and representation
# no matching concepts
#
#
#
# working on term: standards
# ...already exists in synonyms list
#
#
# working on term: statistical methods: descriptive
# no matching concepts
#
#
#
# working on term: statistical methods: inferential
# no matching concepts
#
#
#
# working on term: temporal analysis and representation
# no matching concepts
#
#
#
# working on term: uncertainty
# ...already exists in synonyms list
#
#
# working on term: virtual globes
# no matching concepts
#
#
#
# working on term: visualization and portrayal
# no matching concepts
#
#
#
# working on term: web services
# ['Devices Profile for Web Services', 'OWL-S', 'WS-I Basic Profile', 'Web service', 'Massive open online course', 'Calais', 'Web intelligence', 'Internet shopping']
#
#
#
# working on term: workflow
# ...already exists in synonyms list
#
#
# working on term: interplanetary physics
# no matching concepts
#
#
#
# working on term: coronal mass ejections
# ['Forbush decrease']
#
#
#
# working on term: corotating streams
# no matching concepts
#
#
#
# working on term: cosmic rays
# ...already exists in synonyms list
#
#
# working on term: discontinuities
# ...already exists in synonyms list
#
#
# working on term: ejecta, driver gases, and magnetic clouds
# no matching concepts
#
#
#
# working on term: energetic particles
# ['Solar energetic particles', 'Sputtering', 'Van Allen radiation belt', 'Collision cascade', 'Spacecraft charging']
#
#
#
# working on term: heliopause and solar wind termination
# no matching concepts
#
#
#
# working on term: heliosphere/interstellar medium interactions
# no matching concepts
#
#
#
# working on term: interplanetary dust
# ...already exists in synonyms list
#
#
# working on term: interplanetary magnetic fields
# no matching concepts
#
#
#
# working on term: interplanetary shocks
# no matching concepts
#
#
#
# working on term: interstellar gas
# ...already exists in synonyms list
#
#
# working on term: mhd waves and turbulence
# no matching concepts
#
#
#
# working on term: neutral particles
# ['Particle beam', 'Electron neutrino', 'Muon neutrino', 'Exotic atom', 'Tau neutrino']
#
#
#
# working on term: pickup ions
# no matching concepts
#
#
#
# working on term: planetary bow shocks
# problem with return for planetary bow shocks, continuing
# no matching concepts
#
#
#
# working on term: plasma waves and turbulence
# no matching concepts
#
#
#
# working on term: solar cycle variations
# no matching concepts
#
#
#
# working on term: solar wind plasma
# no matching concepts
#
#
#
# working on term: solar wind sources
# no matching concepts
#
#
#
# working on term: instruments and techniques
# no matching concepts
#
#
#
# working on term: ionosphere
# ...already exists in synonyms list
#
#
# working on term: active experiments
# no matching concepts
#
#
#
# working on term: auroral ionosphere
# no matching concepts
#
#
#
# working on term: current systems
# ['Ocean gyre', 'Classification of mental disorders', 'Psychiatric diagnosis', 'Magnetostatics', 'Z-pinch', 'Ampacity', 'Lightning arrester', 'State function', 'Prospective short circuit current']
#
#
#
# working on term: electric fields
# ['Capacitor', 'Permittivity', 'Field-effect transistor', 'Polarizability', 'Excitation', 'Magnetic field', 'Electron mobility', 'Electroluminescence', 'Dielectrophoresis', 'Stark effect', 'Kerr effect', 'Linear polarization', 'Faraday cage', 'Dielectric function', 'Electric charge', 'Electric field gradient', 'Pyroelectricity', 'Electric potential', 'Dielectric permittivity', 'Drift velocity', 'Electric fish', 'Electrical mobility', 'Ion trap', 'Electroreception', 'Aharonov–Bohm effect', "Maxwell's equations", 'Pockels effect', 'Electro-optic effect', 'Crystal field theory', 'Screening effect', 'Pyroelectric crystal', 'Kerr nonlinearity', 'Gaussian surface', 'Townsend discharge', 'Electromagnet', 'Electron avalanche', 'Vacuum permittivity', 'Doubly fed electric machine', 'Evanescent wave', 'Drift current', 'Wireless power transfer', 'Optical coupling']
#
#
#
# working on term: equatorial ionosphere
# no matching concepts
#
#
#
# working on term: ion chemistry and composition
# no matching concepts
#
#
#
# working on term: ionization processes
# ['Penning ionization', 'Iontophoresis', 'Thermal ionization', 'Electron avalanche']
#
#
#
# working on term: ionosphere/atmosphere interactions
# no matching concepts
#
#
#
# working on term: ionosphere/magnetosphere interactions
# no matching concepts
#
#
#
# working on term: ionospheric disturbances
# no matching concepts
#
#
#
# working on term: ionospheric dynamics
# no matching concepts
#
#
#
# working on term: ionospheric irregularities
# no matching concepts
#
#
#
# working on term: ionospheric storms
# no matching concepts
#
#
#
# working on term: meteor-trail physics
# no matching concepts
#
#
#
# working on term: midlatitude ionosphere
# no matching concepts
#
#
#
# working on term: modeling and forecasting
# ['Mode choice', 'Global Forecast System', 'Trip distribution']
#
#
#
# working on term: particle acceleration
# ['Particle acceleration', 'Plasma acceleration', 'Fermi acceleration']
#
#
#
# working on term: particle precipitation
# ['Concretion', 'Global climate']
#
#
#
# working on term: planetary ionospheres
# no matching concepts
#
#
#
# working on term: plasma interactions with dust and aerosols
# no matching concepts
#
#
#
# working on term: plasma convection
# no matching concepts
#
#
#
# working on term: plasma temperature and density
# no matching concepts
#
#
#
# working on term: plasma waves and instabilities
# no matching concepts
#
#
#
# working on term: polar cap ionosphere
# no matching concepts
#
#
#
# working on term: solar radiation and cosmic ray effects
# no matching concepts
#
#
#
# working on term: topside ionosphere
# problem with return for topside ionosphere, continuing
# no matching concepts
#
#
#
# working on term: wave/particle interactions
# no matching concepts
#
#
#
# working on term: wave propagation
# ['Wave propagation', 'Ground wave propagation', 'Longitudinal wave', 'Shear waves', 'Helioseismology', 'Electromagnetic electron wave', 'Underwater acoustics', 'Longitudinal field', 'Transverse wave', 'Line-of-sight propagation', 'Leaky wave antenna', 'Transverse vibration', 'Airy wave theory', 'Skywave', 'Ionospheric propagation', 'Ionospheric reflection']
#
#
#
# working on term: instruments and techniques
# no matching concepts
#
#
#
# working on term: magnetospheric physics
# no matching concepts
#
#
#
# working on term: auroral phenomena
# no matching concepts
#
#
#
# working on term: cusp
# ...already exists in synonyms list
#
#
# working on term: electric fields
# ['Capacitor', 'Permittivity', 'Field-effect transistor', 'Polarizability', 'Excitation', 'Magnetic field', 'Electron mobility', 'Electroluminescence', 'Dielectrophoresis', 'Stark effect', 'Kerr effect', 'Linear polarization', 'Faraday cage', 'Dielectric function', 'Electric charge', 'Electric field gradient', 'Pyroelectricity', 'Electric potential', 'Dielectric permittivity', 'Drift velocity', 'Electric fish', 'Electrical mobility', 'Ion trap', 'Electroreception', 'Aharonov–Bohm effect', "Maxwell's equations", 'Pockels effect', 'Electro-optic effect', 'Crystal field theory', 'Screening effect', 'Pyroelectric crystal', 'Kerr nonlinearity', 'Gaussian surface', 'Townsend discharge', 'Electromagnet', 'Electron avalanche', 'Vacuum permittivity', 'Doubly fed electric machine', 'Evanescent wave', 'Drift current', 'Wireless power transfer', 'Optical coupling']
#
#
#
# working on term: energetic particles: precipitating
# no matching concepts
#
#
#
# working on term: energetic particles: trapped
# no matching concepts
#
#
#
# working on term: field-aligned currents and current systems
# no matching concepts
#
#
#
# working on term: forecasting
# ...already exists in synonyms list
#
#
# working on term: magnetic reconnection
# ['Magnetic reconnection']
#
#
#
# working on term: magnetopause and boundary layers
# no matching concepts
#
#
#
# working on term: magnetosheath
# ...already exists in synonyms list
#
#
# working on term: magnetosphere: inner
# no matching concepts
#
#
#
# working on term: magnetosphere: outer
# no matching concepts
#
#
#
# working on term: magnetosphere interactions with satellites and rings
# no matching concepts
#
#
#
# working on term: magnetosphere/ionosphere interactions
# no matching concepts
#
#
#
# working on term: magnetospheric configuration and dynamics
# no matching concepts
#
#
#
# working on term: magnetotail
# ...already exists in synonyms list
#
#
# working on term: magnetotail boundary layers
# no matching concepts
#
#
#
# working on term: mhd waves and instabilities
# no matching concepts
#
#
#
# working on term: numerical modeling
# ['Numerical modeling', 'Data assimilation', 'Chemical transport model', 'North American Mesoscale Model', 'Unified Model', 'Mathematical software']
#
#
#
# working on term: planetary magnetospheres
# no matching concepts
#
#
#
# working on term: plasma convection
# no matching concepts
#
#
#
# working on term: plasma sheet
# ['Plasma sheet']
#
#
#
# working on term: plasmasphere
# ...already exists in synonyms list
#
#
# working on term: plasma waves and instabilities
# no matching concepts
#
#
#
# working on term: polar cap phenomena
# no matching concepts
#
#
#
# working on term: radiation belts
# ...already exists in synonyms list
#
#
# working on term: ring current
# ['Ring current']
#
#
#
# working on term: solar wind interactions with unmagnetized bodies
# no matching concepts
#
#
#
# working on term: solar wind/magnetosphere interactions
# no matching concepts
#
#
#
# working on term: magnetic storms and substorms
# no matching concepts
#
#
#
# working on term: substorms
# ...already exists in synonyms list
#
#
# working on term: instruments and techniques
# no matching concepts
#
#
#
# working on term: mathematical geophysics
# problem with return for mathematical geophysics, continuing
# no matching concepts
#
#
#
# working on term: fourier analysis
# ['Fourier analysis', 'Discrete-time Fourier transform', 'Noncommutative harmonic analysis']
#
#
#
# working on term: instability analysis
# no matching concepts
#
#
#
# working on term: inverse theory
# ['Inverse theory', 'S-duality', 'T-duality']
#
#
#
# working on term: numerical approximations and analysis
# ['Numerical analysis', 'Numerical approximation']
#
#
#
# working on term: persistence, memory, correlations, clustering
# no matching concepts
#
#
#
# working on term: prediction
# ...already exists in synonyms list
#
#
# working on term: probabilistic forecasting
# ['Probabilistic forecasting']
#
#
#
# working on term: spatial analysis
# ['Spatial analysis', 'Empirical orthogonal functions', 'Space syntax']
#
#
#
# working on term: spectral analysis
# ['Spectral analysis', 'Hilbert spectral analysis', 'Spectral shape analysis']
#
#
#
# working on term: stochastic processes
# ['Unit root', 'Stochastic differential equation', 'Preferential attachment', 'Lévy process', 'Stochastic calculus', 'Markov property', 'Jump process', 'Wiener process', 'Semimartingale', 'Geometric Brownian motion', 'Voter model', 'Colors of noise', 'Mean reversion', 'Ornstein–Uhlenbeck process', 'Continuous-time Markov chain', 'Brownian bridge', 'Stochastic integral', 'Quadratic variation', 'Stationary process', 'Local martingale', 'Interacting particle system', 'Stopping time', 'Noise spectrum', 'Continuous-time stochastic process', 'Stopping rule']
#
#
#
# working on term: time series analysis
# ['Interrupted Time Series Analysis', 'Autoregressive integrated moving average', 'Autoregressive–moving-average model', 'Marketing mix modeling']
#
#
#
# working on term: uncertainty quantification
# ['Uncertainty quantification', 'Uncertainty analysis']
#
#
#
# working on term: wavelet transform
# ['Wavelet transform', 'Discrete wavelet transform', 'Stationary wavelet transform', 'Second-generation wavelet transform', 'Harmonic wavelet transform', 'Continuous wavelet transform', 'Fast wavelet transform', 'Complex wavelet transform', 'Multiresolution analysis']
#
#
#
# working on term: wave propagation
# ['Wave propagation', 'Ground wave propagation', 'Longitudinal wave', 'Shear waves', 'Helioseismology', 'Electromagnetic electron wave', 'Underwater acoustics', 'Longitudinal field', 'Transverse wave', 'Line-of-sight propagation', 'Leaky wave antenna', 'Transverse vibration', 'Airy wave theory', 'Skywave', 'Ionospheric propagation', 'Ionospheric reflection']
#
#
#
# working on term: instruments and techniques
# no matching concepts
#
#
#
# working on term: natural hazards
# ['Social vulnerability', 'Protection forest']
#
#
#
# working on term: atmospheric
# ...already exists in synonyms list
#
#
# working on term: geological
# ...already exists in synonyms list
#
#
# working on term: hydrological
# ...already exists in synonyms list
#
#
# working on term: oceanic
# ...already exists in synonyms list
#
#
# working on term: space weather
# ['Space weather', 'Geomagnetically induced current']
#
#
#
# working on term: multihazards
# no matching concepts
#
#
#
# working on term: methods
# ['Decoding methods', 'Ab initio quantum chemistry methods', 'Lattice Boltzmann methods', 'Taguchi methods', 'Formal methods', 'Domain decomposition methods', 'Constructivist teaching methods', 'Runge–Kutta methods', 'Phylogenetic comparative methods', 'Design methods', 'Evaluation methods', 'Suicide methods', 'Meshfree methods', 'Biophysics', 'Behavior change methods', 'Direct methods', 'Cooking methods', 'Computational biology', 'Observational methods in psychology', 'Proximal Gradient Methods', 'Combinatorial chemistry', 'Protein methods', 'Visual methods', 'Numerical methods for ordinary differential equations', 'Nucleic acid methods', 'Online research methods', 'Mortar methods', 'Meta-analysis', 'Methods of contour integration', 'High-performance liquid chromatography', 'Finite element method', 'Matching (statistics)', 'Data mining', 'Randomized controlled trial', 'Molecular dynamics', 'Electroencephalography', 'Compensation methods', 'H-infinity methods in control theory', 'Matrix-free methods', 'Proximal gradient methods for learning', 'Medical physics', 'Recombinant DNA', 'Explicit and implicit methods', 'Qualitative research', 'Operations research', 'Density functional theory', 'Gel electrophoresis', 'Statistical hypothesis testing', 'Support vector machine', 'Drug delivery', 'Interpolation (computer graphics)', 'clone (Java method)', 'Restriction fragment length polymorphism', 'Monte Carlo methods for option pricing', 'Actuarial science', 'Planar', 'Ranking (information retrieval)', 'Conceptual framework', 'Climate model', 'Protocol (science)', 'Systematic review', 'Least-squares function approximation', 'Heuristic', 'Interferometry', 'Inoculation', 'Hydrogen production', 'Diffusion MRI', 'Finite difference methods for option pricing', 'Gas chromatography–mass spectrometry', 'Polymerase chain reaction', 'Electrospray ionization', 'Mechanical ventilation', 'Enzyme assay', 'CLARITY', 'Titration', 'Life-cycle assessment', 'Heuristics', 'Computer architecture', 'Phylogenetics', 'Thermogravimetric analysis', 'Thematic analysis', 'Tissue engineering', 'Linear programming', 'Oxidase test', 'Teaching method', 'Capillary electrophoresis', 'Spatial variability', 'Phenomenology (philosophy)', 'Optimal control', 'Dynamic programming', 'Voltammetry', 'Powder diffraction', 'Linear discriminant analysis', 'Library science', 'Indole test', 'Homogenization (climate)', 'Near-infrared spectroscopy', 'Maximum likelihood', 'Organocatalysis', 'Exploratory factor analysis', 'Model predictive control', 'Leadership style', 'Voting', 'Coupled cluster', 'Biological pest control', 'Ordination', 'Molecular beam epitaxy', 'Kriging', 'Photovoltaics', 'Delphi method', 'Size-exclusion chromatography', 'Facilitation', 'Sputter deposition', 'Content analysis', 'Grazing', 'Substance abuse', 'Comparative genomic hybridization', 'Bioassay', 'Alignment-free sequence analysis', 'Atomic absorption spectroscopy', 'Residual', 'Real-time polymerase chain reaction', 'Sliding mode control', 'Dialectic', 'Gene mapping', 'Glucose clamp technique', 'Sanger sequencing', 'Hydrogen storage', 'Galerkin method', 'Boundary element method', 'Calibration curve', 'Service management', 'Overlay', 'Independent component analysis', 'Philosophy of science', 'Electrocardiography', 'Bilinear interpolation', 'Commercialization', 'Finite volume method', 'Research design', 'Edge detection', 'Recursion (computer science)', 'Iterative method', 'Traverse', 'Automatic summarization', 'Design of experiments', 'Multiplexing', 'Biodistribution', 'Resampling', 'Bradford protein assay', 'Antioxidant capacity', 'Participant observation', 'Debye model', 'Metalorganic vapour phase epitaxy', 'Dropout (neural networks)', 'Distillation', 'Ordinary least squares', 'Homology modeling', 'Neural coding', 'Skew', 'Lagrange multiplier', 'PET-CT', 'Vector autoregression', 'Bayesian inference', 'Big data', 'Renormalization group', 'Stepwise regression', 'Ground-penetrating radar', 'Tabu search', 'Selected  ...
#
#
#
# working on term: other
# ...already exists in synonyms list
#
#
# working on term: analogue modeling
# no matching concepts
#
#
#
# working on term: catastrophe and catastrophe theory
# no matching concepts
#
#
#
# working on term: extreme events
# no matching concepts
#
#
#
# working on term: mathematical and computer modeling
# ['Computational science', 'Bézier surface']
#
#
#
# working on term: monitoring, forecasting, prediction
# no matching concepts
#
#
#
# working on term: physical modeling
# ['Fermi gas', 'Semiclassical physics', 'Molecular model', 'Signal processing', 'Directed percolation', 'Technicolor', 'Computer simulation', 'Negative mass', 'Polarizable continuum model', 'Ocean general circulation model', 'S-matrix theory', 'Statistical signal processing', 'Modeling and simulation', 'Test bench', 'Particle in a box', 'Cloud storage', 'Non-standard cosmology', 'Nearly free electron model', 'Bohr radius', 'Numerical modeling', 'Numerical models', 'Computer modelling', 'Computational simulation', 'N = 4 supersymmetric Yang–Mills theory', 'Deterministic system (philosophy)', 'Two-dimensional space']
#
#
#
# working on term: precursors
# ...already exists in synonyms list
#
#
# working on term: statistical analysis
# ['Statistical analysis', 'Confirmatory factor analysis', 'Statistical energy analysis', 'Bibliometrics', 'Change detection', 'Stepwise regression', 'Bayesian linear regression', 'Autoregressive integrated moving average', 'Empirical orthogonal functions', 'Autoregressive–moving-average model', 'Confidence and prediction bands', 'Population mean', 'Exponential random graph models', 'Procrustes analysis', 'Marketing mix modeling', 'Statistical population', 'Incremental cost-effectiveness ratio']
#
#
#
# working on term: spatial modeling
# no matching concepts
#
#
#
# working on term: climate impact
# ['Sustainable transport']
#
#
#
# working on term: health impact
# ['Health impact assessment', 'Environmental health', 'Pandemic', 'Disease burden', 'Burden of disease', 'Environmental epidemiology', 'Spiritual Health', 'Nutritionist']
#
#
#
# working on term: human impact
# ['Environmental health', 'Coral reef protection', 'Environmental epidemiology']
#
#
#
# working on term: spatial decision support systems
# no matching concepts
#
#
#
# working on term: megacities and urban environment
# no matching concepts
#
#
#
# working on term: exposure
# ...already exists in synonyms list
#
#
# working on term: resilience
# ...already exists in synonyms list
#
#
# working on term: risk
# ...already exists in synonyms list
#
#
# working on term: sustainable development
# ['Sustainable development', 'Education for sustainable development', 'Social sustainability', 'Water conservation', 'Sustainable forest management', 'Sustainable regional development', 'Eco-efficiency', 'State-building', 'Water saving', 'Harmony with nature']
#
#
#
# working on term: vulnerability
# ...already exists in synonyms list
#
#
# working on term: disaster relief
# no matching concepts
#
#
#
# working on term: disaster resilience
# no matching concepts
#
#
#
# working on term: disaster risk analysis and assessment
# no matching concepts
#
#
#
# working on term: disaster risk communication
# no matching concepts
#
#
#
# working on term: disaster management
# no matching concepts
#
#
#
# working on term: economic impacts of disasters
# no matching concepts
#
#
#
# working on term: remote sensing and disasters
# problem with return for remote sensing and disasters, continuing
# no matching concepts
#
#
#
# working on term: disaster policy
# ['Disaster recovery', 'IT service continuity']
#
#
#
# working on term: disaster mitigation
# ['Disaster mitigation']
#
#
#
# working on term: early warning systems
# ['Red Color']
#
#
#
# working on term: emergency management
# ['Emergency management']
#
#
#
# working on term: preparedness and planning
# no matching concepts
#
#
#
# working on term: microzonation and macrozonation
# no matching concepts
#
#
#
# working on term: community management
# ['Community management', 'Community-based management', 'Participatory planning']
#
#
#
# working on term: emergency response and evacuations
# no matching concepts
#
#
#
# working on term: recovery and reconstruction after disaster
# no matching concepts
#
#
#
# working on term: contingency planning
# no matching concepts
#
#
#
# working on term: international organizations and natural disasters
# problem with return for international organizations and natural disasters, continuing
# no matching concepts
#
#
#
# working on term: interaction between science and disaster management authorities
# no matching concepts
#
#
#
# working on term: sociology of disasters
# no matching concepts
#
#
#
# working on term: psychology of disasters
# no matching concepts
#
#
#
# working on term: miscellaneous
# ...already exists in synonyms list
#
#
# working on term: radio science
# ['Radio Science']
#
#
#
# working on term: electromagnetic noise and interference
# no matching concepts
#
#
#
# working on term: interferometry
# ...already exists in synonyms list
#
#
# working on term: ionospheric physics
# no matching concepts
#
#
#
# working on term: ionospheric propagation
# ['Ionospheric propagation', 'Skywave', 'Ionospheric reflection']
#
#
#
# working on term: magnetospheric physics
# no matching concepts
#
#
#
# working on term: nonlinear phenomena
# no matching concepts
#
#
#
# working on term: radar astronomy
# no matching concepts
#
#
#
# working on term: radar atmospheric physics
# problem with return for radar atmospheric physics, continuing
# no matching concepts
#
#
#
# working on term: radio astronomy
# ...already exists in synonyms list
#
#
# working on term: radio oceanography
# no matching concepts
#
#
#
# working on term: radio wave propagation
# ['Skywave', 'Ionospheric propagation', 'Ionospheric reflection']
#
#
#
# working on term: remote sensing
# ['Remote sensing', 'Collocation (remote sensing)', 'Remote sensing application', 'Earth remote sensing', 'Interferometric synthetic aperture radar', 'Radio occultation', 'Pyrometer', 'Earth observation']
#
#
#
# working on term: signal processing
# ['Energy (signal processing)', 'Sampling (signal processing)', 'Filter (signal processing)', 'Signal processing', 'Quantization (signal processing)', 'Digital signal processing', 'Multidimensional signal processing', 'Audio signal processing', 'Statistical signal processing', 'Analog signal processing', 'Sonar signal processing', 'Radar signal processing', 'Signal transduction', 'Transmission (telecommunications)', 'Distortion (music)', 'Independent component analysis', 'Beamforming', 'Vector quantization', 'Time–frequency analysis', 'Finite impulse response', 'Compressed sensing', 'Particle filter', 'Phaser', 'Multiplicative noise', 'Signal reconstruction', 'Instantaneous phase', 'Noise reduction', 'Linear predictive coding', 'Zero-forcing precoding', 'Digital signal processor', 'Speech processing', 'Window function', 'Periodogram', 'Phase unwrapping', 'Elliptic filter', 'Modified discrete cosine transform', 'Emphasis (telecommunications)', 'Signal averaging', 'Quorum sensing', 'Exciter', 'Spectral leakage', 'Equalization (audio)', 'Comb filter', 'Blind equalization', 'Demodulation', 'Signalling pathways', 'Analogue filter', 'Butterworth filter', 'Decorrelation', 'Array processing', 'Ringing artifacts', 'Oversampling', 'FDOA', 'Colors of noise', 'Image denoising', 'Gene rearrangement', 'Decimation', 'Dynamic range compression', 'Undersampling', 'Video denoising', 'Data stream', 'Interrupt', 'Apoptosome', 'Digital television', 'Preamplifier', 'Mechanical filter', 'Bilinear transform', 'Input device', 'V(D)J recombination', 'Noise spectrum', 'Image processor', 'Superheterodyne receiver', 'Video capture', 'Quorum Quenching', 'Signal pathway', 'Homomorphic filtering']
#
#
#
# working on term: space and satellite communication
# no matching concepts
#
#
#
# working on term: tomography and imaging
# ['Gated SPECT']
#
#
#
# working on term: waves in plasma
# ['Landau damping', 'Baryon acoustic oscillations']
#
#
#
# working on term: instruments and techniques
# no matching concepts
#
#
#
# working on term: solar physics, astrophysics, and astronomy
# no matching concepts
#
#
#
# working on term: celestial mechanics
# ['Celestial mechanics']
#
#
#
# working on term: chromosphere
# ...already exists in synonyms list
#
#
# working on term: corona
# ...already exists in synonyms list
#
#
# working on term: coronal holes
# no matching concepts
#
#
#
# working on term: coronal mass ejections
# ['Forbush decrease']
#
#
#
# working on term: energetic particles
# ['Solar energetic particles', 'Sputtering', 'Van Allen radiation belt', 'Collision cascade', 'Spacecraft charging']
#
#
#
# working on term: flares
# ...already exists in synonyms list
#
#
# working on term: helioseismology
# ...already exists in synonyms list
#
#
# working on term: magnetic fields
# ...already exists in synonyms list
#
#
# working on term: magnetic reconnection
# ['Magnetic reconnection']
#
#
#
# working on term: photosphere
# ...already exists in synonyms list
#
#
# working on term: prominence eruptions
# no matching concepts
#
#
#
# working on term: radio emissions
# ['Radar jamming and deception']
#
#
#
# working on term: solar activity cycle
# ...already exists in synonyms list
#
#
# working on term: solar and stellar variability
# no matching concepts
#
#
#
# working on term: solar irradiance
# ['Solar irradiance']
#
#
#
# working on term: stellar astronomy
# no matching concepts
#
#
#
# working on term: stellar interiors and dynamo theory
# no matching concepts
#
#
#
# working on term: transition region
# ['Coronal loop', 'Chromosphere', 'Demographic transition']
#
#
#
# working on term: ultraviolet emissions
# no matching concepts
#
#
#
# working on term: x-rays, gamma rays, and neutrinos
# no matching concepts
#
#
#
# working on term: instruments and techniques
# no matching concepts
#
#
#
# working on term: space plasma physics
# no matching concepts
#
#
#
# working on term: active perturbation experiments
# no matching concepts
#
#
#
# working on term: chaos
# ...already exists in synonyms list
#
#
# working on term: charged particle motion and acceleration
# no matching concepts
#
#
#
# working on term: discontinuities
# ...already exists in synonyms list
#
#
# working on term: electrostatic structures
# no matching concepts
#
#
#
# working on term: ionization processes
# ['Penning ionization', 'Iontophoresis', 'Thermal ionization', 'Electron avalanche']
#
#
#
# working on term: kinetic and mhd theory
# no matching concepts
#
#
#
# working on term: kinetic waves and instabilities
# no matching concepts
#
#
#
# working on term: laboratory studies and experimental techniques
# no matching concepts
#
#
#
# working on term: magnetic reconnection
# ['Magnetic reconnection']
#
#
#
# working on term: mathematical and numerical techniques
# no matching concepts
#
#
#
# working on term: mhd waves and instabilities
# no matching concepts
#
#
#
# working on term: neutral particles
# problem with return for neutral particles, continuing
# no matching concepts
#
#
#
# working on term: nonlinear phenomena
# no matching concepts
#
#
#
# working on term: parametric processes
# no matching concepts
#
#
#
# working on term: particle acceleration
# ['Particle acceleration', 'Plasma acceleration', 'Fermi acceleration']
#
#
#
# working on term: plasma energization
# no matching concepts
#
#
#
# working on term: plasma interactions with dust and aerosols
# no matching concepts
#
#
#
# working on term: radiation processes
# ['Enterocolitis', 'Radioactive decay', 'Neutron activation', 'Neutron irradiation', 'Mutation breeding']
#
#
#
# working on term: shock waves
# ['Shock waves in astrophysics', 'Shock metamorphism']
#
#
#
# working on term: solitons and solitary waves
# no matching concepts
#
#
#
# working on term: spacecraft/atmosphere interactions
# no matching concepts
#
#
#
# working on term: spacecraft sheaths, wakes, charging
# no matching concepts
#
#
#
# working on term: stochastic phenomena
# no matching concepts
#
#
#
# working on term: transport processes
# ['Endocytosis', 'Endocytic cycle', 'Bone resorption', 'Erosion', 'Swallowing', 'Exocytosis', 'Logging', 'Traction (geology)', 'Membrane technology', 'Beta oxidation', 'Ribosome biogenesis', 'Receptor-mediated endocytosis', 'Soil loss', 'Twin-arginine translocation pathway', 'Membrane filter', 'Water erosion', 'International shipping']
#
#
#
# working on term: turbulence
# ...already exists in synonyms list
#
#
# working on term: wave/particle interactions
# no matching concepts
#
#
#
# working on term: wave/wave interactions
# ['Underwater acoustics', 'Wind wave model']
#
#
#
# working on term: instruments and techniques
# no matching concepts
#
# number of terms that do not exist in OpenAlex = 150

# %%
# for t2 in unaddressed_terms:
#     print('\n{}'.format(t2))
for t3 in unreplaced_terms:
    print('\n{}'.format(t3))
# Out:
# informatics
#
# forecasting
#
# interoperability
#
# modeling
#
# ontologies
#
# standards
#
# uncertainty
#
# workflow
#
# cosmic rays
#
# discontinuities
#
# interplanetary dust
#
# interstellar gas
#
# ionosphere
#
# cusp
#
# forecasting
#
# magnetosheath
#
# magnetotail
#
# plasmasphere
#
# radiation belts
#
# substorms
#
# prediction
#
# atmospheric
#
# geological
#
# hydrological
#
# oceanic
#
# other
#
# precursors
#
# exposure
#
# resilience
#
# risk
#
# vulnerability
#
# miscellaneous
#
# interferometry
#
# radio astronomy
#
# chromosphere
#
# corona
#
# flares
#
# helioseismology
#
# magnetic fields
#
# photosphere
#
# solar activity cycle
#
# chaos
#
# discontinuities
#
# turbulence

# %% [markdown]
# #### Add acronyms to the bottom of the file that will be added to ADS synonyms file

# %%
list_syns_update.append('\n\n# acronyms added from Heliophysics 2013 Decadal survey in August 2022')

for l in range(len(pd_acronyms)):
    flag = 0
    # Check if the acronym already exists in ADS file
    for i,s in enumerate(extracted_acronyms):
        if pd_acronyms['acronyms'][l] == s:
            print('Helio acronym: {}; ADS acronym: {}'.format(pd_acronyms['acronyms'][l],extracted_acronyms[i]))
            flag = 1
            break
        
    if flag == 0:     
        txt_tmp = '{},{}'.format(pd_acronyms['acronyms'][l],pd_acronyms['terms'][l].lower())

        list_syns_update.append(txt_tmp)
        print('added...{}'.format(list_syns_update[-1]))
# Out:
# Helio acronym: AAS; ADS acronym: AAS
# Helio acronym: ACE; ADS acronym: ACE
# added...ACR,anomalous cosmic ray
# added...AFOSR,air force office of scientific research
# added...AFRL,air force research laboratory
# added...AFWA,air force weather agency
# added...AGS,atmospheric and geospace sciences division
# Helio acronym: AGU; ADS acronym: AGU
# added...AIA,atmospheric imaging assembly
# Helio acronym: AIM; ADS acronym: AIM
# added...AIMI,atmosphere ionosphere magnetosphere interactions
# added...AIP,american institute of physics
# added...AMISR,advanced modular incoherent scatter radar
# added...AMPERE,active magnetosphere and planetary electrodynamics response experiment
# added...AMPTE,active magnetospheric particle tracer explorers
# added...AO,announcement of opportunity
# added...APS,american physical society; active pixel sensor
# added...AST,division of astronomical sciences
# added...ATST,advanced technology solar telescope
# added...AU,astronomical unit
# Helio acronym: AURA; ADS acronym: AURA
# Helio acronym: AXAF; ADS acronym: AXAF
# added...BARREL,balloon array for rbsp relativistic electron losses
# added...BBSO,big bear solar observatory
# added...CADRE,cubesat investigating atmospheric density response to extreme driving
# added...CAREER,faculty early career development
# added...CASSIOPE,cascade small satellite and ionospheric polar explorer
# added...CATE,cost and technical evaluation
# added...CAWSES,climate and weather of the sun earth system
# Helio acronym: CCD; ADS acronym: CCD
# added...CCE,charge composition explorer
# added...CCMC,community coordinated modeling center
# added...CDC,concept design center
# added...CEDAR,coupling energetics and dynamics of atmospheric regions
# Helio acronym: CHAMP; ADS acronym: CHAMP
# added...CINDI,coupled ion neutral dynamic investigation
# added...CINEMA,cubesat for ions neutrals electrons magnetic fields
# added...CIR,corotating interaction region
# added...CISM,center for integrated space weather modeling
# Helio acronym: CME; ADS acronym: CME
# added...CMOS,complementary metal oxide semiconductor
# added...C/No,carrier signal to noise strength
# added...C/NOFS,communications/navigation outage forecasting system
# Helio acronym: COBE; ADS acronym: COBE
# added...CoBRA,complexity based risk assessment
# added...COSMIC,constellation observing system for meteorology ionosphere and climate
# added...COSMO,coronal solar magnetism observatory
# added...COTS,commercial off the shelf
# added...CPU,central processing unit
# added...CRRES,combined release and radiation effects satellite
# added...CSSWE,colorado student space weather experiment
# added...DASI,distributed array of small instruments
# added...DC,direct current
# added...DICE,dynamic ionosphere cubesat experiment
# added...DLR,german aerospace center
# added...DMSP,defense meteorological satellites program
# added...DOD,department of defense
# added...DOE,department of energy
# added...DRIVE,diversify realize integrate venture educate
# added...DSCOVR,deep space climate observatory
# added...DYNAMIC,dynamical neutral atmosphere ionosphere coupling (mission)
# added...EASCO,earth affecting solar causes observatory
# added...ECT,energetic particle composition and thermal plasma suite
# added...EIA,equatorial ionization anomaly
# added...EISCAT,european incoherent scatter scientific association
# added...ELaNa,educational launch of nanosatellites
# added...ENA,energetic neutral atom
# added...ENASI,energetic neutral atom spectroscopic imager
# added...EPO,education and public outreach
# added...e-POP,enhanced polar outflow probe
# Helio acronym: EPP; ADS acronym: EPP
# Helio acronym: ESA; ADS acronym: ESA
# added...ESCAPE,energetics sources and couplings of atmosphere plasma escape
# added...ETA,equatorial temperature anomaly
# Helio acronym: EUV; ADS acronym: EUV
# added...EUVI,extreme ultraviolet imager
# added...EVE,extreme ultraviolet variability experiment
# added...FAA,federal aviation administration
# added...FASR,frequency agile solar radiotelescope
# added...FAST,fast aurora snapshot
# added...FDSS,faculty development in space science
# added...FIREBIRD,focused investigations of relativistic electron burst intensity range and dynamics
# added...FOXSI,focusing optics x ray spectroscopic imager
# added...FUV,far ultraviolet
# Helio acronym: FWHM; ADS acronym: FWHM
# added...FY,fiscal year
# Helio acronym: GCR; ADS acronym: GCR
# added...GDC,geospace dynamics constellation
# Helio acronym: GEM; ADS acronym: GEM
# added...GEO,geostationary earth orbit
# added...GI,guest investigator
# added...GIC,geomagnetically induced current; ground induced current
# added...GNSS,global navigation satellite systems
# added...GOCE,gravity field and steady state ocean circulation explorer
# added...GOES,geostationary operational environmental satellite
# Helio acronym: GONG; ADS acronym: GONG
# Helio acronym: GPS; ADS acronym: GPS
# added...GRACE,gravity recovery and climate experiment
# added...GRIPS,gamma ray imager/polarimeter for solar flares
# added...GRIS,gamma ray imaging spectrometer
# Helio acronym: GSFC; ADS acronym: GSFC
# added...GSRP,graduate student research program
# added...GUVI,global ultraviolet imager
# added...GW,gravity waves
# added...HAARP,high frequency active auroral research program
# Helio acronym: HAO; ADS acronym: HAO
# Helio acronym: HEAO; ADS acronym: HEAO
# added...HEIDI,high energy imaging device
# added...HEO,high earth orbit (above geo)
# added...HF,high frequency
# added...HI,heliospheric imager
# added...HIREGS,high resolution gamma ray and hard x ray spectrometer
# added...HITDP,heliophysics instrument and technology development program
# added...HPDE,heliophysics data environment
# added...HSC,heliophysics science center
# added...HSO,heliophysics systems observatory
# added...HSS,high speed solar wind streams
# added...HSW,halo solar wind
# added...HTP,heliophysics theory program
# added...HXR,hard x ray
# added...IBEX,interstellar boundary explorer
# added...IGS,international gnss service
# Helio acronym: IGY; ADS acronym: IGY
# added...IHY,international heliophysical year
# added...IKAROS,interplanetary kite craft accelerated by radiation of the sun
# added...IMAGE,imager for magnetopause to aurora global exploration
# added...IMAP,interstellar mapping and acceleration probe
# Helio acronym: IMF; ADS acronym: IMF
# added...IMP,interplanetary monitoring platform
# Helio acronym: IMPACT; ADS acronym: IMPACT
# added...INCA,imaging neutral atom camera
# added...INMS,ion neutral mass spectrograph
# added...IR,infrared
# added...IRIS,interface region imaging spectrograph
# added...ISCCP,international satellite cloud climatology project
# Helio acronym: ISEE; ADS acronym: ISEE
# added...ISI,institute for scientific information
# Helio acronym: ISM; ADS acronym: ISM
# added...ISMF,interstellar magnetic field
# added...ISOON,improved solar observing optical network
# added...ISR,incoherent scatter radar
# added...ISS,international space station
# added...IT,ionosphere thermosphere
# added...ITAR,international traffic in arms regulations
# added...ITM,ionosphere thermosphere mesosphere
# added...IVM,ion velocity meter
# Helio acronym: JAXA; ADS acronym: JAXA
# Helio acronym: JPL; ADS acronym: JPL
# added...L1,sun earth lagrangian point 1
# added...L5,sun earth lagrangian point 5
# Helio acronym: LANL; ADS acronym: LANL
# added...LBH,lyman birge hopfield
# added...LCAS,low cost access to space
# added...LECP,low energy charged particle
# Helio acronym: LEO; ADS acronym: LEO
# added...LET,low energy telescope
# added...LISM,local interstellar medium
# Helio acronym: LPV; ADS acronym: LPV
# added...LT,local time
# added...LWS,living with a star
# Helio acronym: MAC; ADS acronym: MAC
# added...MagCat,magnetospheric constellation and tomography (mission)
# added...MagCon,magnetospheric constellation (mission)
# added...MEDICI,magnetosphere energetics dynamics and ionospheric coupling investigation
# added...MEMS,microelectromechanical system
# added...MESSENGER,mercury surface space environment geochemistry and ranging
# Helio acronym: MHD; ADS acronym: MHD
# added...MI,magnetosphere ionosphere
# added...MIDEX,mid size explorer
# added...MISTE,magnetosphere ionosphere source term energetics (mission)
# added...MIT,magnetosphere ionosphere thermosphere
# added...MLSO,mauna loa solar observatory
# added...MLT,mesosphere and lower thermosphere
# added...MMS,magnetospheric multiscale (mission)
# added...MO&DA,mission operations and data analysis
# added...MODIS,moderate resolution imaging spectroradiometer
# Helio acronym: MPS; ADS acronym: MPS
# added...MREFC,major research equipment and facilities construction (program)
# added...MRF,medium scale research facility
# added...MSO,mees solar observatory
# added...MWO,mt wilson observatory
# Helio acronym: NASA; ADS acronym: NASA
# added...NCAR,national center for atmospheric research
# added...NESDIS,national environmental satellite data and information service
# added...NESSF,nasa’s earth and space science fellowship (program)
# added...NGDC,national geophysical data center
# Helio acronym: NIST; ADS acronym: NIST
# added...NJIT,new jersey institute of technology
# Helio acronym: NOAA; ADS acronym: NOAA
# added...NRC,national research council
# Helio acronym: NSF; ADS acronym: NSF
# Helio acronym: NSO; ADS acronym: NSO
# added...NST,new solar telescope
# added...NSWP,national space weather program
# Helio acronym: NuSTAR; ADS acronym: NuSTAR
# added...NWM,neutral wind meter
# added...NWS,national weather service
# added...OCT,office of the chief technologist
# added...OEDG,opportunities for enhancing diversity in the geosciences (program)
# added...ORBITALS,outer radiation belt injection transport acceleration and loss satellite
# added...OVSA,owens valley solar array
# added...PARS,polar aeronomy and radio science
# added...PFISR,poker flat incoherent scatter radar
# added...PI,principal investigator
# added...POES,polar operational environmental satellite
# added...P-POD,poly picosatellite orbital deployer
# added...PUI,pickup ion
# added...PW,planetary waves
# Helio acronym: QBO; ADS acronym: QBO
# added...RE,earth radius
# added...RS,sun radius
# added...R&A,research and analysis
# added...RAX,radio aurora explorer
# added...RBSP,radiation belt storm probe; renamed van allen probes
# added...REPT,relativistic electron proton telescope
# added...REU,research experiences for undergraduates
# added...RFI,request for information
# added...RHESSI,ramaty high energy solar spectroscopic imager
# added...RISR,resolute bay incoherent scatter radar
# added...ROSES,research opportunities in space and earth sciences
# added...RPA,ion retarding potential analyzer
# added...SABER,sounding of the atmosphere using broadband emission radiometry
# added...SALMON,stand alone missions of opportunities notice
# added...SAMPEX,solar anomalous and magnetospheric particle explorer
# added...SAPS,subauroral polarization streams
# added...SCOSTEP,scientific committee on solar terrestrial physics
# Helio acronym: SDO; ADS acronym: SDO
# added...SEE,solar eruptive events (mission)
# added...SEP,solar energetic particle
# added...SFO,san fernando observatory
# added...SHINE,solar heliosphere and interplanetary environment
# added...SHP,solar and heliospheric physics
# added...SKR,saturnian kilometric radio
# added...SM,servicing mission
# added...SMD,science mission directorate
# added...SMEI,solar mass ejection imager
# Helio acronym: SMEX; ADS acronym: SMEX
# added...SNOE,student nitric oxide explorer
# Helio acronym: SNR; ADS acronym: SNR
# added...SO,solar orbiter
# Helio acronym: SOHO; ADS acronym: SOHO
# added...SOLIS,synoptic optical long term investigations of the sun
# added...SOON,solar observing optical network
# added...SORCE,solar radiation and climate experiment
# added...SPA,space physics and aeronomy
# added...SPARC,stratospheric processes and their role in climate
# added...SPASE,space physics archive search and extract
# added...SPD,solar physics division
# added...SPI,solar polar imager
# added...SPP,solar probe plus
# added...SRAG,space radiation analysis group
# added...SRP,solar radiation pressure
# added...SR&T,supporting research and technology
# Helio acronym: SSP; ADS acronym: SSP
# added...SSPIS,solar and space physics information system
# added...STE,suprathermal electron
# added...STEM,science technology engineering and mathematics
# Helio acronym: STEREO; ADS acronym: STEREO
# added...STP,solar terrestrial probes (program)
# added...SuperDARN,super dual auroral radar network
# added...SUVIT,solar uv visible ir telescope
# added...SWaC,space weather and climatology
# added...SWAP,space weight and power
# added...SWICS,solar wind ion composition spectrometer
# added...SWL,space weather laboratory
# added...SWMI,solar wind magnetosphere interactions
# added...SWPC,space weather prediction center
# added...SXT,soft x ray telescope
# Helio acronym: TDRSS; ADS acronym: TDRSS
# added...TEC,total electron content
# added...TEX,tiny explorers
# Helio acronym: THEMIS; ADS acronym: THEMIS
# added...TIM,total irradiance monitor
# Helio acronym: TIMED; ADS acronym: TIMED
# added...TR&T,targeted research and technology
# added...TRACE,transition region and coronal explorer
# added...TRL,technology readiness level
# added...TS,termination shock
# added...TSI,total solar irradiance
# added...TWINS,two wide angle imaging neutral atom spectrometers
# Helio acronym: UARS; ADS acronym: UARS
# added...UHURU,small astronomical satellite 1 swahili for freedom
# added...ULDB,ultra long duration balloon
# Helio acronym: USAF; ADS acronym: USAF
# Helio acronym: USGS; ADS acronym: USGS
# added...USML,us munitions list
# added...UT,universal time
# added...UV,ultraviolet
# added...UVCS,ultraviolet coronagraph spectrometer
# added...V1,voyager 1
# added...V2,voyager 2
# added...VxO,(domain specific) virtual observatory
# added...WAAS,wide area augmentation system
# added...WACCM,whole atmosphere community climate model
# added...WBS,work breakdown structure
# added...WHI,whole heliosphere interval
# added...WLC,white light coronagraph
# added...WPI,wave particle interaction
# added...WSA-Enlil,wang sheely arge enlil
# added...WSO,wilcox solar observatory

# %%
with open(r'data/ads_OpenAlex_synonyms_updated.txt', 'w') as fp:
        
    for item1 in list_syns_update:
        # write each item on a new line
        print(item1,file=fp)   
        
    print('Done')
fp.close()
# Out:
# Done

# %% [markdown]
# ### Method of Identifying Synonyms: Wordnet

# %%
# nltk.download()
nltk.download('wordnet')
nltk.download('omw-1.4')

# %% [markdown]
# #### Loop over AGU terms and add to synonyms files
#
# This currently uses wordnet corpus from NLTK to identify synonyms of the AGU index term and composes the synonyms file update based on those synonyms
#
# For the multi-term AGU index terms, we split apart each word, find the synonyms in wordnet, and put all permutations in the update to the ADS multi-term synonyms file

# %%
# phrase_to_search = pd_agu_terms['term'].iloc[1]
phrase_to_search = 'model'
print('trialing AGU index term = {}'.format(phrase_to_search))
print('output using wordnet ....\n\t')
synonym_antonym_extractor(phrase=phrase_to_search)

# for syn in wordnet.synsets("Spaces"):
#     print('{}: {}'.format(syn,syn.lemmas()))
# Out:
# trialing AGU index term = model
# output using wordnet ....
#
# {'mannequin', 'exemplar', 'manakin', 'pose', 'mould', 'role_model', 'theoretical_account', 'mold', 'good_example', 'posture', 'mock_up', 'modeling', 'pattern', 'fashion_model', 'framework', 'sit', 'mannikin', 'simulate', 'exemplary', 'poser', 'modelling', 'simulation', 'model', 'example', 'manikin'}
# set()

# %%
list_simple_syns_update = []
list_multi_syns_update = []

# Add line of description for multi-term synonyms added (single-term text file has no such headers)
list_multi_syns_update.append('\n\n# multi-term items added from AGU Index Terms in July 2022')

#NOTE: we need to modify the AGU Index Term (removing things like commas) to match format of ADS synonyms file
#  Uncertain what effect this will have on the matching to AGU metadata

for t in pd_agu_terms['term']:
    print('\n\nworking on term {}'.format(t))
    
    if ' ' in t:
        print('\t multi-term')
        t_orig = t
        t_mod = t
        t_mod = t_mod.replace(',','')
        t_mod = t_mod.replace('.','')
        t_mod = t_mod.replace(':','')
        t_mod = t_mod.replace('/',' ')

        words = t_mod.split(' ')
        variations_synonyms = []
        variations_antonyms = []
        for w in words:
            variations_synonyms_tmp,variations_antonyms_tmp = synonym_antonym_extractor(w)
            # catch stop words which produce no variations and add the stop word back
            if not variations_synonyms_tmp:
                variations_synonyms.append([w])
            else:
                variations_synonyms.append(list(variations_synonyms_tmp))
            print(variations_synonyms)
            # not currently adding antonyms
        full_variations = get_all_variations(variations_synonyms)
#         full_variations
        multi_syns_update_loop = []
        for te in full_variations:
            multi_syns_update_loop.append(' '.join(list(te)))
            
        list_multi_syns_update.append('{}, {}\n'.format(', '.join(multi_syns_update_loop),t_mod))

    else:
        print('\t single term')
        variations_synonyms,variations_antonyms = synonym_antonym_extractor(t)
        variations_synonyms = [s.replace('_',' ') for s in variations_synonyms]
        if not variations_synonyms:
            continue
        else:
            list_simple_syns_update.append('{} => {}'.format(', '.join(variations_synonyms),t))
# Out:
# working on term informatics
# 	 single term
#
#
# working on term community modeling frameworks
# 	 multi-term
# [['residential_area', 'residential_district', 'community', 'community_of_interests', 'biotic_community']]
# [['residential_area', 'residential_district', 'community', 'community_of_interests', 'biotic_community'], ['model', 'simulate', 'pose', 'mold', 'moulding', 'clay_sculpture', 'sit', 'molding', 'mock_up', 'pattern', 'modelling', 'mould', 'modeling', 'posture']]
# [['residential_area', 'residential_district', 'community', 'community_of_interests', 'biotic_community'], ['model', 'simulate', 'pose', 'mold', 'moulding', 'clay_sculpture', 'sit', 'molding', 'mock_up', 'pattern', 'modelling', 'mould', 'modeling', 'posture'], ['model', 'fabric', 'theoretical_account', 'framework']]
#
#
# working on term community standards
# 	 multi-term
# [['residential_area', 'residential_district', 'community', 'community_of_interests', 'biotic_community']]
# [['residential_area', 'residential_district', 'community', 'community_of_interests', 'biotic_community'], ['measure', 'criterion', 'touchstone', 'standard', 'monetary_standard', 'banner']]
#
#
# working on term computational models, algorithms
# 	 multi-term
# [['computational']]
# [['computational'], ['simulation', 'simulate', 'mold', 'mock_up', 'manikin', 'modelling', 'posture', 'model', 'mannequin', 'pose', 'modeling', 'sit', 'good_example', 'fashion_model', 'exemplar', 'role_model', 'framework', 'poser', 'mould', 'example', 'manakin', 'theoretical_account', 'pattern', 'mannikin']]
# [['computational'], ['simulation', 'simulate', 'mold', 'mock_up', 'manikin', 'modelling', 'posture', 'model', 'mannequin', 'pose', 'modeling', 'sit', 'good_example', 'fashion_model', 'exemplar', 'role_model', 'framework', 'poser', 'mould', 'example', 'manakin', 'theoretical_account', 'pattern', 'mannikin'], ['algorithm', 'algorithmic_rule', 'algorithmic_program']]
#
#
# working on term cyberinfrastructure
# 	 single term
#
#
# working on term data assimilation, integration and fusion
# 	 multi-term
# [['datum', 'information', 'data', 'data_point']]
# [['datum', 'information', 'data', 'data_point'], ['acculturation', 'absorption', 'assimilation']]
# [['datum', 'information', 'data', 'data_point'], ['acculturation', 'absorption', 'assimilation'], ['desegregation', 'integrating', 'consolidation', 'integration']]
# [['datum', 'information', 'data', 'data_point'], ['acculturation', 'absorption', 'assimilation'], ['desegregation', 'integrating', 'consolidation', 'integration'], ['and']]
# [['datum', 'information', 'data', 'data_point'], ['acculturation', 'absorption', 'assimilation'], ['desegregation', 'integrating', 'consolidation', 'integration'], ['and'], ['merger', 'unification', 'spinal_fusion', 'nuclear_fusion', 'optical_fusion', 'nuclear_fusion_reaction', 'coalition', 'fusion']]
#
#
# working on term data management, preservation, rescue
# 	 multi-term
# [['datum', 'information', 'data', 'data_point']]
# [['datum', 'information', 'data', 'data_point'], ['management', 'direction']]
# [['datum', 'information', 'data', 'data_point'], ['management', 'direction'], ['conservation', 'saving', 'preservation']]
# [['datum', 'information', 'data', 'data_point'], ['management', 'direction'], ['conservation', 'saving', 'preservation'], ['rescue', 'deliver', 'delivery', 'deliverance', 'saving']]
#
#
# working on term data mining
# 	 multi-term
# [['datum', 'information', 'data', 'data_point']]
# [['datum', 'information', 'data', 'data_point'], ['excavation', 'mine', 'minelaying', 'mining']]
#
#
# working on term data and information discovery
# 	 multi-term
# [['datum', 'information', 'data', 'data_point']]
# [['datum', 'information', 'data', 'data_point'], ['and']]
# [['datum', 'information', 'data', 'data_point'], ['and'], ['information', 'selective_information', 'data', 'entropy', 'info']]
# [['datum', 'information', 'data', 'data_point'], ['and'], ['information', 'selective_information', 'data', 'entropy', 'info'], ['breakthrough', 'uncovering', 'find', 'discovery']]
#
#
# working on term decision analysis
# 	 multi-term
# [['decisiveness', 'decision', 'conclusion', 'determination']]
# [['decisiveness', 'decision', 'conclusion', 'determination'], ['analysis', 'analytic_thinking', 'psychoanalysis', 'depth_psychology']]
#
#
# working on term emerging informatics technologies
# 	 multi-term
# [['emerge', 'come_out', 'come_forth', 'emergent', 'egress', 'emerging', 'issue', 'rising', 'go_forth']]
# [['emerge', 'come_out', 'come_forth', 'emergent', 'egress', 'emerging', 'issue', 'rising', 'go_forth'], ['IP', 'information_processing', 'information_science', 'informatics']]
# [['emerge', 'come_out', 'come_forth', 'emergent', 'egress', 'emerging', 'issue', 'rising', 'go_forth'], ['IP', 'information_processing', 'information_science', 'informatics'], ['applied_science', 'engineering_science', 'technology', 'engineering']]
#
#
# working on term forecasting
# 	 single term
#
#
# working on term formal logics and grammars
# 	 multi-term
# [['courtly', 'dinner_dress', 'conventional', 'schematic', 'stately', 'dinner_gown', 'evening_gown', 'formal', 'ball']]
# [['courtly', 'dinner_dress', 'conventional', 'schematic', 'stately', 'dinner_gown', 'evening_gown', 'formal', 'ball'], ['logical_system', 'system_of_logic', 'logic']]
# [['courtly', 'dinner_dress', 'conventional', 'schematic', 'stately', 'dinner_gown', 'evening_gown', 'formal', 'ball'], ['logical_system', 'system_of_logic', 'logic'], ['and']]
# [['courtly', 'dinner_dress', 'conventional', 'schematic', 'stately', 'dinner_gown', 'evening_gown', 'formal', 'ball'], ['logical_system', 'system_of_logic', 'logic'], ['and'], ['grammar']]
#
#
# working on term geospatial
# 	 single term
#
#
# working on term gis science
# 	 multi-term
# [['GI', 'Gi', 'G.I.', 'gilbert', 'Gb']]
# [['GI', 'Gi', 'G.I.', 'gilbert', 'Gb'], ['scientific_discipline', 'science', 'skill']]
#
#
# working on term data and information governance
# 	 multi-term
# [['datum', 'information', 'data', 'data_point']]
# [['datum', 'information', 'data', 'data_point'], ['and']]
# [['datum', 'information', 'data', 'data_point'], ['and'], ['information', 'selective_information', 'data', 'entropy', 'info']]
# [['datum', 'information', 'data', 'data_point'], ['and'], ['information', 'selective_information', 'data', 'entropy', 'info'], ['organisation', 'administration', 'governing_body', 'organization', 'governance', 'government', 'establishment', 'government_activity', 'governing', 'brass']]
#
#
# working on term high-performance computing
# 	 multi-term
# [['high-performance']]
# [['high-performance'], ['computing', 'figure', 'cipher', 'computer_science', 'calculate', 'cypher', 'reckon', 'computation', 'calculation', 'compute', 'work_out']]
#
#
# working on term international collaboration
# 	 multi-term
# [['International', 'international', 'external', 'outside']]
# [['International', 'international', 'external', 'outside'], ['quislingism', 'collaboration', 'coaction', 'collaborationism']]
#
#
# working on term interoperability
# 	 single term
#
#
# working on term knowledge representation and knowledge bases
# 	 multi-term
# [['noesis', 'knowledge', 'cognition']]
# [['noesis', 'knowledge', 'cognition'], ['histrionics', 'theatrical_performance', 'delegacy', 'mental_representation', 'internal_representation', 'agency', 'theatrical', 'representation']]
# [['noesis', 'knowledge', 'cognition'], ['histrionics', 'theatrical_performance', 'delegacy', 'mental_representation', 'internal_representation', 'agency', 'theatrical', 'representation'], ['and']]
# [['noesis', 'knowledge', 'cognition'], ['histrionics', 'theatrical_performance', 'delegacy', 'mental_representation', 'internal_representation', 'agency', 'theatrical', 'representation'], ['and'], ['noesis', 'knowledge', 'cognition']]
# [['noesis', 'knowledge', 'cognition'], ['histrionics', 'theatrical_performance', 'delegacy', 'mental_representation', 'internal_representation', 'agency', 'theatrical', 'representation'], ['and'], ['noesis', 'knowledge', 'cognition'], ['nucleotide', 'base', 'root_word', 'foot', 'establish', 'bag', 'fundament', 'foundation', 'Base', 'groundwork', 'theme', 'base_of_operations', 'floor', 'al-Qaida', 'ground', 'found', 'infrastructure', 'basis', 'Qaeda', 'footing', "al-Qa'ida", 'radical', 'substructure', 'root', 'cornerstone', 'pedestal', 'home', 'free-base', 'radix', 'stand', 'stem', 'understructure', 'alkali', 'al-Qaeda']]
#
#
# working on term machine-to-machine communication
# 	 multi-term
# [['machine-to-machine']]
# [['machine-to-machine'], ['communicating', 'communication']]
#
#
# working on term machine learning
# 	 multi-term
# [['car', 'simple_machine', 'motorcar', 'automobile', 'political_machine', 'auto', 'machine']]
# [['car', 'simple_machine', 'motorcar', 'automobile', 'political_machine', 'auto', 'machine'], ['discover', 'find_out', 'acquisition', 'check', 'watch', 'determine', 'scholarship', 'study', 'learning', 'teach', 'memorise', 'erudition', 'ascertain', 'get_word', 'instruct', 'acquire', 'memorize', 'learnedness', 'get_wind', 'see', 'get_a_line', 'pick_up', 'con', 'read', 'take', 'larn', 'hear', 'eruditeness', 'encyclopedism', 'learn', 'encyclopaedism']]
#
#
# working on term markup languages
# 	 multi-term
# [['markup']]
# [['markup'], ['nomenclature', 'voice_communication', 'terminology', 'linguistic_communication', 'speech', 'spoken_language', 'linguistic_process', 'speech_communication', 'words', 'language', 'oral_communication', 'lyric', 'spoken_communication']]
#
#
# working on term metadata
# 	 single term
#
#
# working on term metadata: provenance
# 	 multi-term
# [['metadata']]
# [['metadata'], ['provenience', 'provenance', 'place_of_origin', 'birthplace', 'cradle']]
#
#
# working on term metadata: quality
# 	 multi-term
# [['metadata']]
# [['metadata'], ['timbre', 'timber', 'select', 'caliber', 'prime', 'tone', 'lineament', 'quality', 'calibre', 'character', 'prize', 'choice']]
#
#
# working on term modeling
# 	 single term
#
#
# working on term natural language processing
# 	 multi-term
# [['cancel', 'lifelike', 'innate', 'rude', 'born', 'natural', 'instinctive', 'raw']]
# [['cancel', 'lifelike', 'innate', 'rude', 'born', 'natural', 'instinctive', 'raw'], ['nomenclature', 'voice_communication', 'terminology', 'linguistic_communication', 'speech', 'spoken_language', 'linguistic_process', 'speech_communication', 'words', 'language', 'oral_communication', 'lyric', 'spoken_communication']]
# [['cancel', 'lifelike', 'innate', 'rude', 'born', 'natural', 'instinctive', 'raw'], ['nomenclature', 'voice_communication', 'terminology', 'linguistic_communication', 'speech', 'spoken_language', 'linguistic_process', 'speech_communication', 'words', 'language', 'oral_communication', 'lyric', 'spoken_communication'], ['action', 'sue', 'march', 'swear_out', 'work_on', 'process', 'work', 'litigate', 'treat', 'processing', 'serve']]
#
#
# working on term numerical algorithms
# 	 multi-term
# [['mathematical', 'numeral', 'numeric', 'numerical']]
# [['mathematical', 'numeral', 'numeric', 'numerical'], ['algorithm', 'algorithmic_rule', 'algorithmic_program']]
#
#
# working on term ontologies
# 	 single term
#
#
# working on term portals and user interfaces
# 	 multi-term
# [['hepatic_portal_vein', 'vena_portae', 'portal', 'portal_site', 'portal_vein']]
# [['hepatic_portal_vein', 'vena_portae', 'portal', 'portal_site', 'portal_vein'], ['and']]
# [['hepatic_portal_vein', 'vena_portae', 'portal', 'portal_site', 'portal_vein'], ['and'], ['substance_abuser', 'drug_user', 'user', 'exploiter']]
# [['hepatic_portal_vein', 'vena_portae', 'portal', 'portal_site', 'portal_vein'], ['and'], ['substance_abuser', 'drug_user', 'user', 'exploiter'], ['port', 'user_interface', 'interface']]
#
#
# working on term query languages for science, markup languages, ontologies
# 	 multi-term
# [['interrogation', 'inquiry', 'query', 'enquiry', 'question']]
# [['interrogation', 'inquiry', 'query', 'enquiry', 'question'], ['nomenclature', 'voice_communication', 'terminology', 'linguistic_communication', 'speech', 'spoken_language', 'linguistic_process', 'speech_communication', 'words', 'language', 'oral_communication', 'lyric', 'spoken_communication']]
# [['interrogation', 'inquiry', 'query', 'enquiry', 'question'], ['nomenclature', 'voice_communication', 'terminology', 'linguistic_communication', 'speech', 'spoken_language', 'linguistic_process', 'speech_communication', 'words', 'language', 'oral_communication', 'lyric', 'spoken_communication'], ['for']]
# [['interrogation', 'inquiry', 'query', 'enquiry', 'question'], ['nomenclature', 'voice_communication', 'terminology', 'linguistic_communication', 'speech', 'spoken_language', 'linguistic_process', 'speech_communication', 'words', 'language', 'oral_communication', 'lyric', 'spoken_communication'], ['for'], ['scientific_discipline', 'science', 'skill']]
# [['interrogation', 'inquiry', 'query', 'enquiry', 'question'], ['nomenclature', 'voice_communication', 'terminology', 'linguistic_communication', 'speech', 'spoken_language', 'linguistic_process', 'speech_communication', 'words', 'language', 'oral_communication', 'lyric', 'spoken_communication'], ['for'], ['scientific_discipline', 'science', 'skill'], ['markup']]
# [['interrogation', 'inquiry', 'query', 'enquiry', 'question'], ['nomenclature', 'voice_communication', 'terminology', 'linguistic_communication', 'speech', 'spoken_language', 'linguistic_process', 'speech_communication', 'words', 'language', 'oral_communication', 'lyric', 'spoken_communication'], ['for'], ['scientific_discipline', 'science', 'skill'], ['markup'], ['nomenclature', 'voice_communication', 'terminology', 'linguistic_communication', 'speech', 'spoken_language', 'linguistic_process', 'speech_communication', 'words', 'language', 'oral_communication', 'lyric', 'spoken_communication']]
# [['interrogation', 'inquiry', 'query', 'enquiry', 'question'], ['nomenclature', 'voice_communication', 'terminology', 'linguistic_communication', 'speech', 'spoken_language', 'linguistic_process', 'speech_communication', 'words', 'language', 'oral_communication', 'lyric', 'spoken_communication'], ['for'], ['scientific_discipline', 'science', 'skill'], ['markup'], ['nomenclature', 'voice_communication', 'terminology', 'linguistic_communication', 'speech', 'spoken_language', 'linguistic_process', 'speech_communication', 'words', 'language', 'oral_communication', 'lyric', 'spoken_communication'], ['ontology']]
#
#
# working on term real-time and responsive information delivery
# 	 multi-term
# [['real-time']]
# [['real-time'], ['and']]
# [['real-time'], ['and'], ['responsive', 'antiphonal', 'reactive']]
# [['real-time'], ['and'], ['responsive', 'antiphonal', 'reactive'], ['information', 'selective_information', 'data', 'entropy', 'info']]
# [['real-time'], ['and'], ['responsive', 'antiphonal', 'reactive'], ['information', 'selective_information', 'data', 'entropy', 'info'], ['manner_of_speaking', 'livery', 'speech', 'rescue', 'obstetrical_delivery', 'delivery', 'pitch', 'bringing', 'legal_transfer', 'deliverance', 'saving']]
#
#
# working on term rules and logic
# 	 multi-term
# [['ruler', 'dominion', 'rule', 'reign', 'find', 'govern', 'prescript', 'formula', 'linguistic_rule', 'normal', 'harness', 'dominate', 'rein', 'regulation', 'principle', 'convention', 'prevail', 'pattern', 'decree', 'predominate']]
# [['ruler', 'dominion', 'rule', 'reign', 'find', 'govern', 'prescript', 'formula', 'linguistic_rule', 'normal', 'harness', 'dominate', 'rein', 'regulation', 'principle', 'convention', 'prevail', 'pattern', 'decree', 'predominate'], ['and']]
# [['ruler', 'dominion', 'rule', 'reign', 'find', 'govern', 'prescript', 'formula', 'linguistic_rule', 'normal', 'harness', 'dominate', 'rein', 'regulation', 'principle', 'convention', 'prevail', 'pattern', 'decree', 'predominate'], ['and'], ['logical_system', 'system_of_logic', 'logic']]
#
#
# working on term scientific reasoning/inference
# 	 multi-term
# [['scientific']]
# [['scientific'], ['logical_thinking', 'intelligent', 'conclude', 'reasoning', 'reason', 'thinking', 'reason_out', 'abstract_thought', 'argue']]
# [['scientific'], ['logical_thinking', 'intelligent', 'conclude', 'reasoning', 'reason', 'thinking', 'reason_out', 'abstract_thought', 'argue'], ['illation', 'inference']]
#
#
# working on term semantic web and semantic integration
# 	 multi-term
# [['semantic']]
# [['semantic'], ['web', 'vane', 'World_Wide_Web', 'network', 'WWW', 'entanglement', 'net']]
# [['semantic'], ['web', 'vane', 'World_Wide_Web', 'network', 'WWW', 'entanglement', 'net'], ['and']]
# [['semantic'], ['web', 'vane', 'World_Wide_Web', 'network', 'WWW', 'entanglement', 'net'], ['and'], ['semantic']]
# [['semantic'], ['web', 'vane', 'World_Wide_Web', 'network', 'WWW', 'entanglement', 'net'], ['and'], ['semantic'], ['desegregation', 'integrating', 'consolidation', 'integration']]
#
#
# working on term sensor web
# 	 multi-term
# [['sensing_element', 'detector', 'sensor']]
# [['sensing_element', 'detector', 'sensor'], ['web', 'vane', 'World_Wide_Web', 'network', 'WWW', 'entanglement', 'net']]
#
#
# working on term social networks
# 	 multi-term
# [['societal', 'sociable', 'social', 'mixer']]
# [['societal', 'sociable', 'social', 'mixer'], ['web', 'mesh', 'meshwork', 'electronic_network', 'network', 'meshing', 'net']]
#
#
# working on term software tools and services
# 	 multi-term
# [['software', 'package', 'software_system', 'software_program', 'computer_software', 'software_package']]
# [['software', 'package', 'software_system', 'software_program', 'computer_software', 'software_package'], ['puppet', 'creature', 'peter', 'dick', 'joyride', 'cock', 'tool_around', 'shaft', 'instrument', 'prick', 'putz', 'pecker', 'tool']]
# [['software', 'package', 'software_system', 'software_program', 'computer_software', 'software_package'], ['puppet', 'creature', 'peter', 'dick', 'joyride', 'cock', 'tool_around', 'shaft', 'instrument', 'prick', 'putz', 'pecker', 'tool'], ['and']]
# [['software', 'package', 'software_system', 'software_program', 'computer_software', 'software_package'], ['puppet', 'creature', 'peter', 'dick', 'joyride', 'cock', 'tool_around', 'shaft', 'instrument', 'prick', 'putz', 'pecker', 'tool'], ['and'], ['divine_service', 'help', 'serve', 'avail', 'inspection_and_repair', 'Service', 'religious_service', 'service_of_process', 'Robert_William_Service', 'military_service', 'servicing', 'overhaul', 'serving', 'armed_service', 'service', 'services', 'table_service']]
#
#
# working on term software re-use
# 	 multi-term
# [['software', 'package', 'software_system', 'software_program', 'computer_software', 'software_package']]
# [['software', 'package', 'software_system', 'software_program', 'computer_software', 'software_package'], ['re-use']]
#
#
# working on term spatial analysis and representation
# 	 multi-term
# [['spatial', 'spacial']]
# [['spatial', 'spacial'], ['analysis', 'analytic_thinking', 'psychoanalysis', 'depth_psychology']]
# [['spatial', 'spacial'], ['analysis', 'analytic_thinking', 'psychoanalysis', 'depth_psychology'], ['and']]
# [['spatial', 'spacial'], ['analysis', 'analytic_thinking', 'psychoanalysis', 'depth_psychology'], ['and'], ['histrionics', 'theatrical_performance', 'delegacy', 'mental_representation', 'internal_representation', 'agency', 'theatrical', 'representation']]
#
#
# working on term standards
# 	 single term
#
#
# working on term statistical methods: descriptive
# 	 multi-term
# [['statistical']]
# [['statistical'], ['method_acting', 'method']]
# [['statistical'], ['method_acting', 'method'], ['descriptive']]
#
#
# working on term statistical methods: inferential
# 	 multi-term
# [['statistical']]
# [['statistical'], ['method_acting', 'method']]
# [['statistical'], ['method_acting', 'method'], ['inferential', 'illative']]
#
#
# working on term temporal analysis and representation
# 	 multi-term
# [['secular', 'worldly', 'temporal_role', 'temporal']]
# [['secular', 'worldly', 'temporal_role', 'temporal'], ['analysis', 'analytic_thinking', 'psychoanalysis', 'depth_psychology']]
# [['secular', 'worldly', 'temporal_role', 'temporal'], ['analysis', 'analytic_thinking', 'psychoanalysis', 'depth_psychology'], ['and']]
# [['secular', 'worldly', 'temporal_role', 'temporal'], ['analysis', 'analytic_thinking', 'psychoanalysis', 'depth_psychology'], ['and'], ['histrionics', 'theatrical_performance', 'delegacy', 'mental_representation', 'internal_representation', 'agency', 'theatrical', 'representation']]
#
#
# working on term uncertainty
# 	 single term
#
#
# working on term virtual globes
# 	 multi-term
# [['virtual', 'practical']]
# [['virtual', 'practical'], ['earth', 'world', 'globe', 'Earth', 'orb', 'ball']]
#
#
# working on term visualization and portrayal
# 	 multi-term
# [['visualisation', 'visual_image', 'visualization']]
# [['visualisation', 'visual_image', 'visualization'], ['and']]
# [['visualisation', 'visual_image', 'visualization'], ['and'], ['portraiture', 'characterization', 'depiction', 'enactment', 'portrayal', 'portraying', 'depicting', 'personation', 'portrait', 'delineation']]
#
#
# working on term web services
# 	 multi-term
# [['web', 'vane', 'World_Wide_Web', 'network', 'WWW', 'entanglement', 'net']]
# [['web', 'vane', 'World_Wide_Web', 'network', 'WWW', 'entanglement', 'net'], ['divine_service', 'help', 'serve', 'avail', 'inspection_and_repair', 'Service', 'religious_service', 'service_of_process', 'Robert_William_Service', 'military_service', 'servicing', 'overhaul', 'serving', 'armed_service', 'service', 'services', 'table_service']]
#
#
# working on term workflow
# 	 single term
#
#
# working on term interplanetary physics
# 	 multi-term
# [['interplanetary']]
# [['interplanetary'], ['natural_philosophy', 'physics', 'purgative', 'physical_science', 'physic', 'cathartic', 'aperient']]
#
#
# working on term coronal mass ejections
# 	 multi-term
# [['wreath', 'lei', 'chaplet', 'garland', 'coronal']]
# [['wreath', 'lei', 'chaplet', 'garland', 'coronal'], ['passel', 'mountain', 'heap', 'plenty', 'Mass', 'peck', 'mess', 'sight', 'aggregate', 'wad', 'mint', 'bulk', 'spate', 'raft', 'masses', 'volume', 'slew', 'mass', 'good_deal', 'batch', 'lot', 'deal', 'flock', 'hatful', 'quite_a_little', 'people', 'the_great_unwashed', 'muckle', 'hoi_polloi', 'aggregated', 'pile', 'tidy_sum', 'pot', 'mickle', 'multitude', 'great_deal', 'stack', 'aggregative']]
# [['wreath', 'lei', 'chaplet', 'garland', 'coronal'], ['passel', 'mountain', 'heap', 'plenty', 'Mass', 'peck', 'mess', 'sight', 'aggregate', 'wad', 'mint', 'bulk', 'spate', 'raft', 'masses', 'volume', 'slew', 'mass', 'good_deal', 'batch', 'lot', 'deal', 'flock', 'hatful', 'quite_a_little', 'people', 'the_great_unwashed', 'muckle', 'hoi_polloi', 'aggregated', 'pile', 'tidy_sum', 'pot', 'mickle', 'multitude', 'great_deal', 'stack', 'aggregative'], ['forcing_out', 'exclusion', 'riddance', 'expulsion', 'ejection', 'projection']]
#
#
# working on term corotating streams
# 	 multi-term
# [['corotating']]
# [['corotating'], ['stream', 'pullulate', 'swarm', 'watercourse', 'flow', 'teem', 'pelt', 'rain_cats_and_dogs', 'well_out', 'current', 'pour', 'rain_buckets']]
#
#
# working on term cosmic rays
# 	 multi-term
# [['cosmic']]
# [['cosmic'], ['beam_of_light', 'ray_of_light', 'electron_beam', 'light_beam', 'beam', 'ray', 'irradiate', 'shaft_of_light', 'shaft', 'irradiation', 'radiate', 're']]
#
#
# working on term discontinuities
# 	 single term
#
#
# working on term ejecta, driver gases, and magnetic clouds
# 	 multi-term
# [['ejecta']]
# [['ejecta'], ['driver', 'device_driver', 'number_one_wood']]
# [['ejecta'], ['driver', 'device_driver', 'number_one_wood'], ['gas', 'gaseous_state', 'brag', 'blow', 'gasoline', 'gasconade', 'gas_pedal', 'flatulency', 'gasolene', 'bluster', 'boast', 'accelerator_pedal', 'vaunt', 'accelerator', 'throttle', 'petrol', 'shoot_a_line', 'tout', 'flatulence', 'swash', 'gun', 'natural_gas']]
# [['ejecta'], ['driver', 'device_driver', 'number_one_wood'], ['gas', 'gaseous_state', 'brag', 'blow', 'gasoline', 'gasconade', 'gas_pedal', 'flatulency', 'gasolene', 'bluster', 'boast', 'accelerator_pedal', 'vaunt', 'accelerator', 'throttle', 'petrol', 'shoot_a_line', 'tout', 'flatulence', 'swash', 'gun', 'natural_gas'], ['and']]
# [['ejecta'], ['driver', 'device_driver', 'number_one_wood'], ['gas', 'gaseous_state', 'brag', 'blow', 'gasoline', 'gasconade', 'gas_pedal', 'flatulency', 'gasolene', 'bluster', 'boast', 'accelerator_pedal', 'vaunt', 'accelerator', 'throttle', 'petrol', 'shoot_a_line', 'tout', 'flatulence', 'swash', 'gun', 'natural_gas'], ['and'], ['magnetised', 'magnetized', 'charismatic', 'magnetic']]
# [['ejecta'], ['driver', 'device_driver', 'number_one_wood'], ['gas', 'gaseous_state', 'brag', 'blow', 'gasoline', 'gasconade', 'gas_pedal', 'flatulency', 'gasolene', 'bluster', 'boast', 'accelerator_pedal', 'vaunt', 'accelerator', 'throttle', 'petrol', 'shoot_a_line', 'tout', 'flatulence', 'swash', 'gun', 'natural_gas'], ['and'], ['magnetised', 'magnetized', 'charismatic', 'magnetic'], ['corrupt', 'fog', 'defile', 'swarm', 'befog', 'becloud', 'overcast', 'obnubilate', 'haze_over', 'taint', 'mottle', 'sully', 'dapple', 'mist', 'obscure', 'cloud']]
#
#
# working on term energetic particles
# 	 multi-term
# [['energetic', 'gumptious', 'industrious', 'up-and-coming']]
# [['energetic', 'gumptious', 'industrious', 'up-and-coming'], ['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle']]
#
#
# working on term heliopause and solar wind termination
# 	 multi-term
# [['heliopause']]
# [['heliopause'], ['and']]
# [['heliopause'], ['and'], ['solar']]
# [['heliopause'], ['and'], ['solar'], ['wind_instrument', 'steer', 'nothingness', 'wind_up', 'tip', 'winding', 'malarky', 'meander', 'wander', 'nose', 'roll', 'lift', 'jazz', 'idle_words', 'confidential_information', 'twine', 'current_of_air', 'twist', 'weave', 'air_current', 'lead', 'farting', 'wrap', 'wreathe', 'thread', 'wind', 'hoist', 'hint', 'fart', 'flatus', 'breaking_wind', 'scent', 'malarkey', 'curve']]
# [['heliopause'], ['and'], ['solar'], ['wind_instrument', 'steer', 'nothingness', 'wind_up', 'tip', 'winding', 'malarky', 'meander', 'wander', 'nose', 'roll', 'lift', 'jazz', 'idle_words', 'confidential_information', 'twine', 'current_of_air', 'twist', 'weave', 'air_current', 'lead', 'farting', 'wrap', 'wreathe', 'thread', 'wind', 'hoist', 'hint', 'fart', 'flatus', 'breaking_wind', 'scent', 'malarkey', 'curve'], ['result', 'expiry', 'terminus', 'ending', 'expiration', 'resultant', 'final_result', 'end_point', 'outcome', 'conclusion', 'termination', 'endpoint']]
#
#
# working on term heliosphere/interstellar medium interactions
# 	 multi-term
# [['heliosphere']]
# [['heliosphere'], ['interstellar']]
# [['heliosphere'], ['interstellar'], ['sensitive', 'intermediate', 'metier', 'mass_medium', 'average', 'spiritualist', 'culture_medium', 'medium']]
# [['heliosphere'], ['interstellar'], ['sensitive', 'intermediate', 'metier', 'mass_medium', 'average', 'spiritualist', 'culture_medium', 'medium'], ['fundamental_interaction', 'interaction']]
#
#
# working on term interplanetary dust
# 	 multi-term
# [['interplanetary']]
# [['interplanetary'], ['rubble', 'detritus', 'debris', 'scatter', 'dust', 'disperse', 'sprinkle', 'dot', 'junk']]
#
#
# working on term interplanetary magnetic fields
# 	 multi-term
# [['interplanetary']]
# [['interplanetary'], ['magnetised', 'magnetized', 'charismatic', 'magnetic']]
# [['interplanetary'], ['magnetised', 'magnetized', 'charismatic', 'magnetic'], ['W._C._Fields', 'landing_field', 'bailiwick', 'battlefield', 'Fields', 'theatre_of_operations', 'line_of_business', 'study', 'playing_area', 'arena', 'field_of_honor', 'theatre', 'field_of_study', 'field_of_operation', 'subject_area', 'field_of_view', 'champaign', 'subject', 'force_field', 'airfield', 'field_of_battle', 'flying_field', 'athletic_field', 'field', 'subject_field', 'playing_field', 'orbit', 'discipline', 'field_of_operations', 'domain', 'plain', 'battleground', 'William_Claude_Dukenfield', 'field_of_force', 'theater', 'theater_of_operations', 'sphere', 'area']]
#
#
# working on term interplanetary shocks
# 	 multi-term
# [['interplanetary']]
# [['interplanetary'], ['ball_over', 'jar', 'take_aback', 'shock_absorber', 'electrical_shock', 'shock', 'blow', 'jounce', 'stupor', 'offend', 'floor', 'traumatise', 'scandalize', 'traumatize', 'outrage', 'scandalise', 'cushion', 'impact', 'appall', 'electric_shock', 'blow_out_of_the_water', 'jolt', 'appal', 'daze', 'seismic_disturbance']]
#
#
# working on term interstellar gas
# 	 multi-term
# [['interstellar']]
# [['interstellar'], ['gas', 'gaseous_state', 'brag', 'blow', 'gasoline', 'gasconade', 'gas_pedal', 'flatulency', 'gasolene', 'bluster', 'boast', 'accelerator_pedal', 'vaunt', 'accelerator', 'throttle', 'petrol', 'shoot_a_line', 'tout', 'flatulence', 'swash', 'gun', 'natural_gas']]
#
#
# working on term mhd waves and turbulence
# 	 multi-term
# [['mhd']]
# [['mhd'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation']]
# [['mhd'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['and']]
# [['mhd'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['and'], ['turbulence', 'turbulency', 'upheaval', 'Sturm_und_Drang']]
#
#
# working on term neutral particles
# 	 multi-term
# [['impersonal', 'neutral', 'inert', 'electroneutral', 'indifferent', 'achromatic']]
# [['impersonal', 'neutral', 'inert', 'electroneutral', 'indifferent', 'achromatic'], ['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle']]
#
#
# working on term pickup ions
# 	 multi-term
# [['tone_arm', 'getaway', 'pickup', 'cartridge', 'pickup_arm', 'pickup_truck', 'pick-me-up']]
# [['tone_arm', 'getaway', 'pickup', 'cartridge', 'pickup_arm', 'pickup_truck', 'pick-me-up'], ['ion']]
#
#
# working on term planetary bow shocks
# 	 multi-term
# [['world', 'global', 'planetary', 'wandering', 'worldwide', 'erratic', 'terrestrial', 'world-wide', 'planetal']]
# [['world', 'global', 'planetary', 'wandering', 'worldwide', 'erratic', 'terrestrial', 'world-wide', 'planetal'], ['bend', 'bow', 'arc', 'prow', 'obeisance', 'bowing', 'defer', 'crouch', 'bow_down', 'stem', 'give_in', 'submit', 'bowknot', 'fore', 'curtain_call', 'stoop', 'accede']]
# [['world', 'global', 'planetary', 'wandering', 'worldwide', 'erratic', 'terrestrial', 'world-wide', 'planetal'], ['bend', 'bow', 'arc', 'prow', 'obeisance', 'bowing', 'defer', 'crouch', 'bow_down', 'stem', 'give_in', 'submit', 'bowknot', 'fore', 'curtain_call', 'stoop', 'accede'], ['ball_over', 'jar', 'take_aback', 'shock_absorber', 'electrical_shock', 'shock', 'blow', 'jounce', 'stupor', 'offend', 'floor', 'traumatise', 'scandalize', 'traumatize', 'outrage', 'scandalise', 'cushion', 'impact', 'appall', 'electric_shock', 'blow_out_of_the_water', 'jolt', 'appal', 'daze', 'seismic_disturbance']]
#
#
# working on term plasma waves and turbulence
# 	 multi-term
# [['plasm', 'plasma', 'blood_plasma']]
# [['plasm', 'plasma', 'blood_plasma'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation']]
# [['plasm', 'plasma', 'blood_plasma'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['and']]
# [['plasm', 'plasma', 'blood_plasma'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['and'], ['turbulence', 'turbulency', 'upheaval', 'Sturm_und_Drang']]
#
#
# working on term solar cycle variations
# 	 multi-term
# [['solar']]
# [['solar'], ['oscillation', 'bike', 'Hz', 'motorcycle', 'wheel', 'rhythm', 'motorbike', 'cps', 'hertz', 'cycle_per_second', 'cycle', 'pedal', 'round', 'bicycle', 'cycles/second']]
# [['solar'], ['oscillation', 'bike', 'Hz', 'motorcycle', 'wheel', 'rhythm', 'motorbike', 'cps', 'hertz', 'cycle_per_second', 'cycle', 'pedal', 'round', 'bicycle', 'cycles/second'], ['version', 'mutation', 'fluctuation', 'variance', 'mutant', 'variation', 'magnetic_declination', 'sport', 'magnetic_variation', 'variant', 'edition', 'pas_seul']]
#
#
# working on term solar wind plasma
# 	 multi-term
# [['solar']]
# [['solar'], ['wind_instrument', 'steer', 'nothingness', 'wind_up', 'tip', 'winding', 'malarky', 'meander', 'wander', 'nose', 'roll', 'lift', 'jazz', 'idle_words', 'confidential_information', 'twine', 'current_of_air', 'twist', 'weave', 'air_current', 'lead', 'farting', 'wrap', 'wreathe', 'thread', 'wind', 'hoist', 'hint', 'fart', 'flatus', 'breaking_wind', 'scent', 'malarkey', 'curve']]
# [['solar'], ['wind_instrument', 'steer', 'nothingness', 'wind_up', 'tip', 'winding', 'malarky', 'meander', 'wander', 'nose', 'roll', 'lift', 'jazz', 'idle_words', 'confidential_information', 'twine', 'current_of_air', 'twist', 'weave', 'air_current', 'lead', 'farting', 'wrap', 'wreathe', 'thread', 'wind', 'hoist', 'hint', 'fart', 'flatus', 'breaking_wind', 'scent', 'malarkey', 'curve'], ['plasm', 'plasma', 'blood_plasma']]
#
#
# working on term solar wind sources
# 	 multi-term
# [['solar']]
# [['solar'], ['wind_instrument', 'steer', 'nothingness', 'wind_up', 'tip', 'winding', 'malarky', 'meander', 'wander', 'nose', 'roll', 'lift', 'jazz', 'idle_words', 'confidential_information', 'twine', 'current_of_air', 'twist', 'weave', 'air_current', 'lead', 'farting', 'wrap', 'wreathe', 'thread', 'wind', 'hoist', 'hint', 'fart', 'flatus', 'breaking_wind', 'scent', 'malarkey', 'curve']]
# [['solar'], ['wind_instrument', 'steer', 'nothingness', 'wind_up', 'tip', 'winding', 'malarky', 'meander', 'wander', 'nose', 'roll', 'lift', 'jazz', 'idle_words', 'confidential_information', 'twine', 'current_of_air', 'twist', 'weave', 'air_current', 'lead', 'farting', 'wrap', 'wreathe', 'thread', 'wind', 'hoist', 'hint', 'fart', 'flatus', 'breaking_wind', 'scent', 'malarkey', 'curve'], ['source', 'reservoir', 'generator', 'seed', 'germ', 'informant', 'origin', 'author', 'root', 'beginning', 'reference', 'rootage']]
#
#
# working on term instruments and techniques
# 	 multi-term
# [['instrumental_role', 'pawn', 'legal_instrument', 'musical_instrument', 'instrumentate', "cat's-paw", 'official_document', 'instrument', 'legal_document', 'tool']]
# [['instrumental_role', 'pawn', 'legal_instrument', 'musical_instrument', 'instrumentate', "cat's-paw", 'official_document', 'instrument', 'legal_document', 'tool'], ['and']]
# [['instrumental_role', 'pawn', 'legal_instrument', 'musical_instrument', 'instrumentate', "cat's-paw", 'official_document', 'instrument', 'legal_document', 'tool'], ['and'], ['proficiency', 'technique']]
#
#
# working on term ionosphere
# 	 single term
#
#
# working on term active experiments
# 	 multi-term
# [['active', 'alive', 'dynamic', 'fighting', 'combat-ready', 'active_agent', 'participating', 'active_voice']]
# [['active', 'alive', 'dynamic', 'fighting', 'combat-ready', 'active_agent', 'participating', 'active_voice'], ['experiment', 'try_out', 'experimentation']]
#
#
# working on term auroral ionosphere
# 	 multi-term
# [['auroral', 'aurorean']]
# [['auroral', 'aurorean'], ['ionosphere']]
#
#
# working on term current systems
# 	 multi-term
# [['electric_current', 'current', 'flow', 'stream']]
# [['electric_current', 'current', 'flow', 'stream'], ['organisation', 'arrangement', 'organization', 'system_of_rules', 'system', 'scheme']]
#
#
# working on term electric fields
# 	 multi-term
# [['galvanic', 'electric_car', 'galvanising', 'electric', 'electric_automobile', 'galvanizing', 'electrical']]
# [['galvanic', 'electric_car', 'galvanising', 'electric', 'electric_automobile', 'galvanizing', 'electrical'], ['W._C._Fields', 'landing_field', 'bailiwick', 'battlefield', 'Fields', 'theatre_of_operations', 'line_of_business', 'study', 'playing_area', 'arena', 'field_of_honor', 'theatre', 'field_of_study', 'field_of_operation', 'subject_area', 'field_of_view', 'champaign', 'subject', 'force_field', 'airfield', 'field_of_battle', 'flying_field', 'athletic_field', 'field', 'subject_field', 'playing_field', 'orbit', 'discipline', 'field_of_operations', 'domain', 'plain', 'battleground', 'William_Claude_Dukenfield', 'field_of_force', 'theater', 'theater_of_operations', 'sphere', 'area']]
#
#
# working on term equatorial ionosphere
# 	 multi-term
# [['equatorial']]
# [['equatorial'], ['ionosphere']]
#
#
# working on term ion chemistry and composition
# 	 multi-term
# [['ion']]
# [['ion'], ['interpersonal_chemistry', 'chemical_science', 'chemistry', 'alchemy']]
# [['ion'], ['interpersonal_chemistry', 'chemical_science', 'chemistry', 'alchemy'], ['and']]
# [['ion'], ['interpersonal_chemistry', 'chemical_science', 'chemistry', 'alchemy'], ['and'], ['composition', 'penning', 'writing', 'authorship', 'paper', 'make-up', 'typography', 'physical_composition', 'piece_of_music', 'report', 'theme', 'composing', 'opus', 'piece', 'constitution', 'makeup', 'musical_composition']]
#
#
# working on term ionization processes
# 	 multi-term
# [['ionisation', 'ionization']]
# [['ionisation', 'ionization'], ['summons', 'swear_out', 'appendage', 'sue', 'unconscious_process', 'march', 'work_on', 'litigate', 'treat', 'operation', 'cognitive_process', 'process', 'work', 'physical_process', 'outgrowth', 'action', 'procedure', 'cognitive_operation', 'mental_process', 'serve']]
#
#
# working on term ionosphere/atmosphere interactions
# 	 multi-term
# [['ionosphere']]
# [['ionosphere'], ['ambiance', 'atmospheric_state', 'standard_atmosphere', 'standard_pressure', 'atmosphere', 'atm', 'aura', 'ambience', 'air']]
# [['ionosphere'], ['ambiance', 'atmospheric_state', 'standard_atmosphere', 'standard_pressure', 'atmosphere', 'atm', 'aura', 'ambience', 'air'], ['fundamental_interaction', 'interaction']]
#
#
# working on term ionosphere/magnetosphere interactions
# 	 multi-term
# [['ionosphere']]
# [['ionosphere'], ['magnetosphere']]
# [['ionosphere'], ['magnetosphere'], ['fundamental_interaction', 'interaction']]
#
#
# working on term ionospheric disturbances
# 	 multi-term
# [['ionospheric']]
# [['ionospheric'], ['fray', 'ruffle', 'hoo-ha', 'affray', 'kerfuffle', 'upset', 'noise', 'interference', 'mental_disturbance', 'psychological_disorder', 'folie', 'flutter', 'hoo-hah', 'mental_disorder', 'disruption', 'disturbance', 'hurly_burly', 'commotion', 'to-do', 'perturbation']]
#
#
# working on term ionospheric dynamics
# 	 multi-term
# [['ionospheric']]
# [['ionospheric'], ['kinetics', 'dynamics', 'dynamic', 'moral_force']]
#
#
# working on term ionospheric irregularities
# 	 multi-term
# [['ionospheric']]
# [['ionospheric'], ['abnormality', 'irregularity', 'geometrical_irregularity', 'unregularity', 'constipation']]
#
#
# working on term ionospheric storms
# 	 multi-term
# [['ionospheric']]
# [['ionospheric'], ['ramp', 'tempest', 'surprise', 'violent_storm', 'storm', 'force', 'rage']]
#
#
# working on term meteor-trail physics
# 	 multi-term
# [['meteor-trail']]
# [['meteor-trail'], ['natural_philosophy', 'physics', 'purgative', 'physical_science', 'physic', 'cathartic', 'aperient']]
#
#
# working on term midlatitude ionosphere
# 	 multi-term
# [['midlatitude']]
# [['midlatitude'], ['ionosphere']]
#
#
# working on term modeling and forecasting
# 	 multi-term
# [['model', 'simulate', 'pose', 'mold', 'moulding', 'clay_sculpture', 'sit', 'molding', 'mock_up', 'pattern', 'modelling', 'mould', 'modeling', 'posture']]
# [['model', 'simulate', 'pose', 'mold', 'moulding', 'clay_sculpture', 'sit', 'molding', 'mock_up', 'pattern', 'modelling', 'mould', 'modeling', 'posture'], ['and']]
# [['model', 'simulate', 'pose', 'mold', 'moulding', 'clay_sculpture', 'sit', 'molding', 'mock_up', 'pattern', 'modelling', 'mould', 'modeling', 'posture'], ['and'], ['betoken', 'figure', 'presage', 'foretell', 'auspicate', 'predict', 'forecasting', 'forecast', 'augur', 'bode', 'foretelling', 'count_on', 'prognosticate', 'prognostication', 'prediction', 'omen', 'prefigure', 'estimate', 'calculate', 'reckon', 'foreshadow', 'portend']]
#
#
# working on term particle acceleration
# 	 multi-term
# [['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle']]
# [['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle'], ['quickening', 'acceleration', 'speedup']]
#
#
# working on term particle precipitation
# 	 multi-term
# [['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle']]
# [['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle'], ['hurriedness', 'hurry', 'hastiness', 'haste', 'precipitation', 'downfall']]
#
#
# working on term planetary ionospheres
# 	 multi-term
# [['world', 'global', 'planetary', 'wandering', 'worldwide', 'erratic', 'terrestrial', 'world-wide', 'planetal']]
# [['world', 'global', 'planetary', 'wandering', 'worldwide', 'erratic', 'terrestrial', 'world-wide', 'planetal'], ['ionosphere']]
#
#
# working on term plasma interactions with dust and aerosols
# 	 multi-term
# [['plasm', 'plasma', 'blood_plasma']]
# [['plasm', 'plasma', 'blood_plasma'], ['fundamental_interaction', 'interaction']]
# [['plasm', 'plasma', 'blood_plasma'], ['fundamental_interaction', 'interaction'], ['with']]
# [['plasm', 'plasma', 'blood_plasma'], ['fundamental_interaction', 'interaction'], ['with'], ['rubble', 'detritus', 'debris', 'scatter', 'dust', 'disperse', 'sprinkle', 'dot', 'junk']]
# [['plasm', 'plasma', 'blood_plasma'], ['fundamental_interaction', 'interaction'], ['with'], ['rubble', 'detritus', 'debris', 'scatter', 'dust', 'disperse', 'sprinkle', 'dot', 'junk'], ['and']]
# [['plasm', 'plasma', 'blood_plasma'], ['fundamental_interaction', 'interaction'], ['with'], ['rubble', 'detritus', 'debris', 'scatter', 'dust', 'disperse', 'sprinkle', 'dot', 'junk'], ['and'], ['spray_can', 'aerosol_bomb', 'aerosol_can', 'aerosol_container', 'aerosol']]
#
#
# working on term plasma convection
# 	 multi-term
# [['plasm', 'plasma', 'blood_plasma']]
# [['plasm', 'plasma', 'blood_plasma'], ['convection']]
#
#
# working on term plasma temperature and density
# 	 multi-term
# [['plasm', 'plasma', 'blood_plasma']]
# [['plasm', 'plasma', 'blood_plasma'], ['temperature']]
# [['plasm', 'plasma', 'blood_plasma'], ['temperature'], ['and']]
# [['plasm', 'plasma', 'blood_plasma'], ['temperature'], ['and'], ['denseness', 'compactness', 'density', 'tightness', 'concentration']]
#
#
# working on term plasma waves and instabilities
# 	 multi-term
# [['plasm', 'plasma', 'blood_plasma']]
# [['plasm', 'plasma', 'blood_plasma'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation']]
# [['plasm', 'plasma', 'blood_plasma'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['and']]
# [['plasm', 'plasma', 'blood_plasma'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['and'], ['instability', 'unbalance', 'imbalance', 'unstableness']]
#
#
# working on term polar cap ionosphere
# 	 multi-term
# [['polar', 'pivotal', 'arctic', 'icy', 'opposite', 'diametrical', 'gelid', 'frigid', 'glacial', 'diametric']]
# [['polar', 'pivotal', 'arctic', 'icy', 'opposite', 'diametrical', 'gelid', 'frigid', 'glacial', 'diametric'], ['crown', 'crownwork', 'chapiter', 'cap', 'jacket', 'capital', 'crest', 'detonating_device', 'detonator', 'roof', 'jacket_crown', 'ceiling', 'hood', 'pileus']]
# [['polar', 'pivotal', 'arctic', 'icy', 'opposite', 'diametrical', 'gelid', 'frigid', 'glacial', 'diametric'], ['crown', 'crownwork', 'chapiter', 'cap', 'jacket', 'capital', 'crest', 'detonating_device', 'detonator', 'roof', 'jacket_crown', 'ceiling', 'hood', 'pileus'], ['ionosphere']]
#
#
# working on term solar radiation and cosmic ray effects
# 	 multi-term
# [['solar']]
# [['solar'], ['radiation_therapy', 'actinotherapy', 'radioactivity', 'radiation_sickness', 'radiation', 'radiotherapy', 'irradiation', 'radiation_syndrome']]
# [['solar'], ['radiation_therapy', 'actinotherapy', 'radioactivity', 'radiation_sickness', 'radiation', 'radiotherapy', 'irradiation', 'radiation_syndrome'], ['and']]
# [['solar'], ['radiation_therapy', 'actinotherapy', 'radioactivity', 'radiation_sickness', 'radiation', 'radiotherapy', 'irradiation', 'radiation_syndrome'], ['and'], ['cosmic']]
# [['solar'], ['radiation_therapy', 'actinotherapy', 'radioactivity', 'radiation_sickness', 'radiation', 'radiotherapy', 'irradiation', 'radiation_syndrome'], ['and'], ['cosmic'], ['beam_of_light', 'ray_of_light', 'electron_beam', 'light_beam', 'beam', 'ray', 'irradiate', 'shaft_of_light', 'shaft', 'irradiation', 'radiate', 're']]
# [['solar'], ['radiation_therapy', 'actinotherapy', 'radioactivity', 'radiation_sickness', 'radiation', 'radiotherapy', 'irradiation', 'radiation_syndrome'], ['and'], ['cosmic'], ['beam_of_light', 'ray_of_light', 'electron_beam', 'light_beam', 'beam', 'ray', 'irradiate', 'shaft_of_light', 'shaft', 'irradiation', 'radiate', 're'], ['result', 'core', 'personal_effects', 'effectuate', 'effects', 'essence', 'consequence', 'upshot', 'gist', 'outcome', 'set_up', 'burden', 'force', 'issue', 'impression', 'effect', 'event']]
#
#
# working on term topside ionosphere
# 	 multi-term
# [['topside']]
# [['topside'], ['ionosphere']]
#
#
# working on term wave/particle interactions
# 	 multi-term
# [['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation']]
# [['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle']]
# [['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle'], ['fundamental_interaction', 'interaction']]
#
#
# working on term wave propagation
# 	 multi-term
# [['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation']]
# [['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['propagation', 'extension', 'multiplication', 'generation']]
#
#
# working on term instruments and techniques
# 	 multi-term
# [['instrumental_role', 'pawn', 'legal_instrument', 'musical_instrument', 'instrumentate', "cat's-paw", 'official_document', 'instrument', 'legal_document', 'tool']]
# [['instrumental_role', 'pawn', 'legal_instrument', 'musical_instrument', 'instrumentate', "cat's-paw", 'official_document', 'instrument', 'legal_document', 'tool'], ['and']]
# [['instrumental_role', 'pawn', 'legal_instrument', 'musical_instrument', 'instrumentate', "cat's-paw", 'official_document', 'instrument', 'legal_document', 'tool'], ['and'], ['proficiency', 'technique']]
#
#
# working on term magnetospheric physics
# 	 multi-term
# [['magnetospheric']]
# [['magnetospheric'], ['natural_philosophy', 'physics', 'purgative', 'physical_science', 'physic', 'cathartic', 'aperient']]
#
#
# working on term auroral phenomena
# 	 multi-term
# [['auroral', 'aurorean']]
# [['auroral', 'aurorean'], ['phenomenon']]
#
#
# working on term cusp
# 	 single term
#
#
# working on term electric fields
# 	 multi-term
# [['galvanic', 'electric_car', 'galvanising', 'electric', 'electric_automobile', 'galvanizing', 'electrical']]
# [['galvanic', 'electric_car', 'galvanising', 'electric', 'electric_automobile', 'galvanizing', 'electrical'], ['W._C._Fields', 'landing_field', 'bailiwick', 'battlefield', 'Fields', 'theatre_of_operations', 'line_of_business', 'study', 'playing_area', 'arena', 'field_of_honor', 'theatre', 'field_of_study', 'field_of_operation', 'subject_area', 'field_of_view', 'champaign', 'subject', 'force_field', 'airfield', 'field_of_battle', 'flying_field', 'athletic_field', 'field', 'subject_field', 'playing_field', 'orbit', 'discipline', 'field_of_operations', 'domain', 'plain', 'battleground', 'William_Claude_Dukenfield', 'field_of_force', 'theater', 'theater_of_operations', 'sphere', 'area']]
#
#
# working on term energetic particles: precipitating
# 	 multi-term
# [['energetic', 'gumptious', 'industrious', 'up-and-coming']]
# [['energetic', 'gumptious', 'industrious', 'up-and-coming'], ['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle']]
# ...
# [['institutionalize', 'rouse', 'charge_up', 'consign', 'saddle', 'shoot_down', 'institutionalise', 'supercharged', 'commove', 'commit', 'charge', 'excite', 'point', 'level', 'lodge', 'appoint', 'send', 'bear_down', 'buck', 'aerated', 'file', 'burden', 'blame', 'charged', 'agitate', 'bill', 'shoot', 'accuse', 'load', 'tear', 'turn_on'], ['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle'], ['movement', 'motility', 'motion', 'apparent_motion', 'apparent_movement', 'gesture', 'gesticulate', 'move', 'question']]
# [['institutionalize', 'rouse', 'charge_up', 'consign', 'saddle', 'shoot_down', 'institutionalise', 'supercharged', 'commove', 'commit', 'charge', 'excite', 'point', 'level', 'lodge', 'appoint', 'send', 'bear_down', 'buck', 'aerated', 'file', 'burden', 'blame', 'charged', 'agitate', 'bill', 'shoot', 'accuse', 'load', 'tear', 'turn_on'], ['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle'], ['movement', 'motility', 'motion', 'apparent_motion', 'apparent_movement', 'gesture', 'gesticulate', 'move', 'question'], ['and']]
# [['institutionalize', 'rouse', 'charge_up', 'consign', 'saddle', 'shoot_down', 'institutionalise', 'supercharged', 'commove', 'commit', 'charge', 'excite', 'point', 'level', 'lodge', 'appoint', 'send', 'bear_down', 'buck', 'aerated', 'file', 'burden', 'blame', 'charged', 'agitate', 'bill', 'shoot', 'accuse', 'load', 'tear', 'turn_on'], ['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle'], ['movement', 'motility', 'motion', 'apparent_motion', 'apparent_movement', 'gesture', 'gesticulate', 'move', 'question'], ['and'], ['quickening', 'acceleration', 'speedup']]
#
#
# working on term discontinuities
# 	 single term
#
#
# working on term electrostatic structures
# 	 multi-term
# [['electrostatic', 'static']]
# [['electrostatic', 'static'], ['bodily_structure', 'structure', 'social_structure', 'construction', 'social_organisation', 'social_system', 'complex_body_part', 'body_structure', 'social_organization', 'anatomical_structure']]
#
#
# working on term ionization processes
# 	 multi-term
# [['ionisation', 'ionization']]
# [['ionisation', 'ionization'], ['summons', 'swear_out', 'appendage', 'sue', 'unconscious_process', 'march', 'work_on', 'litigate', 'treat', 'operation', 'cognitive_process', 'process', 'work', 'physical_process', 'outgrowth', 'action', 'procedure', 'cognitive_operation', 'mental_process', 'serve']]
#
#
# working on term kinetic and mhd theory
# 	 multi-term
# [['kinetic', 'energizing', 'energising']]
# [['kinetic', 'energizing', 'energising'], ['and']]
# [['kinetic', 'energizing', 'energising'], ['and'], ['mhd']]
# [['kinetic', 'energizing', 'energising'], ['and'], ['mhd'], ['possibility', 'theory', 'hypothesis']]
#
#
# working on term kinetic waves and instabilities
# 	 multi-term
# [['kinetic', 'energizing', 'energising']]
# [['kinetic', 'energizing', 'energising'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation']]
# [['kinetic', 'energizing', 'energising'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['and']]
# [['kinetic', 'energizing', 'energising'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['and'], ['instability', 'unbalance', 'imbalance', 'unstableness']]
#
#
# working on term laboratory studies and experimental techniques
# 	 multi-term
# [['research_lab', 'science_laboratory', 'lab', 'laboratory', 'testing_ground', 'research_laboratory', 'science_lab']]
# [['research_lab', 'science_laboratory', 'lab', 'laboratory', 'testing_ground', 'research_laboratory', 'science_lab'], ['canvass', 'bailiwick', 'study', 'written_report', 'canvas', 'survey', 'field_of_study', 'subject_area', 'sketch', 'subject', 'analyse', 'examine', 'hit_the_books', 'meditate', 'field', 'subject_field', 'work', 'consider', 'discipline', 'read', 'take', 'contemplate', 'learn', 'report', 'analyze', 'cogitation']]
# [['research_lab', 'science_laboratory', 'lab', 'laboratory', 'testing_ground', 'research_laboratory', 'science_lab'], ['canvass', 'bailiwick', 'study', 'written_report', 'canvas', 'survey', 'field_of_study', 'subject_area', 'sketch', 'subject', 'analyse', 'examine', 'hit_the_books', 'meditate', 'field', 'subject_field', 'work', 'consider', 'discipline', 'read', 'take', 'contemplate', 'learn', 'report', 'analyze', 'cogitation'], ['and']]
# [['research_lab', 'science_laboratory', 'lab', 'laboratory', 'testing_ground', 'research_laboratory', 'science_lab'], ['canvass', 'bailiwick', 'study', 'written_report', 'canvas', 'survey', 'field_of_study', 'subject_area', 'sketch', 'subject', 'analyse', 'examine', 'hit_the_books', 'meditate', 'field', 'subject_field', 'work', 'consider', 'discipline', 'read', 'take', 'contemplate', 'learn', 'report', 'analyze', 'cogitation'], ['and'], ['data-based', 'observational', 'experimental']]
# [['research_lab', 'science_laboratory', 'lab', 'laboratory', 'testing_ground', 'research_laboratory', 'science_lab'], ['canvass', 'bailiwick', 'study', 'written_report', 'canvas', 'survey', 'field_of_study', 'subject_area', 'sketch', 'subject', 'analyse', 'examine', 'hit_the_books', 'meditate', 'field', 'subject_field', 'work', 'consider', 'discipline', 'read', 'take', 'contemplate', 'learn', 'report', 'analyze', 'cogitation'], ['and'], ['data-based', 'observational', 'experimental'], ['proficiency', 'technique']]
#
#
# working on term magnetic reconnection
# 	 multi-term
# [['magnetised', 'magnetized', 'charismatic', 'magnetic']]
# [['magnetised', 'magnetized', 'charismatic', 'magnetic'], ['reconnection']]
#
#
# working on term mathematical and numerical techniques
# 	 multi-term
# [['mathematical', 'numerical']]
# [['mathematical', 'numerical'], ['and']]
# [['mathematical', 'numerical'], ['and'], ['mathematical', 'numeral', 'numeric', 'numerical']]
# [['mathematical', 'numerical'], ['and'], ['mathematical', 'numeral', 'numeric', 'numerical'], ['proficiency', 'technique']]
#
#
# working on term mhd waves and instabilities
# 	 multi-term
# [['mhd']]
# [['mhd'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation']]
# [['mhd'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['and']]
# [['mhd'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['and'], ['instability', 'unbalance', 'imbalance', 'unstableness']]
#
#
# working on term neutral particles
# 	 multi-term
# [['impersonal', 'neutral', 'inert', 'electroneutral', 'indifferent', 'achromatic']]
# [['impersonal', 'neutral', 'inert', 'electroneutral', 'indifferent', 'achromatic'], ['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle']]
#
#
# working on term nonlinear phenomena
# 	 multi-term
# [['nonlinear']]
# [['nonlinear'], ['phenomenon']]
#
#
# working on term parametric processes
# 	 multi-term
# [['parametric']]
# [['parametric'], ['summons', 'swear_out', 'appendage', 'sue', 'unconscious_process', 'march', 'work_on', 'litigate', 'treat', 'operation', 'cognitive_process', 'process', 'work', 'physical_process', 'outgrowth', 'action', 'procedure', 'cognitive_operation', 'mental_process', 'serve']]
#
#
# working on term particle acceleration
# 	 multi-term
# [['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle']]
# [['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle'], ['quickening', 'acceleration', 'speedup']]
#
#
# working on term plasma energization
# 	 multi-term
# [['plasm', 'plasma', 'blood_plasma']]
# [['plasm', 'plasma', 'blood_plasma'], ['energization']]
#
#
# working on term plasma interactions with dust and aerosols
# 	 multi-term
# [['plasm', 'plasma', 'blood_plasma']]
# [['plasm', 'plasma', 'blood_plasma'], ['fundamental_interaction', 'interaction']]
# [['plasm', 'plasma', 'blood_plasma'], ['fundamental_interaction', 'interaction'], ['with']]
# [['plasm', 'plasma', 'blood_plasma'], ['fundamental_interaction', 'interaction'], ['with'], ['rubble', 'detritus', 'debris', 'scatter', 'dust', 'disperse', 'sprinkle', 'dot', 'junk']]
# [['plasm', 'plasma', 'blood_plasma'], ['fundamental_interaction', 'interaction'], ['with'], ['rubble', 'detritus', 'debris', 'scatter', 'dust', 'disperse', 'sprinkle', 'dot', 'junk'], ['and']]
# [['plasm', 'plasma', 'blood_plasma'], ['fundamental_interaction', 'interaction'], ['with'], ['rubble', 'detritus', 'debris', 'scatter', 'dust', 'disperse', 'sprinkle', 'dot', 'junk'], ['and'], ['spray_can', 'aerosol_bomb', 'aerosol_can', 'aerosol_container', 'aerosol']]
#
#
# working on term radiation processes
# 	 multi-term
# [['radiation_therapy', 'actinotherapy', 'radioactivity', 'radiation_sickness', 'radiation', 'radiotherapy', 'irradiation', 'radiation_syndrome']]
# [['radiation_therapy', 'actinotherapy', 'radioactivity', 'radiation_sickness', 'radiation', 'radiotherapy', 'irradiation', 'radiation_syndrome'], ['summons', 'swear_out', 'appendage', 'sue', 'unconscious_process', 'march', 'work_on', 'litigate', 'treat', 'operation', 'cognitive_process', 'process', 'work', 'physical_process', 'outgrowth', 'action', 'procedure', 'cognitive_operation', 'mental_process', 'serve']]
#
#
# working on term shock waves
# 	 multi-term
# [['ball_over', 'jar', 'take_aback', 'shock_absorber', 'electrical_shock', 'shock', 'blow', 'jounce', 'stupor', 'offend', 'floor', 'traumatise', 'scandalize', 'traumatize', 'outrage', 'scandalise', 'cushion', 'impact', 'appall', 'electric_shock', 'blow_out_of_the_water', 'jolt', 'appal', 'daze', 'seismic_disturbance']]
# [['ball_over', 'jar', 'take_aback', 'shock_absorber', 'electrical_shock', 'shock', 'blow', 'jounce', 'stupor', 'offend', 'floor', 'traumatise', 'scandalize', 'traumatize', 'outrage', 'scandalise', 'cushion', 'impact', 'appall', 'electric_shock', 'blow_out_of_the_water', 'jolt', 'appal', 'daze', 'seismic_disturbance'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation']]
#
#
# working on term solitons and solitary waves
# 	 multi-term
# [['soliton_wave', 'soliton', 'solitary_wave']]
# [['soliton_wave', 'soliton', 'solitary_wave'], ['and']]
# [['soliton_wave', 'soliton', 'solitary_wave'], ['and'], ['lonely', 'nonsocial', 'unfrequented', 'solitudinarian', 'sole', 'solitary', 'troglodyte', 'solitary_confinement', 'alone', 'lone', 'only', 'nongregarious', 'hermit', 'recluse', 'lonesome']]
# [['soliton_wave', 'soliton', 'solitary_wave'], ['and'], ['lonely', 'nonsocial', 'unfrequented', 'solitudinarian', 'sole', 'solitary', 'troglodyte', 'solitary_confinement', 'alone', 'lone', 'only', 'nongregarious', 'hermit', 'recluse', 'lonesome'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation']]
#
#
# working on term spacecraft/atmosphere interactions
# 	 multi-term
# [['ballistic_capsule', 'spacecraft', 'space_vehicle']]
# [['ballistic_capsule', 'spacecraft', 'space_vehicle'], ['ambiance', 'atmospheric_state', 'standard_atmosphere', 'standard_pressure', 'atmosphere', 'atm', 'aura', 'ambience', 'air']]
# [['ballistic_capsule', 'spacecraft', 'space_vehicle'], ['ambiance', 'atmospheric_state', 'standard_atmosphere', 'standard_pressure', 'atmosphere', 'atm', 'aura', 'ambience', 'air'], ['fundamental_interaction', 'interaction']]
#
#
# working on term spacecraft sheaths, wakes, charging
# 	 multi-term
# [['ballistic_capsule', 'spacecraft', 'space_vehicle']]
# [['ballistic_capsule', 'spacecraft', 'space_vehicle'], ['cocktail_dress', 'sheath', 'case']]
# [['ballistic_capsule', 'spacecraft', 'space_vehicle'], ['cocktail_dress', 'sheath', 'case'], ['wake', 'aftermath', 'viewing', 'come_alive', 'Wake_Island', 'rouse', 'wake_up', 'arouse', 'awaken', 'fire_up', 'waken', 'stir_up', 'ignite', 'Wake', 'inflame', 'awake', 'heat', 'backwash']]
# [['ballistic_capsule', 'spacecraft', 'space_vehicle'], ['cocktail_dress', 'sheath', 'case'], ['wake', 'aftermath', 'viewing', 'come_alive', 'Wake_Island', 'rouse', 'wake_up', 'arouse', 'awaken', 'fire_up', 'waken', 'stir_up', 'ignite', 'Wake', 'inflame', 'awake', 'heat', 'backwash'], ['institutionalize', 'rouse', 'charge_up', 'consign', 'saddle', 'shoot_down', 'institutionalise', 'commove', 'commit', 'charge', 'excite', 'point', 'level', 'lodge', 'appoint', 'send', 'bear_down', 'buck', 'file', 'burden', 'blame', 'agitate', 'bill', 'shoot', 'accuse', 'load', 'tear', 'turn_on']]
#
#
# working on term stochastic phenomena
# 	 multi-term
# [['stochastic']]
# [['stochastic'], ['phenomenon']]
#
#
# working on term transport processes
# 	 multi-term
# [['transport', 'enchant', 'shipping', 'raptus', 'enthral', 'tape_drive', 'exaltation', 'transferral', 'channelize', 'ecstasy', 'conveyance', 'transportation', 'enrapture', 'send', 'tape_transport', 'carry', 'ravish', 'delight', 'enthrall', 'transfer', 'transmit', 'rapture', 'ship', 'channel', 'channelise']]
# [['transport', 'enchant', 'shipping', 'raptus', 'enthral', 'tape_drive', 'exaltation', 'transferral', 'channelize', 'ecstasy', 'conveyance', 'transportation', 'enrapture', 'send', 'tape_transport', 'carry', 'ravish', 'delight', 'enthrall', 'transfer', 'transmit', 'rapture', 'ship', 'channel', 'channelise'], ['summons', 'swear_out', 'appendage', 'sue', 'unconscious_process', 'march', 'work_on', 'litigate', 'treat', 'operation', 'cognitive_process', 'process', 'work', 'physical_process', 'outgrowth', 'action', 'procedure', 'cognitive_operation', 'mental_process', 'serve']]
#
#
# working on term turbulence
# 	 single term
#
#
# working on term wave/particle interactions
# 	 multi-term
# [['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation']]
# [['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle']]
# [['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['particle', 'atom', 'speck', 'molecule', 'mote', 'corpuscle', 'subatomic_particle'], ['fundamental_interaction', 'interaction']]
#
#
# working on term wave/wave interactions
# 	 multi-term
# [['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation']]
# [['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation']]
# [['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['wave', 'waving', 'roll', 'undulate', 'Wave', 'curl', 'moving_ridge', 'beckon', 'flap', 'flourish', 'brandish', 'wafture', 'undulation'], ['fundamental_interaction', 'interaction']]
#
#
# working on term instruments and techniques
# 	 multi-term
# [['instrumental_role', 'pawn', 'legal_instrument', 'musical_instrument', 'instrumentate', "cat's-paw", 'official_document', 'instrument', 'legal_document', 'tool']]
# [['instrumental_role', 'pawn', 'legal_instrument', 'musical_instrument', 'instrumentate', "cat's-paw", 'official_document', 'instrument', 'legal_document', 'tool'], ['and']]
# [['instrumental_role', 'pawn', 'legal_instrument', 'musical_instrument', 'instrumentate', "cat's-paw", 'official_document', 'instrument', 'legal_document', 'tool'], ['and'], ['proficiency', 'technique']]

# %%
list_multi_syns_update
# Out:
# ['\n\n# multi-term items added from AGU Index Terms in July 2022',
#  'residential_area model model, residential_area model fabric, residential_area model theoretical_account, residential_area model framework, residential_area simulate model, residential_area simulate fabric, residential_area simulate theoretical_account, residential_area simulate framework, residential_area pose model, residential_area pose fabric, residential_area pose theoretical_account, residential_area pose framework, residential_area mold model, residential_area mold fabric, residential_area mold theoretical_account, residential_area mold framework, residential_area moulding model, residential_area moulding fabric, residential_area moulding theoretical_account, residential_area moulding framework, residential_area clay_sculpture model, residential_area clay_sculpture fabric, residential_area clay_sculpture theoretical_account, residential_area clay_sculpture framework, residential_area sit model, residential_area sit fabric, residential_area sit theoretical_account, residential_area sit framework, residential_area molding model, residential_area molding fabric, residential_area molding theoretical_account, residential_area molding framework, residential_area mock_up model, residential_area mock_up fabric, residential_area mock_up theoretical_account, residential_area mock_up framework, residential_area pattern model, residential_area pattern fabric, residential_area pattern theoretical_account, residential_area pattern framework, residential_area modelling model, residential_area modelling fabric, residential_area modelling theoretical_account, residential_area modelling framework, residential_area mould model, residential_area mould fabric, residential_area mould theoretical_account, residential_area mould framework, residential_area modeling model, residential_area modeling fabric, residential_area modeling theoretical_account, residential_area modeling framework, residential_area posture model, residential_area posture fabric, residential_area posture theoretical_account, residential_area posture framework, residential_district model model, residential_district model fabric, residential_district model theoretical_account, residential_district model framework, residential_district simulate model, residential_district simulate fabric, residential_district simulate theoretical_account, residential_district simulate framework, residential_district pose model, residential_district pose fabric, residential_district pose theoretical_account, residential_district pose framework, residential_district mold model, residential_district mold fabric, residential_district mold theoretical_account, residential_district mold framework, residential_district moulding model, residential_district moulding fabric, residential_district moulding theoretical_account, residential_district moulding framework, residential_district clay_sculpture model, residential_district clay_sculpture fabric, residential_district clay_sculpture theoretical_account, residential_district clay_sculpture framework, residential_district sit model, residential_district sit fabric, residential_district sit theoretical_account, residential_district sit framework, residential_district molding model, residential_district molding fabric, residential_district molding theoretical_account, residential_district molding framework, residential_district mock_up model, residential_district mock_up fabric, residential_district mock_up theoretical_account, residential_district mock_up framework, residential_district pattern model, residential_district pattern fabric, residential_district pattern theoretical_account, residential_district pattern framework, residential_district modelling model, residential_district modelling fabric, residential_district modelling theoretical_account, residential_district modelling framework, residential_district mould model, residential_district mould fabric, residential_district mould theoretical_account, residential_district mould framework, resi ...
#  'residential_area measure, residential_area criterion, residential_area touchstone, residential_area standard, residential_area monetary_standard, residential_area banner, residential_district measure, residential_district criterion, residential_district touchstone, residential_district standard, residential_district monetary_standard, residential_district banner, community measure, community criterion, community touchstone, community standard, community monetary_standard, community banner, community_of_interests measure, community_of_interests criterion, community_of_interests touchstone, community_of_interests standard, community_of_interests monetary_standard, community_of_interests banner, biotic_community measure, biotic_community criterion, biotic_community touchstone, biotic_community standard, biotic_community monetary_standard, biotic_community banner, community standards\n',
#  'computational simulation algorithm, computational simulation algorithmic_rule, computational simulation algorithmic_program, computational simulate algorithm, computational simulate algorithmic_rule, computational simulate algorithmic_program, computational mold algorithm, computational mold algorithmic_rule, computational mold algorithmic_program, computational mock_up algorithm, computational mock_up algorithmic_rule, computational mock_up algorithmic_program, computational manikin algorithm, computational manikin algorithmic_rule, computational manikin algorithmic_program, computational modelling algorithm, computational modelling algorithmic_rule, computational modelling algorithmic_program, computational posture algorithm, computational posture algorithmic_rule, computational posture algorithmic_program, computational model algorithm, computational model algorithmic_rule, computational model algorithmic_program, computational mannequin algorithm, computational mannequin algorithmic_rule, computational mannequin algorithmic_program, computational pose algorithm, computational pose algorithmic_rule, computational pose algorithmic_program, computational modeling algorithm, computational modeling algorithmic_rule, computational modeling algorithmic_program, computational sit algorithm, computational sit algorithmic_rule, computational sit algorithmic_program, computational good_example algorithm, computational good_example algorithmic_rule, computational good_example algorithmic_program, computational fashion_model algorithm, computational fashion_model algorithmic_rule, computational fashion_model algorithmic_program, computational exemplar algorithm, computational exemplar algorithmic_rule, computational exemplar algorithmic_program, computational role_model algorithm, computational role_model algorithmic_rule, computational role_model algorithmic_program, computational framework algorithm, computational framework algorithmic_rule, computational framework algorithmic_program, computational poser algorithm, computational poser algorithmic_rule, computational poser algorithmic_program, computational mould algorithm, computational mould algorithmic_rule, computational mould algorithmic_program, computational example algorithm, computational example algorithmic_rule, computational example algorithmic_program, computational manakin algorithm, computational manakin algorithmic_rule, computational manakin algorithmic_program, computational theoretical_account algorithm, computational theoretical_account algorithmic_rule, computational theoretical_account algorithmic_program, computational pattern algorithm, computational pattern algorithmic_rule, computational pattern algorithmic_program, computational mannikin algorithm, computational mannikin algorithmic_rule, computational mannikin algorithmic_program, computational models algorithms\n',
#  'datum acculturation desegregation and merger, datum acculturation desegregation and unification, datum acculturation desegregation and spinal_fusion, datum acculturation desegregation and nuclear_fusion, datum acculturation desegregation and optical_fusion, datum acculturation desegregation and nuclear_fusion_reaction, datum acculturation desegregation and coalition, datum acculturation desegregation and fusion, datum acculturation integrating and merger, datum acculturation integrating and unification, datum acculturation integrating and spinal_fusion, datum acculturation integrating and nuclear_fusion, datum acculturation integrating and optical_fusion, datum acculturation integrating and nuclear_fusion_reaction, datum acculturation integrating and coalition, datum acculturation integrating and fusion, datum acculturation consolidation and merger, datum acculturation consolidation and unification, datum acculturation consolidation and spinal_fusion, datum acculturation consolidation and nuclear_fusion, datum acculturation consolidation and optical_fusion, datum acculturation consolidation and nuclear_fusion_reaction, datum acculturation consolidation and coalition, datum acculturation consolidation and fusion, datum acculturation integration and merger, datum acculturation integration and unification, datum acculturation integration and spinal_fusion, datum acculturation integration and nuclear_fusion, datum acculturation integration and optical_fusion, datum acculturation integration and nuclear_fusion_reaction, datum acculturation integration and coalition, datum acculturation integration and fusion, datum absorption desegregation and merger, datum absorption desegregation and unification, datum absorption desegregation and spinal_fusion, datum absorption desegregation and nuclear_fusion, datum absorption desegregation and optical_fusion, datum absorption desegregation and nuclear_fusion_reaction, datum absorption desegregation and coalition, datum absorption desegregation and fusion, datum absorption integrating and merger, datum absorption integrating and unification, datum absorption integrating and spinal_fusion, datum absorption integrating and nuclear_fusion, datum absorption integrating and optical_fusion, datum absorption integrating and nuclear_fusion_reaction, datum absorption integrating and coalition, datum absorption integrating and fusion, datum absorption consolidation and merger, datum absorption consolidation and unification, datum absorption consolidation and spinal_fusion, datum absorption consolidation and nuclear_fusion, datum absorption consolidation and optical_fusion, datum absorption consolidation and nuclear_fusion_reaction, datum absorption consolidation and coalition, datum absorption consolidation and fusion, datum absorption integration and merger, datum absorption integration and unification, datum absorption integration and spinal_fusion, datum absorption integration and nuclear_fusion, datum absorption integration and optical_fusion, datum absorption integration and nuclear_fusion_reaction, datum absorption integration and coalition, datum absorption integration and fusion, datum assimilation desegregation and merger, datum assimilation desegregation and unification, datum assimilation desegregation and spinal_fusion, datum assimilation desegregation and nuclear_fusion, datum assimilation desegregation and optical_fusion, datum assimilation desegregation and nuclear_fusion_reaction, datum assimilation desegregation and coalition, datum assimilation desegregation and fusion, datum assimilation integrating and merger, datum assimilation integrating and unification, datum assimilation integrating and spinal_fusion, datum assimilation integrating and nuclear_fusion, datum assimilation integrating and optical_fusion, datum assimilation integrating and nuclear_fusion_reaction, datum assimilation integrating and coalition, datum assimilation integrating and fusion, datum assimilation consolidati ...
#  'datum management conservation rescue, datum management conservation deliver, datum management conservation delivery, datum management conservation deliverance, datum management conservation saving, datum management saving rescue, datum management saving deliver, datum management saving delivery, datum management saving deliverance, datum management saving saving, datum management preservation rescue, datum management preservation deliver, datum management preservation delivery, datum management preservation deliverance, datum management preservation saving, datum direction conservation rescue, datum direction conservation deliver, datum direction conservation delivery, datum direction conservation deliverance, datum direction conservation saving, datum direction saving rescue, datum direction saving deliver, datum direction saving delivery, datum direction saving deliverance, datum direction saving saving, datum direction preservation rescue, datum direction preservation deliver, datum direction preservation delivery, datum direction preservation deliverance, datum direction preservation saving, information management conservation rescue, information management conservation deliver, information management conservation delivery, information management conservation deliverance, information management conservation saving, information management saving rescue, information management saving deliver, information management saving delivery, information management saving deliverance, information management saving saving, information management preservation rescue, information management preservation deliver, information management preservation delivery, information management preservation deliverance, information management preservation saving, information direction conservation rescue, information direction conservation deliver, information direction conservation delivery, information direction conservation deliverance, information direction conservation saving, information direction saving rescue, information direction saving deliver, information direction saving delivery, information direction saving deliverance, information direction saving saving, information direction preservation rescue, information direction preservation deliver, information direction preservation delivery, information direction preservation deliverance, information direction preservation saving, data management conservation rescue, data management conservation deliver, data management conservation delivery, data management conservation deliverance, data management conservation saving, data management saving rescue, data management saving deliver, data management saving delivery, data management saving deliverance, data management saving saving, data management preservation rescue, data management preservation deliver, data management preservation delivery, data management preservation deliverance, data management preservation saving, data direction conservation rescue, data direction conservation deliver, data direction conservation delivery, data direction conservation deliverance, data direction conservation saving, data direction saving rescue, data direction saving deliver, data direction saving delivery, data direction saving deliverance, data direction saving saving, data direction preservation rescue, data direction preservation deliver, data direction preservation delivery, data direction preservation deliverance, data direction preservation saving, data_point management conservation rescue, data_point management conservation deliver, data_point management conservation delivery, data_point management conservation deliverance, data_point management conservation saving, data_point management saving rescue, data_point management saving deliver, data_point management saving delivery, data_point management saving deliverance, data_point management saving saving, data_point management preservation rescue, data_point management preservation deliver, data_p ...
#  'datum excavation, datum mine, datum minelaying, datum mining, information excavation, information mine, information minelaying, information mining, data excavation, data mine, data minelaying, data mining, data_point excavation, data_point mine, data_point minelaying, data_point mining, data mining\n',
#  'datum and information breakthrough, datum and information uncovering, datum and information find, datum and information discovery, datum and selective_information breakthrough, datum and selective_information uncovering, datum and selective_information find, datum and selective_information discovery, datum and data breakthrough, datum and data uncovering, datum and data find, datum and data discovery, datum and entropy breakthrough, datum and entropy uncovering, datum and entropy find, datum and entropy discovery, datum and info breakthrough, datum and info uncovering, datum and info find, datum and info discovery, information and information breakthrough, information and information uncovering, information and information find, information and information discovery, information and selective_information breakthrough, information and selective_information uncovering, information and selective_information find, information and selective_information discovery, information and data breakthrough, information and data uncovering, information and data find, information and data discovery, information and entropy breakthrough, information and entropy uncovering, information and entropy find, information and entropy discovery, information and info breakthrough, information and info uncovering, information and info find, information and info discovery, data and information breakthrough, data and information uncovering, data and information find, data and information discovery, data and selective_information breakthrough, data and selective_information uncovering, data and selective_information find, data and selective_information discovery, data and data breakthrough, data and data uncovering, data and data find, data and data discovery, data and entropy breakthrough, data and entropy uncovering, data and entropy find, data and entropy discovery, data and info breakthrough, data and info uncovering, data and info find, data and info discovery, data_point and information breakthrough, data_point and information uncovering, data_point and information find, data_point and information discovery, data_point and selective_information breakthrough, data_point and selective_information uncovering, data_point and selective_information find, data_point and selective_information discovery, data_point and data breakthrough, data_point and data uncovering, data_point and data find, data_point and data discovery, data_point and entropy breakthrough, data_point and entropy uncovering, data_point and entropy find, data_point and entropy discovery, data_point and info breakthrough, data_point and info uncovering, data_point and info find, data_point and info discovery, data and information discovery\n',
#  'decisiveness analysis, decisiveness analytic_thinking, decisiveness psychoanalysis, decisiveness depth_psychology, decision analysis, decision analytic_thinking, decision psychoanalysis, decision depth_psychology, conclusion analysis, conclusion analytic_thinking, conclusion psychoanalysis, conclusion depth_psychology, determination analysis, determination analytic_thinking, determination psychoanalysis, determination depth_psychology, decision analysis\n',
#  'emerge IP applied_science, emerge IP engineering_science, emerge IP technology, emerge IP engineering, emerge information_processing applied_science, emerge information_processing engineering_science, emerge information_processing technology, emerge information_processing engineering, emerge information_science applied_science, emerge information_science engineering_science, emerge information_science technology, emerge information_science engineering, emerge informatics applied_science, emerge informatics engineering_science, emerge informatics technology, emerge informatics engineering, come_out IP applied_science, come_out IP engineering_science, come_out IP technology, come_out IP engineering, come_out information_processing applied_science, come_out information_processing engineering_science, come_out information_processing technology, come_out information_processing engineering, come_out information_science applied_science, come_out information_science engineering_science, come_out information_science technology, come_out information_science engineering, come_out informatics applied_science, come_out informatics engineering_science, come_out informatics technology, come_out informatics engineering, come_forth IP applied_science, come_forth IP engineering_science, come_forth IP technology, come_forth IP engineering, come_forth information_processing applied_science, come_forth information_processing engineering_science, come_forth information_processing technology, come_forth information_processing engineering, come_forth information_science applied_science, come_forth information_science engineering_science, come_forth information_science technology, come_forth information_science engineering, come_forth informatics applied_science, come_forth informatics engineering_science, come_forth informatics technology, come_forth informatics engineering, emergent IP applied_science, emergent IP engineering_science, emergent IP technology, emergent IP engineering, emergent information_processing applied_science, emergent information_processing engineering_science, emergent information_processing technology, emergent information_processing engineering, emergent information_science applied_science, emergent information_science engineering_science, emergent information_science technology, emergent information_science engineering, emergent informatics applied_science, emergent informatics engineering_science, emergent informatics technology, emergent informatics engineering, egress IP applied_science, egress IP engineering_science, egress IP technology, egress IP engineering, egress information_processing applied_science, egress information_processing engineering_science, egress information_processing technology, egress information_processing engineering, egress information_science applied_science, egress information_science engineering_science, egress information_science technology, egress information_science engineering, egress informatics applied_science, egress informatics engineering_science, egress informatics technology, egress informatics engineering, emerging IP applied_science, emerging IP engineering_science, emerging IP technology, emerging IP engineering, emerging information_processing applied_science, emerging information_processing engineering_science, emerging information_processing technology, emerging information_processing engineering, emerging information_science applied_science, emerging information_science engineering_science, emerging information_science technology, emerging information_science engineering, emerging informatics applied_science, emerging informatics engineering_science, emerging informatics technology, emerging informatics engineering, issue IP applied_science, issue IP engineering_science, issue IP technology, issue IP engineering, issue information_processing applied_science, issue information_processing engineering_science, issue information_processing technology, issue information_processi ...
#  'courtly logical_system and grammar, courtly system_of_logic and grammar, courtly logic and grammar, dinner_dress logical_system and grammar, dinner_dress system_of_logic and grammar, dinner_dress logic and grammar, conventional logical_system and grammar, conventional system_of_logic and grammar, conventional logic and grammar, schematic logical_system and grammar, schematic system_of_logic and grammar, schematic logic and grammar, stately logical_system and grammar, stately system_of_logic and grammar, stately logic and grammar, dinner_gown logical_system and grammar, dinner_gown system_of_logic and grammar, dinner_gown logic and grammar, evening_gown logical_system and grammar, evening_gown system_of_logic and grammar, evening_gown logic and grammar, formal logical_system and grammar, formal system_of_logic and grammar, formal logic and grammar, ball logical_system and grammar, ball system_of_logic and grammar, ball logic and grammar, formal logics and grammars\n',
#  'GI scientific_discipline, GI science, GI skill, Gi scientific_discipline, Gi science, Gi skill, G.I. scientific_discipline, G.I. science, G.I. skill, gilbert scientific_discipline, gilbert science, gilbert skill, Gb scientific_discipline, Gb science, Gb skill, gis science\n',
#  'datum and information organisation, datum and information administration, datum and information governing_body, datum and information organization, datum and information governance, datum and information government, datum and information establishment, datum and information government_activity, datum and information governing, datum and information brass, datum and selective_information organisation, datum and selective_information administration, datum and selective_information governing_body, datum and selective_information organization, datum and selective_information governance, datum and selective_information government, datum and selective_information establishment, datum and selective_information government_activity, datum and selective_information governing, datum and selective_information brass, datum and data organisation, datum and data administration, datum and data governing_body, datum and data organization, datum and data governance, datum and data government, datum and data establishment, datum and data government_activity, datum and data governing, datum and data brass, datum and entropy organisation, datum and entropy administration, datum and entropy governing_body, datum and entropy organization, datum and entropy governance, datum and entropy government, datum and entropy establishment, datum and entropy government_activity, datum and entropy governing, datum and entropy brass, datum and info organisation, datum and info administration, datum and info governing_body, datum and info organization, datum and info governance, datum and info government, datum and info establishment, datum and info government_activity, datum and info governing, datum and info brass, information and information organisation, information and information administration, information and information governing_body, information and information organization, information and information governance, information and information government, information and information establishment, information and information government_activity, information and information governing, information and information brass, information and selective_information organisation, information and selective_information administration, information and selective_information governing_body, information and selective_information organization, information and selective_information governance, information and selective_information government, information and selective_information establishment, information and selective_information government_activity, information and selective_information governing, information and selective_information brass, information and data organisation, information and data administration, information and data governing_body, information and data organization, information and data governance, information and data government, information and data establishment, information and data government_activity, information and data governing, information and data brass, information and entropy organisation, information and entropy administration, information and entropy governing_body, information and entropy organization, information and entropy governance, information and entropy government, information and entropy establishment, information and entropy government_activity, information and entropy governing, information and entropy brass, information and info organisation, information and info administration, information and info governing_body, information and info organization, information and info governance, information and info government, information and info establishment, information and info government_activity, information and info governing, information and info brass, data and information organisation, data and information administration, data and information governing_body, data and information organization, data and information governance, data and information government, data and information establishment, data and information government_ ...
#  'high-performance computing, high-performance figure, high-performance cipher, high-performance computer_science, high-performance calculate, high-performance cypher, high-performance reckon, high-performance computation, high-performance calculation, high-performance compute, high-performance work_out, high-performance computing\n',
#  'International quislingism, International collaboration, International coaction, International collaborationism, international quislingism, international collaboration, international coaction, international collaborationism, external quislingism, external collaboration, external coaction, external collaborationism, outside quislingism, outside collaboration, outside coaction, outside collaborationism, international collaboration\n',
#  "noesis histrionics and noesis nucleotide, noesis histrionics and noesis base, noesis histrionics and noesis root_word, noesis histrionics and noesis foot, noesis histrionics and noesis establish, noesis histrionics and noesis bag, noesis histrionics and noesis fundament, noesis histrionics and noesis foundation, noesis histrionics and noesis Base, noesis histrionics and noesis groundwork, noesis histrionics and noesis theme, noesis histrionics and noesis base_of_operations, noesis histrionics and noesis floor, noesis histrionics and noesis al-Qaida, noesis histrionics and noesis ground, noesis histrionics and noesis found, noesis histrionics and noesis infrastructure, noesis histrionics and noesis basis, noesis histrionics and noesis Qaeda, noesis histrionics and noesis footing, noesis histrionics and noesis al-Qa'ida, noesis histrionics and noesis radical, noesis histrionics and noesis substructure, noesis histrionics and noesis root, noesis histrionics and noesis cornerstone, noesis histrionics and noesis pedestal, noesis histrionics and noesis home, noesis histrionics and noesis free-base, noesis histrionics and noesis radix, noesis histrionics and noesis stand, noesis histrionics and noesis stem, noesis histrionics and noesis understructure, noesis histrionics and noesis alkali, noesis histrionics and noesis al-Qaeda, noesis histrionics and knowledge nucleotide, noesis histrionics and knowledge base, noesis histrionics and knowledge root_word, noesis histrionics and knowledge foot, noesis histrionics and knowledge establish, noesis histrionics and knowledge bag, noesis histrionics and knowledge fundament, noesis histrionics and knowledge foundation, noesis histrionics and knowledge Base, noesis histrionics and knowledge groundwork, noesis histrionics and knowledge theme, noesis histrionics and knowledge base_of_operations, noesis histrionics and knowledge floor, noesis histrionics and knowledge al-Qaida, noesis histrionics and knowledge ground, noesis histrionics and knowledge found, noesis histrionics and knowledge infrastructure, noesis histrionics and knowledge basis, noesis histrionics and knowledge Qaeda, noesis histrionics and knowledge footing, noesis histrionics and knowledge al-Qa'ida, noesis histrionics and knowledge radical, noesis histrionics and knowledge substructure, noesis histrionics and knowledge root, noesis histrionics and knowledge cornerstone, noesis histrionics and knowledge pedestal, noesis histrionics and knowledge home, noesis histrionics and knowledge free-base, noesis histrionics and knowledge radix, noesis histrionics and knowledge stand, noesis histrionics and knowledge stem, noesis histrionics and knowledge understructure, noesis histrionics and knowledge alkali, noesis histrionics and knowledge al-Qaeda, noesis histrionics and cognition nucleotide, noesis histrionics and cognition base, noesis histrionics and cognition root_word, noesis histrionics and cognition foot, noesis histrionics and cognition establish, noesis histrionics and cognition bag, noesis histrionics and cognition fundament, noesis histrionics and cognition foundation, noesis histrionics and cognition Base, noesis histrionics and cognition groundwork, noesis histrionics and cognition theme, noesis histrionics and cognition base_of_operations, noesis histrionics and cognition floor, noesis histrionics and cognition al-Qaida, noesis histrionics and cognition ground, noesis histrionics and cognition found, noesis histrionics and cognition infrastructure, noesis histrionics and cognition basis, noesis histrionics and cognition Qaeda, noesis histrionics and cognition footing, noesis histrionics and cognition al-Qa'ida, noesis histrionics and cognition radical, noesis histrionics and cognition substructure, noesis histrionics and cognition root, noesis histrionics and cognition cornerstone, noesis histrionics and cognition pedestal, noesis histrionics and cognition home, noesis histrionics and cognition free-base, noesis histrio ...
#  'machine-to-machine communicating, machine-to-machine communication, machine-to-machine communication\n',
#  'car discover, car find_out, car acquisition, car check, car watch, car determine, car scholarship, car study, car learning, car teach, car memorise, car erudition, car ascertain, car get_word, car instruct, car acquire, car memorize, car learnedness, car get_wind, car see, car get_a_line, car pick_up, car con, car read, car take, car larn, car hear, car eruditeness, car encyclopedism, car learn, car encyclopaedism, simple_machine discover, simple_machine find_out, simple_machine acquisition, simple_machine check, simple_machine watch, simple_machine determine, simple_machine scholarship, simple_machine study, simple_machine learning, simple_machine teach, simple_machine memorise, simple_machine erudition, simple_machine ascertain, simple_machine get_word, simple_machine instruct, simple_machine acquire, simple_machine memorize, simple_machine learnedness, simple_machine get_wind, simple_machine see, simple_machine get_a_line, simple_machine pick_up, simple_machine con, simple_machine read, simple_machine take, simple_machine larn, simple_machine hear, simple_machine eruditeness, simple_machine encyclopedism, simple_machine learn, simple_machine encyclopaedism, motorcar discover, motorcar find_out, motorcar acquisition, motorcar check, motorcar watch, motorcar determine, motorcar scholarship, motorcar study, motorcar learning, motorcar teach, motorcar memorise, motorcar erudition, motorcar ascertain, motorcar get_word, motorcar instruct, motorcar acquire, motorcar memorize, motorcar learnedness, motorcar get_wind, motorcar see, motorcar get_a_line, motorcar pick_up, motorcar con, motorcar read, motorcar take, motorcar larn, motorcar hear, motorcar eruditeness, motorcar encyclopedism, motorcar learn, motorcar encyclopaedism, automobile discover, automobile find_out, automobile acquisition, automobile check, automobile watch, automobile determine, automobile scholarship, automobile study, automobile learning, automobile teach, automobile memorise, automobile erudition, automobile ascertain, automobile get_word, automobile instruct, automobile acquire, automobile memorize, automobile learnedness, automobile get_wind, automobile see, automobile get_a_line, automobile pick_up, automobile con, automobile read, automobile take, automobile larn, automobile hear, automobile eruditeness, automobile encyclopedism, automobile learn, automobile encyclopaedism, political_machine discover, political_machine find_out, political_machine acquisition, political_machine check, political_machine watch, political_machine determine, political_machine scholarship, political_machine study, political_machine learning, political_machine teach, political_machine memorise, political_machine erudition, political_machine ascertain, political_machine get_word, political_machine instruct, political_machine acquire, political_machine memorize, political_machine learnedness, political_machine get_wind, political_machine see, political_machine get_a_line, political_machine pick_up, political_machine con, political_machine read, political_machine take, political_machine larn, political_machine hear, political_machine eruditeness, political_machine encyclopedism, political_machine learn, political_machine encyclopaedism, auto discover, auto find_out, auto acquisition, auto check, auto watch, auto determine, auto scholarship, auto study, auto learning, auto teach, auto memorise, auto erudition, auto ascertain, auto get_word, auto instruct, auto acquire, auto memorize, auto learnedness, auto get_wind, auto see, auto get_a_line, auto pick_up, auto con, auto read, auto take, auto larn, auto hear, auto eruditeness, auto encyclopedism, auto learn, auto encyclopaedism, machine discover, machine find_out, machine acquisition, machine check, machine watch, machine determine, machine scholarship, machine study, machine learning, machine teach, machine memorise, machine erudition, machine ascertain, machine get_word, machine instruct, machine acquire, machine memorize, mach ...
#  'markup nomenclature, markup voice_communication, markup terminology, markup linguistic_communication, markup speech, markup spoken_language, markup linguistic_process, markup speech_communication, markup words, markup language, markup oral_communication, markup lyric, markup spoken_communication, markup languages\n',
#  'metadata provenience, metadata provenance, metadata place_of_origin, metadata birthplace, metadata cradle, metadata provenance\n',
#  'metadata timbre, metadata timber, metadata select, metadata caliber, metadata prime, metadata tone, metadata lineament, metadata quality, metadata calibre, metadata character, metadata prize, metadata choice, metadata quality\n',
#  'cancel nomenclature action, cancel nomenclature sue, cancel nomenclature march, cancel nomenclature swear_out, cancel nomenclature work_on, cancel nomenclature process, cancel nomenclature work, cancel nomenclature litigate, cancel nomenclature treat, cancel nomenclature processing, cancel nomenclature serve, cancel voice_communication action, cancel voice_communication sue, cancel voice_communication march, cancel voice_communication swear_out, cancel voice_communication work_on, cancel voice_communication process, cancel voice_communication work, cancel voice_communication litigate, cancel voice_communication treat, cancel voice_communication processing, cancel voice_communication serve, cancel terminology action, cancel terminology sue, cancel terminology march, cancel terminology swear_out, cancel terminology work_on, cancel terminology process, cancel terminology work, cancel terminology litigate, cancel terminology treat, cancel terminology processing, cancel terminology serve, cancel linguistic_communication action, cancel linguistic_communication sue, cancel linguistic_communication march, cancel linguistic_communication swear_out, cancel linguistic_communication work_on, cancel linguistic_communication process, cancel linguistic_communication work, cancel linguistic_communication litigate, cancel linguistic_communication treat, cancel linguistic_communication processing, cancel linguistic_communication serve, cancel speech action, cancel speech sue, cancel speech march, cancel speech swear_out, cancel speech work_on, cancel speech process, cancel speech work, cancel speech litigate, cancel speech treat, cancel speech processing, cancel speech serve, cancel spoken_language action, cancel spoken_language sue, cancel spoken_language march, cancel spoken_language swear_out, cancel spoken_language work_on, cancel spoken_language process, cancel spoken_language work, cancel spoken_language litigate, cancel spoken_language treat, cancel spoken_language processing, cancel spoken_language serve, cancel linguistic_process action, cancel linguistic_process sue, cancel linguistic_process march, cancel linguistic_process swear_out, cancel linguistic_process work_on, cancel linguistic_process process, cancel linguistic_process work, cancel linguistic_process litigate, cancel linguistic_process treat, cancel linguistic_process processing, cancel linguistic_process serve, cancel speech_communication action, cancel speech_communication sue, cancel speech_communication march, cancel speech_communication swear_out, cancel speech_communication work_on, cancel speech_communication process, cancel speech_communication work, cancel speech_communication litigate, cancel speech_communication treat, cancel speech_communication processing, cancel speech_communication serve, cancel words action, cancel words sue, cancel words march, cancel words swear_out, cancel words work_on, cancel words process, cancel words work, cancel words litigate, cancel words treat, cancel words processing, cancel words serve, cancel language action, cancel language sue, cancel language march, cancel language swear_out, cancel language work_on, cancel language process, cancel language work, cancel language litigate, cancel language treat, cancel language processing, cancel language serve, cancel oral_communication action, cancel oral_communication sue, cancel oral_communication march, cancel oral_communication swear_out, cancel oral_communication work_on, cancel oral_communication process, cancel oral_communication work, cancel oral_communication litigate, cancel oral_communication treat, cancel oral_communication processing, cancel oral_communication serve, cancel lyric action, cancel lyric sue, cancel lyric march, cancel lyric swear_out, cancel lyric work_on, cancel lyric process, cancel lyric work, cancel lyric litigate, cancel lyric treat, cancel lyric processing, cancel lyric serve, cancel spoken_communication action, cancel spoken_communication sue, cancel spo ...
#  'mathematical algorithm, mathematical algorithmic_rule, mathematical algorithmic_program, numeral algorithm, numeral algorithmic_rule, numeral algorithmic_program, numeric algorithm, numeric algorithmic_rule, numeric algorithmic_program, numerical algorithm, numerical algorithmic_rule, numerical algorithmic_program, numerical algorithms\n',
#  'hepatic_portal_vein and substance_abuser port, hepatic_portal_vein and substance_abuser user_interface, hepatic_portal_vein and substance_abuser interface, hepatic_portal_vein and drug_user port, hepatic_portal_vein and drug_user user_interface, hepatic_portal_vein and drug_user interface, hepatic_portal_vein and user port, hepatic_portal_vein and user user_interface, hepatic_portal_vein and user interface, hepatic_portal_vein and exploiter port, hepatic_portal_vein and exploiter user_interface, hepatic_portal_vein and exploiter interface, vena_portae and substance_abuser port, vena_portae and substance_abuser user_interface, vena_portae and substance_abuser interface, vena_portae and drug_user port, vena_portae and drug_user user_interface, vena_portae and drug_user interface, vena_portae and user port, vena_portae and user user_interface, vena_portae and user interface, vena_portae and exploiter port, vena_portae and exploiter user_interface, vena_portae and exploiter interface, portal and substance_abuser port, portal and substance_abuser user_interface, portal and substance_abuser interface, portal and drug_user port, portal and drug_user user_interface, portal and drug_user interface, portal and user port, portal and user user_interface, portal and user interface, portal and exploiter port, portal and exploiter user_interface, portal and exploiter interface, portal_site and substance_abuser port, portal_site and substance_abuser user_interface, portal_site and substance_abuser interface, portal_site and drug_user port, portal_site and drug_user user_interface, portal_site and drug_user interface, portal_site and user port, portal_site and user user_interface, portal_site and user interface, portal_site and exploiter port, portal_site and exploiter user_interface, portal_site and exploiter interface, portal_vein and substance_abuser port, portal_vein and substance_abuser user_interface, portal_vein and substance_abuser interface, portal_vein and drug_user port, portal_vein and drug_user user_interface, portal_vein and drug_user interface, portal_vein and user port, portal_vein and user user_interface, portal_vein and user interface, portal_vein and exploiter port, portal_vein and exploiter user_interface, portal_vein and exploiter interface, portals and user interfaces\n',
# ...
#  'stochastic phenomenon, stochastic phenomena\n',
#  'transport summons, transport swear_out, transport appendage, transport sue, transport unconscious_process, transport march, transport work_on, transport litigate, transport treat, transport operation, transport cognitive_process, transport process, transport work, transport physical_process, transport outgrowth, transport action, transport procedure, transport cognitive_operation, transport mental_process, transport serve, enchant summons, enchant swear_out, enchant appendage, enchant sue, enchant unconscious_process, enchant march, enchant work_on, enchant litigate, enchant treat, enchant operation, enchant cognitive_process, enchant process, enchant work, enchant physical_process, enchant outgrowth, enchant action, enchant procedure, enchant cognitive_operation, enchant mental_process, enchant serve, shipping summons, shipping swear_out, shipping appendage, shipping sue, shipping unconscious_process, shipping march, shipping work_on, shipping litigate, shipping treat, shipping operation, shipping cognitive_process, shipping process, shipping work, shipping physical_process, shipping outgrowth, shipping action, shipping procedure, shipping cognitive_operation, shipping mental_process, shipping serve, raptus summons, raptus swear_out, raptus appendage, raptus sue, raptus unconscious_process, raptus march, raptus work_on, raptus litigate, raptus treat, raptus operation, raptus cognitive_process, raptus process, raptus work, raptus physical_process, raptus outgrowth, raptus action, raptus procedure, raptus cognitive_operation, raptus mental_process, raptus serve, enthral summons, enthral swear_out, enthral appendage, enthral sue, enthral unconscious_process, enthral march, enthral work_on, enthral litigate, enthral treat, enthral operation, enthral cognitive_process, enthral process, enthral work, enthral physical_process, enthral outgrowth, enthral action, enthral procedure, enthral cognitive_operation, enthral mental_process, enthral serve, tape_drive summons, tape_drive swear_out, tape_drive appendage, tape_drive sue, tape_drive unconscious_process, tape_drive march, tape_drive work_on, tape_drive litigate, tape_drive treat, tape_drive operation, tape_drive cognitive_process, tape_drive process, tape_drive work, tape_drive physical_process, tape_drive outgrowth, tape_drive action, tape_drive procedure, tape_drive cognitive_operation, tape_drive mental_process, tape_drive serve, exaltation summons, exaltation swear_out, exaltation appendage, exaltation sue, exaltation unconscious_process, exaltation march, exaltation work_on, exaltation litigate, exaltation treat, exaltation operation, exaltation cognitive_process, exaltation process, exaltation work, exaltation physical_process, exaltation outgrowth, exaltation action, exaltation procedure, exaltation cognitive_operation, exaltation mental_process, exaltation serve, transferral summons, transferral swear_out, transferral appendage, transferral sue, transferral unconscious_process, transferral march, transferral work_on, transferral litigate, transferral treat, transferral operation, transferral cognitive_process, transferral process, transferral work, transferral physical_process, transferral outgrowth, transferral action, transferral procedure, transferral cognitive_operation, transferral mental_process, transferral serve, channelize summons, channelize swear_out, channelize appendage, channelize sue, channelize unconscious_process, channelize march, channelize work_on, channelize litigate, channelize treat, channelize operation, channelize cognitive_process, channelize process, channelize work, channelize physical_process, channelize outgrowth, channelize action, channelize procedure, channelize cognitive_operation, channelize mental_process, channelize serve, ecstasy summons, ecstasy swear_out, ecstasy appendage, ecstasy sue, ecstasy unconscious_process, ecstasy march, ecstasy work_on, ecstasy litigate, ecstasy treat, ecstasy operation, ecstasy cognitive_process, ecstasy ...
#  'wave particle fundamental_interaction, wave particle interaction, wave atom fundamental_interaction, wave atom interaction, wave speck fundamental_interaction, wave speck interaction, wave molecule fundamental_interaction, wave molecule interaction, wave mote fundamental_interaction, wave mote interaction, wave corpuscle fundamental_interaction, wave corpuscle interaction, wave subatomic_particle fundamental_interaction, wave subatomic_particle interaction, waving particle fundamental_interaction, waving particle interaction, waving atom fundamental_interaction, waving atom interaction, waving speck fundamental_interaction, waving speck interaction, waving molecule fundamental_interaction, waving molecule interaction, waving mote fundamental_interaction, waving mote interaction, waving corpuscle fundamental_interaction, waving corpuscle interaction, waving subatomic_particle fundamental_interaction, waving subatomic_particle interaction, roll particle fundamental_interaction, roll particle interaction, roll atom fundamental_interaction, roll atom interaction, roll speck fundamental_interaction, roll speck interaction, roll molecule fundamental_interaction, roll molecule interaction, roll mote fundamental_interaction, roll mote interaction, roll corpuscle fundamental_interaction, roll corpuscle interaction, roll subatomic_particle fundamental_interaction, roll subatomic_particle interaction, undulate particle fundamental_interaction, undulate particle interaction, undulate atom fundamental_interaction, undulate atom interaction, undulate speck fundamental_interaction, undulate speck interaction, undulate molecule fundamental_interaction, undulate molecule interaction, undulate mote fundamental_interaction, undulate mote interaction, undulate corpuscle fundamental_interaction, undulate corpuscle interaction, undulate subatomic_particle fundamental_interaction, undulate subatomic_particle interaction, Wave particle fundamental_interaction, Wave particle interaction, Wave atom fundamental_interaction, Wave atom interaction, Wave speck fundamental_interaction, Wave speck interaction, Wave molecule fundamental_interaction, Wave molecule interaction, Wave mote fundamental_interaction, Wave mote interaction, Wave corpuscle fundamental_interaction, Wave corpuscle interaction, Wave subatomic_particle fundamental_interaction, Wave subatomic_particle interaction, curl particle fundamental_interaction, curl particle interaction, curl atom fundamental_interaction, curl atom interaction, curl speck fundamental_interaction, curl speck interaction, curl molecule fundamental_interaction, curl molecule interaction, curl mote fundamental_interaction, curl mote interaction, curl corpuscle fundamental_interaction, curl corpuscle interaction, curl subatomic_particle fundamental_interaction, curl subatomic_particle interaction, moving_ridge particle fundamental_interaction, moving_ridge particle interaction, moving_ridge atom fundamental_interaction, moving_ridge atom interaction, moving_ridge speck fundamental_interaction, moving_ridge speck interaction, moving_ridge molecule fundamental_interaction, moving_ridge molecule interaction, moving_ridge mote fundamental_interaction, moving_ridge mote interaction, moving_ridge corpuscle fundamental_interaction, moving_ridge corpuscle interaction, moving_ridge subatomic_particle fundamental_interaction, moving_ridge subatomic_particle interaction, beckon particle fundamental_interaction, beckon particle interaction, beckon atom fundamental_interaction, beckon atom interaction, beckon speck fundamental_interaction, beckon speck interaction, beckon molecule fundamental_interaction, beckon molecule interaction, beckon mote fundamental_interaction, beckon mote interaction, beckon corpuscle fundamental_interaction, beckon corpuscle interaction, beckon subatomic_particle fundamental_interaction, beckon subatomic_particle interaction, flap particle fundamental_interaction, flap particle interaction, flap atom fu ...
#  'wave wave fundamental_interaction, wave wave interaction, wave waving fundamental_interaction, wave waving interaction, wave roll fundamental_interaction, wave roll interaction, wave undulate fundamental_interaction, wave undulate interaction, wave Wave fundamental_interaction, wave Wave interaction, wave curl fundamental_interaction, wave curl interaction, wave moving_ridge fundamental_interaction, wave moving_ridge interaction, wave beckon fundamental_interaction, wave beckon interaction, wave flap fundamental_interaction, wave flap interaction, wave flourish fundamental_interaction, wave flourish interaction, wave brandish fundamental_interaction, wave brandish interaction, wave wafture fundamental_interaction, wave wafture interaction, wave undulation fundamental_interaction, wave undulation interaction, waving wave fundamental_interaction, waving wave interaction, waving waving fundamental_interaction, waving waving interaction, waving roll fundamental_interaction, waving roll interaction, waving undulate fundamental_interaction, waving undulate interaction, waving Wave fundamental_interaction, waving Wave interaction, waving curl fundamental_interaction, waving curl interaction, waving moving_ridge fundamental_interaction, waving moving_ridge interaction, waving beckon fundamental_interaction, waving beckon interaction, waving flap fundamental_interaction, waving flap interaction, waving flourish fundamental_interaction, waving flourish interaction, waving brandish fundamental_interaction, waving brandish interaction, waving wafture fundamental_interaction, waving wafture interaction, waving undulation fundamental_interaction, waving undulation interaction, roll wave fundamental_interaction, roll wave interaction, roll waving fundamental_interaction, roll waving interaction, roll roll fundamental_interaction, roll roll interaction, roll undulate fundamental_interaction, roll undulate interaction, roll Wave fundamental_interaction, roll Wave interaction, roll curl fundamental_interaction, roll curl interaction, roll moving_ridge fundamental_interaction, roll moving_ridge interaction, roll beckon fundamental_interaction, roll beckon interaction, roll flap fundamental_interaction, roll flap interaction, roll flourish fundamental_interaction, roll flourish interaction, roll brandish fundamental_interaction, roll brandish interaction, roll wafture fundamental_interaction, roll wafture interaction, roll undulation fundamental_interaction, roll undulation interaction, undulate wave fundamental_interaction, undulate wave interaction, undulate waving fundamental_interaction, undulate waving interaction, undulate roll fundamental_interaction, undulate roll interaction, undulate undulate fundamental_interaction, undulate undulate interaction, undulate Wave fundamental_interaction, undulate Wave interaction, undulate curl fundamental_interaction, undulate curl interaction, undulate moving_ridge fundamental_interaction, undulate moving_ridge interaction, undulate beckon fundamental_interaction, undulate beckon interaction, undulate flap fundamental_interaction, undulate flap interaction, undulate flourish fundamental_interaction, undulate flourish interaction, undulate brandish fundamental_interaction, undulate brandish interaction, undulate wafture fundamental_interaction, undulate wafture interaction, undulate undulation fundamental_interaction, undulate undulation interaction, Wave wave fundamental_interaction, Wave wave interaction, Wave waving fundamental_interaction, Wave waving interaction, Wave roll fundamental_interaction, Wave roll interaction, Wave undulate fundamental_interaction, Wave undulate interaction, Wave Wave fundamental_interaction, Wave Wave interaction, Wave curl fundamental_interaction, Wave curl interaction, Wave moving_ridge fundamental_interaction, Wave moving_ridge interaction, Wave beckon fundamental_interaction, Wave beckon interaction, Wave flap fundamental_interaction, Wave flap interaction, Wave flo ...
#  "instrumental_role and proficiency, instrumental_role and technique, pawn and proficiency, pawn and technique, legal_instrument and proficiency, legal_instrument and technique, musical_instrument and proficiency, musical_instrument and technique, instrumentate and proficiency, instrumentate and technique, cat's-paw and proficiency, cat's-paw and technique, official_document and proficiency, official_document and technique, instrument and proficiency, instrument and technique, legal_document and proficiency, legal_document and technique, tool and proficiency, tool and technique, instruments and techniques\n"]

# %% [markdown]
# #### Add acronyms to the bottom of the original multi-term synonyms file

# %%
txt_data_multi_syns.append('\n\n# acronyms added from Heliophysics 2013 Decadal survey in July 2022')

for l in range(len(pd_acronyms)):
    flag = 0
    # Check if the acronym already exists in ADS file
    for i,s in enumerate(extracted_acronyms):
        if pd_acronyms['acronyms'][l] == s:
            print('Helio acronym: {}; ADS acronym: {}'.format(pd_acronyms['acronyms'][l],extracted_acronyms[i]))
            flag = 1
            break
        
    if flag == 0:     
        txt_tmp = '{},{}'.format(pd_acronyms['acronyms'][l],pd_acronyms['terms'][l].lower())

        txt_data_multi_syns.append(txt_tmp)
        print('added...{}'.format(txt_data_multi_syns[-1]))
    


#TODO: 
#  edit by hand to exclude short acronyms
#  edit by hand to exclude acronyms which are too ambiguous (e.g. VO means "Virtual Observatory" in AST but "oxygen vacancy" in PHY)
#  disambiguate same acronyms
#  find and match similar acronyms

#DONE
#  find and match same acronyms
# Out:
# Helio acronym: AAS; ADS acronym: AAS
# Helio acronym: ACE; ADS acronym: ACE
# added...ACR,anomalous cosmic ray
# added...AFOSR,air force office of scientific research
# added...AFRL,air force research laboratory
# added...AFWA,air force weather agency
# added...AGS,atmospheric and geospace sciences division
# Helio acronym: AGU; ADS acronym: AGU
# added...AIA,atmospheric imaging assembly
# Helio acronym: AIM; ADS acronym: AIM
# added...AIMI,atmosphere ionosphere magnetosphere interactions
# added...AIP,american institute of physics
# added...AMISR,advanced modular incoherent scatter radar
# added...AMPERE,active magnetosphere and planetary electrodynamics response experiment
# added...AMPTE,active magnetospheric particle tracer explorers
# added...AO,announcement of opportunity
# added...APS,american physical society; active pixel sensor
# added...AST,division of astronomical sciences
# added...ATST,advanced technology solar telescope
# added...AU,astronomical unit
# Helio acronym: AURA; ADS acronym: AURA
# Helio acronym: AXAF; ADS acronym: AXAF
# added...BARREL,balloon array for rbsp relativistic electron losses
# added...BBSO,big bear solar observatory
# added...CADRE,cubesat investigating atmospheric density response to extreme driving
# added...CAREER,faculty early career development
# added...CASSIOPE,cascade small satellite and ionospheric polar explorer
# added...CATE,cost and technical evaluation
# added...CAWSES,climate and weather of the sun earth system
# Helio acronym: CCD; ADS acronym: CCD
# added...CCE,charge composition explorer
# added...CCMC,community coordinated modeling center
# added...CDC,concept design center
# added...CEDAR,coupling energetics and dynamics of atmospheric regions
# Helio acronym: CHAMP; ADS acronym: CHAMP
# added...CINDI,coupled ion neutral dynamic investigation
# added...CINEMA,cubesat for ions neutrals electrons magnetic fields
# added...CIR,corotating interaction region
# added...CISM,center for integrated space weather modeling
# Helio acronym: CME; ADS acronym: CME
# added...CMOS,complementary metal oxide semiconductor
# added...C/No,carrier signal to noise strength
# added...C/NOFS,communications/navigation outage forecasting system
# Helio acronym: COBE; ADS acronym: COBE
# added...CoBRA,complexity based risk assessment
# added...COSMIC,constellation observing system for meteorology ionosphere and climate
# added...COSMO,coronal solar magnetism observatory
# added...COTS,commercial off the shelf
# added...CPU,central processing unit
# added...CRRES,combined release and radiation effects satellite
# added...CSSWE,colorado student space weather experiment
# added...DASI,distributed array of small instruments
# added...DC,direct current
# added...DICE,dynamic ionosphere cubesat experiment
# added...DLR,german aerospace center
# added...DMSP,defense meteorological satellites program
# added...DOD,department of defense
# added...DOE,department of energy
# added...DRIVE,diversify realize integrate venture educate
# added...DSCOVR,deep space climate observatory
# added...DYNAMIC,dynamical neutral atmosphere ionosphere coupling (mission)
# added...EASCO,earth affecting solar causes observatory
# added...ECT,energetic particle composition and thermal plasma suite
# added...EIA,equatorial ionization anomaly
# added...EISCAT,european incoherent scatter scientific association
# added...ELaNa,educational launch of nanosatellites
# added...ENA,energetic neutral atom
# added...ENASI,energetic neutral atom spectroscopic imager
# added...EPO,education and public outreach
# added...e-POP,enhanced polar outflow probe
# Helio acronym: EPP; ADS acronym: EPP
# Helio acronym: ESA; ADS acronym: ESA
# added...ESCAPE,energetics sources and couplings of atmosphere plasma escape
# added...ETA,equatorial temperature anomaly
# Helio acronym: EUV; ADS acronym: EUV
# added...EUVI,extreme ultraviolet imager
# added...EVE,extreme ultraviolet variability experiment
# added...FAA,federal aviation administration
# added...FASR,frequency agile solar radiotelescope
# added...FAST,fast aurora snapshot
# added...FDSS,faculty development in space science
# added...FIREBIRD,focused investigations of relativistic electron burst intensity range and dynamics
# added...FOXSI,focusing optics x ray spectroscopic imager
# added...FUV,far ultraviolet
# Helio acronym: FWHM; ADS acronym: FWHM
# added...FY,fiscal year
# Helio acronym: GCR; ADS acronym: GCR
# added...GDC,geospace dynamics constellation
# Helio acronym: GEM; ADS acronym: GEM
# added...GEO,geostationary earth orbit
# added...GI,guest investigator
# added...GIC,geomagnetically induced current; ground induced current
# added...GNSS,global navigation satellite systems
# added...GOCE,gravity field and steady state ocean circulation explorer
# added...GOES,geostationary operational environmental satellite
# Helio acronym: GONG; ADS acronym: GONG
# Helio acronym: GPS; ADS acronym: GPS
# added...GRACE,gravity recovery and climate experiment
# added...GRIPS,gamma ray imager/polarimeter for solar flares
# added...GRIS,gamma ray imaging spectrometer
# Helio acronym: GSFC; ADS acronym: GSFC
# added...GSRP,graduate student research program
# added...GUVI,global ultraviolet imager
# added...GW,gravity waves
# added...HAARP,high frequency active auroral research program
# Helio acronym: HAO; ADS acronym: HAO
# Helio acronym: HEAO; ADS acronym: HEAO
# added...HEIDI,high energy imaging device
# added...HEO,high earth orbit (above geo)
# added...HF,high frequency
# added...HI,heliospheric imager
# added...HIREGS,high resolution gamma ray and hard x ray spectrometer
# added...HITDP,heliophysics instrument and technology development program
# added...HPDE,heliophysics data environment
# added...HSC,heliophysics science center
# added...HSO,heliophysics systems observatory
# added...HSS,high speed solar wind streams
# added...HSW,halo solar wind
# added...HTP,heliophysics theory program
# added...HXR,hard x ray
# added...IBEX,interstellar boundary explorer
# added...IGS,international gnss service
# Helio acronym: IGY; ADS acronym: IGY
# added...IHY,international heliophysical year
# added...IKAROS,interplanetary kite craft accelerated by radiation of the sun
# added...IMAGE,imager for magnetopause to aurora global exploration
# added...IMAP,interstellar mapping and acceleration probe
# Helio acronym: IMF; ADS acronym: IMF
# added...IMP,interplanetary monitoring platform
# Helio acronym: IMPACT; ADS acronym: IMPACT
# added...INCA,imaging neutral atom camera
# added...INMS,ion neutral mass spectrograph
# added...IR,infrared
# added...IRIS,interface region imaging spectrograph
# added...ISCCP,international satellite cloud climatology project
# Helio acronym: ISEE; ADS acronym: ISEE
# added...ISI,institute for scientific information
# Helio acronym: ISM; ADS acronym: ISM
# added...ISMF,interstellar magnetic field
# added...ISOON,improved solar observing optical network
# added...ISR,incoherent scatter radar
# added...ISS,international space station
# added...IT,ionosphere thermosphere
# added...ITAR,international traffic in arms regulations
# added...ITM,ionosphere thermosphere mesosphere
# added...IVM,ion velocity meter
# Helio acronym: JAXA; ADS acronym: JAXA
# Helio acronym: JPL; ADS acronym: JPL
# added...L1,sun earth lagrangian point 1
# added...L5,sun earth lagrangian point 5
# Helio acronym: LANL; ADS acronym: LANL
# added...LBH,lyman birge hopfield
# added...LCAS,low cost access to space
# added...LECP,low energy charged particle
# Helio acronym: LEO; ADS acronym: LEO
# added...LET,low energy telescope
# added...LISM,local interstellar medium
# Helio acronym: LPV; ADS acronym: LPV
# added...LT,local time
# added...LWS,living with a star
# Helio acronym: MAC; ADS acronym: MAC
# added...MagCat,magnetospheric constellation and tomography (mission)
# added...MagCon,magnetospheric constellation (mission)
# added...MEDICI,magnetosphere energetics dynamics and ionospheric coupling investigation
# added...MEMS,microelectromechanical system
# added...MESSENGER,mercury surface space environment geochemistry and ranging
# Helio acronym: MHD; ADS acronym: MHD
# added...MI,magnetosphere ionosphere
# added...MIDEX,mid size explorer
# added...MISTE,magnetosphere ionosphere source term energetics (mission)
# added...MIT,magnetosphere ionosphere thermosphere
# added...MLSO,mauna loa solar observatory
# added...MLT,mesosphere and lower thermosphere
# added...MMS,magnetospheric multiscale (mission)
# added...MO&DA,mission operations and data analysis
# added...MODIS,moderate resolution imaging spectroradiometer
# Helio acronym: MPS; ADS acronym: MPS
# added...MREFC,major research equipment and facilities construction (program)
# added...MRF,medium scale research facility
# added...MSO,mees solar observatory
# added...MWO,mt wilson observatory
# Helio acronym: NASA; ADS acronym: NASA
# added...NCAR,national center for atmospheric research
# added...NESDIS,national environmental satellite data and information service
# added...NESSF,nasa’s earth and space science fellowship (program)
# added...NGDC,national geophysical data center
# Helio acronym: NIST; ADS acronym: NIST
# added...NJIT,new jersey institute of technology
# Helio acronym: NOAA; ADS acronym: NOAA
# added...NRC,national research council
# Helio acronym: NSF; ADS acronym: NSF
# Helio acronym: NSO; ADS acronym: NSO
# added...NST,new solar telescope
# added...NSWP,national space weather program
# Helio acronym: NuSTAR; ADS acronym: NuSTAR
# added...NWM,neutral wind meter
# added...NWS,national weather service
# added...OCT,office of the chief technologist
# added...OEDG,opportunities for enhancing diversity in the geosciences (program)
# added...ORBITALS,outer radiation belt injection transport acceleration and loss satellite
# added...OVSA,owens valley solar array
# added...PARS,polar aeronomy and radio science
# added...PFISR,poker flat incoherent scatter radar
# added...PI,principal investigator
# added...POES,polar operational environmental satellite
# added...P-POD,poly picosatellite orbital deployer
# added...PUI,pickup ion
# added...PW,planetary waves
# Helio acronym: QBO; ADS acronym: QBO
# added...RE,earth radius
# added...RS,sun radius
# added...R&A,research and analysis
# added...RAX,radio aurora explorer
# added...RBSP,radiation belt storm probe; renamed van allen probes
# added...REPT,relativistic electron proton telescope
# added...REU,research experiences for undergraduates
# added...RFI,request for information
# added...RHESSI,ramaty high energy solar spectroscopic imager
# added...RISR,resolute bay incoherent scatter radar
# added...ROSES,research opportunities in space and earth sciences
# added...RPA,ion retarding potential analyzer
# added...SABER,sounding of the atmosphere using broadband emission radiometry
# added...SALMON,stand alone missions of opportunities notice
# added...SAMPEX,solar anomalous and magnetospheric particle explorer
# added...SAPS,subauroral polarization streams
# added...SCOSTEP,scientific committee on solar terrestrial physics
# Helio acronym: SDO; ADS acronym: SDO
# added...SEE,solar eruptive events (mission)
# added...SEP,solar energetic particle
# added...SFO,san fernando observatory
# added...SHINE,solar heliosphere and interplanetary environment
# added...SHP,solar and heliospheric physics
# added...SKR,saturnian kilometric radio
# added...SM,servicing mission
# added...SMD,science mission directorate
# added...SMEI,solar mass ejection imager
# Helio acronym: SMEX; ADS acronym: SMEX
# added...SNOE,student nitric oxide explorer
# Helio acronym: SNR; ADS acronym: SNR
# added...SO,solar orbiter
# Helio acronym: SOHO; ADS acronym: SOHO
# added...SOLIS,synoptic optical long term investigations of the sun
# added...SOON,solar observing optical network
# added...SORCE,solar radiation and climate experiment
# added...SPA,space physics and aeronomy
# added...SPARC,stratospheric processes and their role in climate
# added...SPASE,space physics archive search and extract
# added...SPD,solar physics division
# added...SPI,solar polar imager
# added...SPP,solar probe plus
# added...SRAG,space radiation analysis group
# added...SRP,solar radiation pressure
# added...SR&T,supporting research and technology
# Helio acronym: SSP; ADS acronym: SSP
# added...SSPIS,solar and space physics information system
# added...STE,suprathermal electron
# added...STEM,science technology engineering and mathematics
# Helio acronym: STEREO; ADS acronym: STEREO
# added...STP,solar terrestrial probes (program)
# added...SuperDARN,super dual auroral radar network
# added...SUVIT,solar uv visible ir telescope
# added...SWaC,space weather and climatology
# added...SWAP,space weight and power
# added...SWICS,solar wind ion composition spectrometer
# added...SWL,space weather laboratory
# added...SWMI,solar wind magnetosphere interactions
# added...SWPC,space weather prediction center
# added...SXT,soft x ray telescope
# Helio acronym: TDRSS; ADS acronym: TDRSS
# added...TEC,total electron content
# added...TEX,tiny explorers
# Helio acronym: THEMIS; ADS acronym: THEMIS
# added...TIM,total irradiance monitor
# Helio acronym: TIMED; ADS acronym: TIMED
# added...TR&T,targeted research and technology
# added...TRACE,transition region and coronal explorer
# added...TRL,technology readiness level
# added...TS,termination shock
# added...TSI,total solar irradiance
# added...TWINS,two wide angle imaging neutral atom spectrometers
# Helio acronym: UARS; ADS acronym: UARS
# added...UHURU,small astronomical satellite 1 swahili for freedom
# added...ULDB,ultra long duration balloon
# Helio acronym: USAF; ADS acronym: USAF
# Helio acronym: USGS; ADS acronym: USGS
# added...USML,us munitions list
# added...UT,universal time
# added...UV,ultraviolet
# added...UVCS,ultraviolet coronagraph spectrometer
# added...V1,voyager 1
# added...V2,voyager 2
# added...VxO,(domain specific) virtual observatory
# added...WAAS,wide area augmentation system
# added...WACCM,whole atmosphere community climate model
# added...WBS,work breakdown structure
# added...WHI,whole heliosphere interval
# added...WLC,white light coronagraph
# added...WPI,wave particle interaction
# added...WSA-Enlil,wang sheely arge enlil
# added...WSO,wilcox solar observatory

# %% [markdown]
# #### Write updated single term synonyms to file
# The ordering is:
# 1. original data
# 2. agu terms

# %%
with open(r'data/ads_simple_synonyms_updated.txt', 'w') as fp:
    for item1 in txt_data_simple_syns:
        # write each item on a new line
        print(item1,file=fp)
        
    for item2 in list_simple_syns_update:
        # write each item on a new line
        print(item2,file=fp)   
        
    print('Done')
fp.close()
# Out:
# Done

# %% [markdown]
# #### Write updated multi-term synonyms to file
# The ordering is:
# 1. original data
# 2. acronyms
# 3. agu terms

# %%
with open(r'data/ads_multi_synonyms_updated.txt', 'w') as fp:
    for item1 in txt_data_multi_syns:
        # write each item on a new line
        print(item1,file=fp)
    
    for item2 in list_multi_syns_update:
        # write each item on a new line
        print(item2,file=fp)   
        

        
    print('Done')
fp.close()
# Out:
# Done
